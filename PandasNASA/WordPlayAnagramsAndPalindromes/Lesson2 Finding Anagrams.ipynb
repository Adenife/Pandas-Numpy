# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
words = [line.strip().lower() for line in open('words.txt', 'r')]

# %%
words = sorted({line.strip().lower() for line in open('words.txt', 'r')})

# %%
words[:4]
# Out:
# ['a', 'aa', 'aal', 'aalii']

# %%
sorted('aaron')
# Out:
# ['a', 'a', 'n', 'o', 'r']

# %%
sorted('lives') == sorted('elvis')
# Out:
# True

# %%
sorted('tobi') == sorted('dami')
# Out:
# False

# %%
'-'.join(sorted('aaron'))
# Out:
# 'a-a-n-o-r'

# %%
''.join(sorted('aaron'))
# Out:
# 'aanor'

# %%
def signature(word):
    return ''.join(sorted(word))

# %%
def findAnagram(myWord):
    wordSignature = signature(myWord)
    
    for word in words:
        if wordSignature == signature(word):
            print(word)

# %%
findAnagram('dictionary')
# Out:
# dictionary
# indicatory

# %%
# %time findAnagram('lives')
# Out:
# elvis
# levis
# slive
# Wall time: 329 ms

# %%
wordsBySignature = collections.defaultdict(set)

for word in words:
    wordsBySignature[signature(word)].add(word)

# %%
wordsBySignature
# Out:
# defaultdict(set,
#             {'a': {'a'},
#              'aa': {'aa'},
#              'aal': {'aal', 'ala'},
#              'aaiil': {'aalii'},
#              'aam': {'aam', 'ama'},
#              'aain': {'aani'},
#              'aaadkrrv': {'aardvark'},
#              'aadflorw': {'aardwolf'},
#              'aanor': {'aaron'},
#              'aacinor': {'aaronic', 'nicarao', 'ocarina'},
#              'aaacilnor': {'aaronical'},
#              'aaeinort': {'aaronite', 'aeration'},
#              'aaciinort': {'aaronitic'},
#              'aaru': {'aaru', 'aura'},
#              'ab': {'ab', 'ba'},
#              'aab': {'aba', 'baa'},
#              'aabbdeh': {'ababdeh'},
#              'aaabbu': {'ababua'},
#              'aabc': {'abac', 'caba'},
#              'aaabc': {'abaca'},
#              'aaabcet': {'abacate'},
#              'aaabcy': {'abacay'},
#              'aaabceint': {'abacinate'},
#              'aaabciinnot': {'abacination'},
#              'aabccissu': {'abaciscus'},
#              'aabcist': {'abacist'},
#              'aabck': {'aback'},
#              'aaabcilnt': {'abactinal'},
#              'aaabcillnty': {'abactinally'},
#              'aabcinot': {'abaction'},
#              'aabcort': {'abactor', 'acrobat'},
#              'aabclsuu': {'abaculus'},
#              'aabcsu': {'abacus'},
#              'aabdeit': {'abadite'},
#              'aabff': {'abaff'},
#              'aabft': {'abaft', 'bafta'},
#              'aaabceins': {'abaisance'},
#              'aabeirs': {'abaiser'},
#              'aabdeiss': {'abaissed'},
#              'aaabeeilnt': {'abalienate'},
#              'aaabeiilnnot': {'abalienation'},
#              'aabelno': {'abalone', 'balonea'},
#              'aaabm': {'abama'},
#              'aabeempr': {'abampere'},
#              'aabdnno': {'abandon'},
#              'aaabbdelnno': {'abandonable'},
#              'aabddenno': {'abandoned'},
#              'aabddelnnoy': {'abandonedly'},
#              'aabdeenno': {'abandonee'},
#              'aabdennor': {'abandoner', 'reabandon'},
#              'aabdemnnnot': {'abandonment'},
#              'aabcin': {'abanic', 'bianca'},
#              'aabenst': {'abantes'},
#              'aabinopstt': {'abaptiston'},
#              'aaabbmor': {'abarambo'},
#              'aabirs': {'abaris', 'arabis'},
#              'aabhiorrsst': {'abarthrosis'},
#              'aaabcilrrtu': {'abarticular'},
#              'aaabciilnorttu': {'abarticulation'},
#              'aabs': {'abas', 'saba'},
#              'aabes': {'abase'},
#              'aabdes': {'abased'},
#              'aabdelsy': {'abasedly'},
#              'aabdeensss': {'abasedness'},
#              'aabeemnst': {'abasement'},
#              'aabers': {'abaser', 'abrase'},
#              'aabgis': {'abasgi'},
#              'aabhs': {'abash'},
#              'aabdehs': {'abashed'},
#              'aabdehlsy': {'abashedly'},
#              'aabdeehnsss': {'abashedness'},
#              'aabehlsss': {'abashless'},
#              'aabehllsssy': {'abashlessly'},
#              'aabehmnst': {'abashment'},
#              'aaabis': {'abasia'},
#              'aabcis': {'abasic'},
#              'aabks': {'abask'},
#              'aabinss': {'abassin'},
#              'aaabdeirstz': {'abastardize'},
#              'aaabbelt': {'abatable'},
#              'aabet': {'abate', 'ateba', 'batea', 'beata'},
#              'aabeemntt': {'abatement'},
#              'aabert': {'abater', 'artabe', 'eartab', 'trabea'},
#              'aabist': {'abatis'},
#              'aabdeist': {'abatised'},
#              'aabnot': {'abaton'},
#              'aabort': {'abator'},
#              'aabiortt': {'abattoir'},
#              'aaabtu': {'abatua'},
#              'aabertu': {'abature'},
#              'aabev': {'abave'},
#              'aaabilx': {'abaxial'},
#              'aabeilx': {'abaxile'},
#              'aabez': {'abaze'},
#              'abb': {'abb', 'bab'},
#              'aabb': {'abba', 'baba'},
#              'aabbcemos': {'abbacomes'},
#              'aabbcy': {'abbacy'},
#              'aabbddei': {'abbadide'},
#              'aabbs': {'abbas'},
#              'aabbis': {'abbasi'},
#              'aabbiss': {'abbassi'},
#              'aabbdeiss': {'abbasside'},
#              'aaabbilt': {'abbatial'},
#              'aaabbcilt': {'abbatical'},
#              'abbess': {'abbess'},
#              'abbey': {'abbey', 'bebay'},
#              'abbdeeesty': {'abbeystede'},
#              'abbei': {'abbie'},
#              'abbot': {'abbot'},
#              'abbcoty': {'abbotcy'},
#              'abbillnostuu': {'abbotnullius'},
#              'abbhiopst': {'abbotship'},
#              'aabbeeirtv': {'abbreviate'},
#              'aabbeeilrtvy': {'abbreviately'},
#              'aabbeiinortv': {'abbreviation'},
#              'aabbeiorrtv': {'abbreviator'},
#              'aabbeiorrtvy': {'abbreviatory'},
#              'aabbeeirrtuv': {'abbreviature'},
#              'abby': {'abby', 'baby'},
#              'abbclmoou': {'abcoulomb'},
#              'aabdl': {'abdal'},
#              'aabdt': {'abdat', 'batad'},
#              'aabdeinr': {'abderian'},
#              'abdeeirt': {'abderite'},
#              'abdest': {'abdest'},
#              'aabbcdeil': {'abdicable'},
#              'aabcdint': {'abdicant'},
#              'aabcdeit': {'abdicate'},
#              'aabcdiinot': {'abdication'},
#              'aabcdeiitv': {'abdicative'},
#              'aabcdiort': {'abdicator'},
#              'abdeil': {'abdiel', 'baldie'},
#              'abdeiitv': {'abditive'},
#              'abdiorty': {'abditory'},
#              'abdemno': {'abdomen'},
#              'aabdilmno': {'abdominal'},
#              'aabdeilmnos': {'abdominales'},
#              'aaabdiilmnno': {'abdominalian'},
#              'aabdillmnoy': {'abdominally'},
#              'aabdeiimnnooorrt': {'abdominoanterior'},
#              'aaabccddiimnoor': {'abdominocardiac'},
#              'abcdeeiimnnoosst': {'abdominocentesis'},
#              'abccdiimnoosty': {'abdominocystic'},
#              'aabdegiilmnnoot': {'abdominogenital'},
#              'abcdeehimmnooorsttyy': {'abdominohysterectomy'},
#              'abdehimmnoooorsttyy': {'abdominohysterotomy'},
#              'abdeiimnooooprrst': {'abdominoposterior'},
#              'abcdeimnooops': {'abdominoscope'},
#              'abcdimnooopsy': {'abdominoscopy'},
#              'aabccdhiimnooort': {'abdominothoracic'},
#              'abdimnoosu': {'abdominous'},
#              'aaabdgiilmnnoov': {'abdominovaginal', 'vaginoabdominal'},
#              'aabcdeiilmnoosv': {'abdominovesical', 'vesicoabdominal'},
#              'abcdeu': {'abduce'},
#              'abcdensu': {'abducens'},
#              'abcdentu': {'abducent'},
#              'abcdtu': {'abduct'},
#              'abcdinotu': {'abduction'},
#              'abcdortu': {'abductor'},
#              'abe': {'abe', 'bae', 'bea'},
#              'aabem': {'abeam'},
#              'aaber': {'abear'},
#              'aaabceenr': {'abearance'},
#              'aaabcdeeinr': {'abecedarian'},
#              'aabcdeeimru': {'abecedarium'},
#              'aabcdeery': {'abecedary'},
#              'abde': {'abed', 'bade', 'bead'},
#              'abeghi': {'abeigh'},
#              'abel': {'abel', 'able', 'albe', 'bale', 'beal', 'bela', 'blae'},
#              'abeel': {'abele', 'albee'},
#              'aabeil': {'abelia'},
#              'aabeiln': {'abelian', 'nebalia'},
#              'aabceeil': {'abelicea'},
#              'abeeilt': {'abelite'},
#              'abcehlmossu': {'abelmoschus'},
#              'abeklmos': {'abelmosk'},
#              'aabeilnno': {'abelonian'},
#              'abeeelrt': {'abeltree'},
#              'aabceeegnrrs': {'abencerrages'},
#              'abceeinrt': {'abenteric', 'bicrenate'},
#              'aabehiimpty': {'abepithymia'},
#              'abdeeenr': {'aberdeen'},
#              'abdeeeinrv': {'aberdevine'},
#              'aabdeinnor': {'aberdonian'},
#              'aabeir': {'aberia', 'baeria', 'baiera'},
#              'aabceenrr': {'aberrance'},
#              'aabcenrry': {'aberrancy'},
#              'aabenrrt': {'aberrant'},
#              'aabeerrt': {'aberrate'},
#              'aabeinorrt': {'aberration'},
#              'aaabeilnorrt': {'aberrational'},
#              'aabeorrrt': {'aberrator'},
#              'abeeemorrrt': {'aberrometer'},
#              'abceeooprrs': {'aberroscope'},
#              'aabcenorrtu': {'aberuncator'},
#              'abet': {'abet', 'bate', 'beat', 'beta'},
#              'abeemntt': {'abetment', 'batement'},
#              'aabeltt': {'abettal'},
#              'abeortt': {'abettor', 'taboret'},
#              'aaabceinotuv': {'abevacuation'},
#              'abey': {'abey'},
#              'aabceeny': {'abeyance'},
#              'aabcenyy': {'abeyancy'},
#              'aabenty': {'abeyant'},
#              'aaabdfr': {'abfarad'},
#              'abehnry': {'abhenry'},
#              'aabehiks': {'abhiseka'},
#              'aabbehilmno': {'abhominable'},
#              'abhor': {'abhor'},
#              'abceehnorr': {'abhorrence'},
#              'abcehnorry': {'abhorrency'},
#              'abehnorrt': {'abhorrent', 'earthborn'},
#              'abehlnorrty': {'abhorrently'},
#              'abehorrr': {'abhorrer', 'harborer'},
#              'abbehilorr': {'abhorrible'},
#              'abghinorr': {'abhorring'},
#              'abhnoors': {'abhorson'},
#              'aabdil': {'abidal'},
#              'aabcdein': {'abidance'},
#              'abdei': {'abide'},
#              'abdeir': {'abider', 'bardie'},
#              'abdii': {'abidi'},
#              'abdgiin': {'abiding'},
#              'abdgiilny': {'abidingly'},
#              'abdegiinnss': {'abidingness'},
#              'abei': {'abie'},
#              'abeis': {'abies', 'beisa'},
#              'aabeeitt': {'abietate'},
#              'abeeeint': {'abietene'},
#              'abceiit': {'abietic'},
#              'abeiint': {'abietin'},
#              'aabeeeiint': {'abietineae'},
#              'abeeiinostu': {'abietineous'},
#              'abceiiint': {'abietinic'},
#              'abeeirz': {'abiezer'},
#              'aabgiil': {'abigail'},
#              'aabghiiilps': {'abigailship'},
#              'aabegit': {'abigeat'},
#              'abegisu': {'abigeus'},
#              'aabilo': {'abilao'},
#              'abiilty': {'ability'},
#              'aabill': {'abilla', 'labial'},
#              'abilo': {'abilo', 'aboil'},
#              'aabeeinsttt': {'abintestate'},
#              'abeegiinoss': {'abiogenesis'},
#              'abeegiinosst': {'abiogenesist'},
#              'abceegiinot': {'abiogenetic'},
#              'aabceegiilnot': {'abiogenetical'},
#              'aabceegiillnoty': {'abiogenetically'},
#              'abegiinost': {'abiogenist'},
#              'abeginoosu': {'abiogenous'},
#              'abeginoy': {'abiogeny'},
#              'aabcgiilloo': {'abiological'},
#              'aabcgiilllooy': {'abiologically'},
#              'abgilooy': {'abiology'},
#              'abiioss': {'abiosis'},
#              'abciiot': {'abiotic'},
#              'abchiiooprt': {'abiotrophic'},
#              'abhiooprty': {'abiotrophy'},
#              'abinop': {'abipon'},
#              'abir': {'abir', 'bari', 'rabi'},
#              'aabiinrrtt': {'abirritant'},
#              'aabeiirrtt': {'abirritate'},
#              'aabiiinorrtt': {'abirritation'},
#              'aabeiiirrttv': {'abirritative'},
#              'abinost': {'abiston', 'bastion'},
#              'abbiiit': {'abitibi'},
#              'abeirtu': {'abiuret', 'aubrite', 'biurate', 'rubiate'},
#              'abcejt': {'abject'},
#              'abcdeeejnsst': {'abjectedness'},
#              'abceijnot': {'abjection'},
#              'abceeijtv': {'abjective'},
#              'abcejlty': {'abjectly'},
#              'abceejnsst': {'abjectness'},
#              'abijnot': {'abjoint'},
#              'abdegju': {'abjudge'},
#              'aabcdeijtu': {'abjudicate'},
#              'aabcdiijnotu': {'abjudication'},
#              'abcijnnotu': {'abjunction'},
#              'abceijntuv': {'abjunctive'},
#              'aabijnortu': {'abjuration'},
#              'aabjorrtuy': {'abjuratory'},
#              'abejru': {'abjure'},
#              'abeejmnrtu': {'abjurement'},
#              'abejrru': {'abjurer'},
#              'aabkr': {'abkar', 'arkab'},
#              'aabikr': {'abkari'},
#              'aabhks': {'abkhas', 'kasbah'},
#              'aaabhikns': {'abkhasian'},
#              'aabchl': {'ablach'},
#              'aaabceltt': {'ablactate', 'cabaletta'},
#              'aaabcilnott': {'ablactation'},
#              'aabelr': {'ablare', 'arable', 'arbela'},
#              'aabceilmst': {'ablastemic', 'masticable'},
#              'aablosstu': {'ablastous'},
#              'aabelt': {'ablate'},
#              'aabilnot': {'ablation', 'obtainal'},
#              'aabiilosttu': {'ablatitious'},
#              'aaabilltv': {'ablatival'},
#              'aabeiltv': {'ablative'},
#              'aablort': {'ablator'},
#              'aabltu': {'ablaut', 'tabula'},
#              'aabelz': {'ablaze'},
#              'abeeelz': {'ableeze'},
#              'aabeeglt': {'ablegate'},
#              'abeelnss': {'ableness', 'blaeness', 'sensable'},
#              'aaabehilpr': {'ablepharia'},
#              'aabehlnopr': {'ablepharon'},
#              'aabehloprsu': {'ablepharous'},
#              'aabehlprsu': {'ablepharus'},
#              'aabeilps': {'ablepsia', 'epibasal'},
#              'aabceillpt': {'ableptical'},
#              'aabceilllpty': {'ableptically'},
#              'abelr': {'abler', 'baler', 'belar', 'blare', 'blear'},
#              'abelst': {'ablest', 'stable', 'tables'},
#              'aabceehklstw': {'ablewhackets'},
#              'abilns': {'ablins'},
#              'ablmoo': {'abloom', 'mabolo'},
#              'ablow': {'ablow', 'balow', 'bowla'},
#              'abdelu': {'ablude', 'belaud'},
#              'abelntu': {'abluent', 'tunable'},
#              'abhlsu': {'ablush'},
#              'abilnotu': {'ablution', 'abutilon'},
#              'aabilnortuy': {'ablutionary'},
#              'abilnouv': {'abluvion'},
#              'ably': {'ably', 'blay', 'yalb'},
#              'abhmo': {'abmho', 'abohm'},
#              'aabikn': {'abnaki'},
#              'aabeegnt': {'abnegate'},
#              'aabeginnot': {'abnegation'},
#              'aabeegintv': {'abnegative'},
#              'aabegnort': {'abnegator'},
#              'abenr': {'abner', 'arneb', 'reban'},
#              'aabelnrv': {'abnerval'},
#              'abent': {'abnet', 'beant'},
#              'aabelnru': {'abneural'},
#              'aablmnor': {'abnormal'},
#              'aabilmmnors': {'abnormalism'},
#              'aabilmnorst': {'abnormalist'},
#              'aabilmnorty': {'abnormality'},
#              'aabeilmnorz': {'abnormalize'},
#              'aabllmnory': {'abnormally'},
#              'aabelmnnorss': {'abnormalness'},
#              'abimnorty': {'abnormity'},
#              'abmnoorsu': {'abnormous'},
#              'aabbeelmnru': {'abnumerable'},
#              'abo': {'abo', 'boa'},
#              'aabdor': {'aboard', 'aborad', 'abroad'},
#              'aabbor': {'abobra'},
#              'abdeo': {'abode', 'adobe'},
#              'abdeemnot': {'abodement'},
#              'abdoy': {'abody'},
#              'abhilos': {'abolish'},
#              'abehilors': {'abolisher', 'reabolish'},
#              'abehilmnost': {'abolishment'},
#              'abiilnoot': {'abolition'},
#              'aabiilnoorty': {'abolitionary'},
#              'abiiilmnoost': {'abolitionism'},
#              'abiiilnoostt': {'abolitionist'},
#              'abeiiilnootz': {'abolitionize'},
#              'aabllo': {'abolla'},
#              'aabmo': {'aboma'},
#              'aabmmosu': {'abomasum'},
#              'aabmossu': {'abomasus'},
#              'aabbeilmno': {'abominable'},
#              'aabbeeilmnnoss': {'abominableness'},
#              'aabbilmnoy': {'abominably'},
#              'aabeimnot': {'abominate'},
#              'aabiimnnoot': {'abomination'},
#              'aabimnoort': {'abominator'},
#              'abeimno': {'abomine'},
#              'abgnoo': {'abongo', 'gaboon'},
#              'abnoo': {'aboon'},
#              'aablor': {'aboral', 'arbalo'},
#              'aabllory': {'aborally'},
#              'abdor': {'abord', 'bardo', 'board', 'broad', 'dobra', 'dorab'},
#              'aabgiilnor': {'aboriginal'},
#              'aabgiiilnorty': {'aboriginality'},
#              'aabgiillnory': {'aboriginally'},
#              'aabgiinorry': {'aboriginary'},
#              'abegiinor': {'aborigine'},
#              'abort': {'abort', 'tabor'},
#              'abdeort': {'aborted'},
#              'abcdeiiort': {'aborticide', 'bacterioid'},
#              'abeinortt': {'abortient', 'torbanite'},
#              'aabcefiinortt': {'abortifacient'},
#              'abinort': {'abortin', 'taborin'},
#              'abinoort': {'abortion', 'robotian'},
#              'aabilnoort': {'abortional'},
#              'abiinoorstt': {'abortionist'},
#              'abeiortv': {'abortive', 'bravoite'},
#              'abeilortvy': {'abortively'},
#              'abeeinorsstv': {'abortiveness'},
#              'aborstu': {'abortus'},
#              'abceehmnotu': {'abouchement'},
#              'abdnou': {'abound'},
#              'abdenoru': {'abounder'},
#              'abdginnou': {'abounding'},
#              'abdgilnnouy': {'aboundingly'},
#              'abotu': {'about'},
#              'abostu': {'abouts', 'basuto'},
#              'abeov': {'above'},
#              'aabbdeoorv': {'aboveboard'},
#              'abcdeekov': {'abovedeck'},
#              'abdegnooruv': {'aboveground'},
#              'abefoooprv': {'aboveproof'},
#              'aabeiorsstv': {'abovestairs'},
#              'abox': {'abox'},
#              'aaaaabbcdrr': {'abracadabra'},
#              'aaabchir': {'abrachia'},
#              'aaabdnrt': {'abradant'},
#              'aabder': {'abrade'},
#              'aabderr': {'abrader'},
#              'aaabhmr': {'abraham'},
#              'aaabchimr': {'abrahamic'},
#              'aaaabdehimr': {'abrahamidae'},
#              'aaabehimrt': {'abrahamite'},
#              'aaabchiimrt': {'abrahamitic'},
#              'aabdir': {'abraid'},
#              'aabmr': {'abram', 'ambar'},
#              'aabimrs': {'abramis', 'arabism'},
#              'aaabchilnr': {'abranchial'},
#              'aaabchiilmnrs': {'abranchialism'},
#              'aaabchinnr': {'abranchian'},
#              'aaaabchinrt': {'abranchiata'},
#              'aaabcehinrt': {'abranchiate'},
#              'aabchinorsu': {'abranchious'},
#              'aaabrsx': {'abrasax', 'abraxas'},
#              'aabhrs': {'abrash'},
#              'aabeeimorrst': {'abrasiometer'},
#              'aabinors': {'abrasion', 'sorabian'},
#              'aabeirsv': {'abrasive'},
#              'aablorst': {'abrastol', 'albatros'},
#              'aabmru': {'abraum'},
#              'aabcert': {'abreact', 'bractea', 'cabaret'},
#              'aabceinort': {'abreaction'},
#              'aaberst': {'abreast'},
#              'abceennoru': {'abrenounce'},
#              'abert': {'abret', 'bater', 'berat'},
#              'abcior': {'abrico'},
#              'abdegir': {'abridge', 'brigade'},
#              'aabbdeegilr': {'abridgeable'},
#              'abddegir': {'abridged'},
#              'abddegilry': {'abridgedly'},
#              'abdegirr': {'abridger'},
#              'abdegimnrt': {'abridgment'},
#              'abimr': {'abrim', 'birma'},
#              'abinr': {'abrin', 'bairn', 'brain', 'brian', 'rabin'},
#              'abeilrst': {'abristle', 'libertas'},
#              'aabchor': {'abroach'},
#              'aabcmoor': {'abrocoma'},
#              'abcemoor': {'abrocome'},
#              'aabbeglor': {'abrogable'},
#              'aabegort': {'abrogate'},
#              'aabginoort': {'abrogation'},
#              'aabegiortv': {'abrogative'},
#              'aabgoorrt': {'abrogator'},
#              'aabmor': {'abroma'},
#              'aabinor': {'abronia'},
#              'abkoor': {'abrook'},
#              'aabmnortu': {'abrotanum'},
#              'abeinort': {'abrotine', 'baritone', 'obtainer', 'reobtain'},
#              'abprtu': {'abrupt'},
#              'abdelprtuy': {'abruptedly'},
#              'abinoprtu': {'abruption'},
#              'ablprtuy': {'abruptly'},
#              'abenprsstu': {'abruptness'},
#              'abrsu': {'abrus', 'bursa', 'subra'},
#              'aablmos': {'absalom', 'balsamo'},
#              'aabeemprs': {'absampere'},
#              'aaabkors': {'absaroka'},
#              'aabeikorst': {'absarokite'},
#              'abcesss': {'abscess'},
#              'abcdeesss': {'abscessed'},
#              'abceinosss': {'abscession'},
#              'abceoorssst': {'abscessroot'},
#              'abcdins': {'abscind'},
#              'abceiss': {'abscise', 'scabies'},
#              'abciinoss': {'abscision'},
#              'abcisss': {'absciss'},
#              'aabcisss': {'abscissa'},
#              'aabceisss': {'abscissae'},
#              'abceisss': {'abscisse'},
#              'abciinosss': {'abscission'},
#              'abccenos': {'absconce'},
#              'abcdnos': {'abscond'},
#              'abcddenos': {'absconded'},
#              'abcddelnosy': {'abscondedly'},
#              'abccdeennos': {'abscondence'},
#              'abcdenors': {'absconder'},
#              'aabcnoss': {'absconsa'},
#              'abbclmoosu': {'abscoulomb'},
#              'abceens': {'absence'},
#              'abenst': {'absent', 'basten'},
#              'aabeinnostt': {'absentation'},
#              'abeeenst': {'absentee'},
#              'abeeeimnsst': {'absenteeism'},
#              'abeeehinpsst': {'absenteeship'},
#              'abeenrst': {'absenter', 'reabsent'},
#              'abelnsty': {'absently'},
#              'abeemnnstt': {'absentment'},
#              'abddeeilmnnsty': {'absentmindedly'},
#              'abeennssst': {'absentness'},
#              'aaabdfrs': {'absfarad'},
#              'abehnrsy': {'abshenry'},
#              'abis': {'absi', 'bais', 'bias', 'isba'},
#              'abehinst': {'absinthe'},
#              'aabhiilnst': {'absinthial'},
#              'aabhiinnst': {'absinthian'},
#              'aabehiinstt': {'absinthiate'},
#              'abchiinst': {'absinthic'},
#              'abhiinnst': {'absinthin'},
#              'abehiinnst': {'absinthine'},
#              'abhiimnsst': {'absinthism'},
#              'abchiiimnsst': {'absinthismic'},
#              'abhiimnstu': {'absinthium'},
#              'abhilnost': {'absinthol'},
#              'abist': {'absit', 'batis'},
#              'abhmos': {'absmho', 'absohm'},
#              'abelostu': {'absolute'},
#              'abellostuy': {'absolutely'},
#              'abeelnossstu': {'absoluteness'},
#              'abilnoostu': {'absolution'},
#              'abilmosstu': {'absolutism'},
#              'abilossttu': {'absolutist'},
#              'abciilossttu': {'absolutistic'},
#              'aabciilllossttuy': {'absolutistically'},
#              'abeilostuv': {'absolutive'},
#              'aabiilnoosttuz': {'absolutization'},
#              'abeilostuz': {'absolutize'},
#              'abloorstuy': {'absolutory'},
#              'aabbellosv': {'absolvable'},
#              'aabloorstvy': {'absolvatory'},
#              'abelosv': {'absolve'},
#              'abelnostv': {'absolvent'},
#              'abelorsv': {'absolver'},
#              'abiloorstv': {'absolvitor'},
#              'abiloorstvy': {'absolvitory'},
#              'aabnnost': {'absonant'},
#              'abnoossu': {'absonous'},
#              'abbors': {'absorb'},
#              'aabbbiilorsty': {'absorbability'},
#              'aabbbelors': {'absorbable'},
#              'abbdeors': {'absorbed'},
#              'abbdelorsy': {'absorbedly'},
#              'abbdeenorsss': {'absorbedness'},
#              'aabbceefinorst': {'absorbefacient'},
#              'abbcenorsy': {'absorbency'},
#              'abbenorst': {'absorbent'},
#              'abbeorrs': {'absorber', 'reabsorb'},
#              'abbginors': {'absorbing'},
#              'abbgilnorsy': {'absorbingly'},
#              'abbiinoorst': {'absorbition'},
#              'aboprst': {'absorpt', 'barpost'},
#              'aabcenoprst': {'absorptance'},
#              'abeeimooprrstt': {'absorptiometer'},
#              'abceiimooprrstt': {'absorptiometric'},
#              'abinooprst': {'absorption'},
#              'abeioprstv': {'absorptive'},
#              'abeiloprstvy': {'absorptively'},
#              'abeeinoprssstv': {'absorptiveness'},
#              'abiioprsttvy': {'absorptivity'},
#              'aaabelqsttuu': {'absquatulate'},
#              'aabinst': {'abstain'},
#              'aabeinrst': {'abstainer'},
#              'aabeimnnstt': {'abstainment'},
#              'abeimosstu': {'abstemious'},
#              'abeilmosstuy': {'abstemiously'},
#              'abeeimnosssstu': {'abstemiousness'},
#              'abeinnostt': {'abstention'},
#              'abeiinnossttt': {'abstentionist'},
#              'abeinossttu': {'abstentious'},
#              'abeegrst': {'absterge'},
#              'abeegnrstt': {'abstergent'},
#              'abeinorsst': {'abstersion'},
#              'abeeirsstv': {'abstersive'},
#              'abeeeinrsssstv': {'abstersiveness'},
#              'abceeinnst': {'abstinence'},
#              'abceinnsty': {'abstinency'},
#              'abeinnstt': {'abstinent'},
#              'aabeiilnnstt': {'abstinential'},
#              'abeilnnstty': {'abstinently'},
#              'aabcrstt': {'abstract'},
#              'aabcderstt': {'abstracted'},
#              'aabcdelrstty': {'abstractedly'},
#              'aabcdeenrssstt': {'abstractedness'},
#              'aabcerrstt': {'abstracter'},
#              'aabcinorstt': {'abstraction'},
#              'aaabcilnorstt': {'abstractional'},
#              'aabciimnorsstt': {'abstractionism'},
#              'aabciinorssttt': {'abstractionist'},
#              'aabciiorsstttu': {'abstractitious'},
#              'aabceirsttv': {'abstractive'},
#              'aabceilrsttvy': {'abstractively'},
#              'aabceeinrsssttv': {'abstractiveness'},
#              'aabclrstty': {'abstractly'},
#              'aabcenrssstt': {'abstractness'},
#              'aabcorrstt': {'abstractor'},
#              'aabehnrstt': {'abstrahent'},
#              'abcdeirstt': {'abstricted'},
#              'abciinorstt': {'abstriction'},
#              'abersstu': {'abstruse'},
#              'abelrsstuy': {'abstrusely'},
#              'abeenrsssstu': {'abstruseness'},
#              'abinorsstu': {'abstrusion'},
#              'abirssttuy': {'abstrusity'},
#              'abemsu': {'absume'},
#              'abimnopstu': {'absumption'},
#              'abdrsu': {'absurd'},
#              'abdirstuy': {'absurdity'},
#              'abdlrsuy': {'absurdly'},
#              'abdenrsssu': {'absurdness'},
#              'ablostv': {'absvolt'},
#              'abrsstuy': {'absyrtus'},
#              'aabeilmnrt': {'abterminal'},
#              'aabhint': {'abthain', 'habitan'},
#              'aabehiinrt': {'abthainrie'},
#              'aabhinrty': {'abthainry'},
#              'aaabeghnt': {'abthanage'},
#              'abu': {'abu'},
#              'abccou': {'abucco'},
#              'aabilu': {'abulia'},
#              'abcilu': {'abulic', 'baculi'},
#              'aaabilmnou': {'abulomania'},
#              'aabnu': {'abuna'},
#              'aabcdennu': {'abundance'},
#              'aabcdnnuy': {'abundancy'},
#              'aabdnntu': {'abundant'},
#              'aaabdinntu': {'abundantia'},
#              'aabdlnntuy': {'abundantly'},
#              'aabru': {'abura'},
#              'aabboruuz': {'aburabozu'},
#              'aabbnru': {'aburban'},
#              'abrstu': {'aburst'},
#              'abnortu': {'aburton'},
#              'aabbelsu': {'abusable'},
#              'abesu': {'abuse'},
#              'abdelsuy': {'abusedly'},
#              'abeesu': {'abusee'},
#              'abeflsuu': {'abuseful'},
#              'abefllsuuy': {'abusefully'},
#              'abeeflnsssuu': {'abusefulness'},
#              'abersu': {'abuser'},
#              'abinosu': {'abusion'},
#              'abiossuu': {'abusious'},
#              'abeisuv': {'abusive'},
#              'abeilsuvy': {'abusively'},
#              'abeeinsssuv': {'abusiveness'},
#              'abtu': {'abut', 'tabu', 'tuba'},
#              'aabtu': {'abuta', 'bauta'},
#              'abemnttu': {'abutment'},
#              'aablttu': {'abuttal'},
#              'aberttu': {'abutter'},
#              'abginttu': {'abutting'},
#              'abuzz': {'abuzz'},
#              'ablotv': {'abvolt'},
#              'aabbw': {'abwab'},
#              'aby': {'aby', 'bay'},
#              'abmsy': {'abysm'},
#              'aablmsy': {'abysmal', 'balsamy'},
#              'aabllmsyy': {'abysmally'},
#              'abssy': {'abyss'},
#              'aablssy': {'abyssal'},
#              'aabiinnssy': {'abyssinian'},
#              'abbcehinnoossty': {'abyssobenthonic'},
#              'abhilossty': {'abyssolith'},
#              'aabcegilopssy': {'abyssopelagic'},
#              'aaacccehint': {'acacatechin'},
#              'aaacccehlot': {'acacatechol'},
#              'aacceint': {'acacetin'},
#              'aaacci': {'acacia'},
#              'aaaccin': {'acacian'},
#              'aacciin': {'acaciin'},
#              'aaccin': {'acacin'},
#              'aacdeem': {'academe'},
#              'aaacdeilm': {'academial'},
#              'aaacdeimn': {'academian'},
#              'aaccdeim': {'academic'},
#              'aaaccdeilm': {'academical'},
#              'aaaccdeillmy': {'academically'},
#              'aaaccdeilms': {'academicals'},
#              'aaaccdeiimn': {'academician'},
#              'aaccdeiimms': {'academicism'},
#              'aacdeimms': {'academism'},
#              'aacdeimst': {'academist'},
#              'aacdeeimt': {'academite', 'acetamide'},
#              'aaacdeiimnotz': {'academization'},
#              'aacdeeimz': {'academize'},
#              'aacdemsu': {'academus'},
#              'aacdemy': {'academy'},
#              'aaacdi': {'acadia'},
#              'aaacdeiilt': {'acadialite'},
#              'aaacdin': {'acadian'},
#              'aacdei': {'acadie', 'acedia', 'adicea'},
#              'aaacen': {'acaena'},
#              'aacjou': {'acajou'},
#              'aacehlp': {'acaleph', 'acephal'},
#              'aaacehlp': {'acalepha', 'acephala'},
#              'aaaceehlp': {'acalephae', 'apalachee'},
#              'aaacehlnp': {'acalephan', 'acephalan'},
#              'aacdehilop': {'acalephoid'},
#              'aaacclly': {'acalycal'},
#              'aacceilny': {'acalycine'},
#              'aaccilnosuy': {'acalycinous'},
#              'aaaccelltuy': {'acalyculate'},
#              'aaachlpy': {'acalypha'},
#              'aaaceelprty': {'acalypterae'},
#              'aaaaclprtty': {'acalyptrata'},
#              'aaaacelprtty': {'acalyptratae'},
#              'aaacelprtty': {'acalyptrate', 'calyptratae'},
#              'aaacmr': {'acamar', 'camara', 'maraca'},
#              'aaacimps': {'acampsia'},
#              'aaacn': {'acana'},
#              'aaaccenosu': {'acanaceous'},
#              'aaaccilnno': {'acanonical'},
#              'aachnt': {'acanth', 'anchat', 'tanach'},
#              'aaachnt': {'acantha'},
#              'aaaacceehnt': {'acanthaceae'},
#              'aaaccehnostu': {'acanthaceous'},
#              'aaacdhnt': {'acanthad'},
#              'aaaachinrt': {'acantharia'},
#              'aaachint': {'acanthia', 'achatina'},
#              'aaachilnt': {'acanthial', 'calathian'},
#              'aachinnt': {'acanthin', 'chinanta'},
#              'aacehinnt': {'acanthine'},
#              'aachinnot': {'acanthion'},
#              'aacehintt': {'acanthite'},
#              'aaacchnooprstu': {'acanthocarpous'},
#              'aaaaccehhlnopt': {'acanthocephala'},
#              'aaaaccehhlnnopt': {'acanthocephalan'},
#              'aaaccehhilnopt': {'acanthocephali'},
#              'aaaccehhlnoopstu': {'acanthocephalous'},
#              'aacceehnorstu': {'acanthocereus'},
#              'aaaccdhlnoostu': {'acanthocladous'},
#              'aaacdehnot': {'acanthodea'},
#              'aaacdehnnot': {'acanthodean'},
#              'aacdehinot': {'acanthodei'},
#              'aacdehnost': {'acanthodes'},
#              'aaacdhinnot': {'acanthodian'},
#              'aaacddehinot': {'acanthodidae'},
#              'aacdhiinot': {'acanthodii'},
#              'aacdhiinnot': {'acanthodini'},
#              'aacdhinot': {'acanthoid'},
#              'aachilmnnoot': {'acantholimon'},
#              'aaaccghillnoot': {'acanthological'},
#              'aacghlnooty': {'acanthology'},
#              'aachilnossty': {'acantholysis'},
#              'aaachmnot': {'acanthoma'},
#              'aaacdeehimnort': {'acanthomeridae'},
#              'aachnnot': {'acanthon'},
#              'aaaachnnoptx': {'acanthopanax'},
#              'aachhinopst': {'acanthophis'},
#              'aachhnoooprstu': {'acanthophorous'},
#              'aacdhnoopt': {'acanthopod'},
#              'aacdhnooopstu': {'acanthopodous'},
#              'aaachmnooopsttu': {'acanthopomatous'},
#              'aacehnooprt': {'acanthopore'},
#              'aaacehnnoprtt': {'acanthopteran'},
#              'aacehinoprtt': {'acanthopteri'},
#              'aacehnooprsttu': {'acanthopterous'},
#              'aaaceghinnoprtty': {'acanthopterygian'},
#              'aaceghiinoprtty': {'acanthopterygii'},
#              'aachinosst': {'acanthosis'},
#              'aachnostu': {'acanthous'},
#              'aaacdehinrtu': {'acanthuridae'},
#              'aachnrstuu': {'acanthurus'},
#              'aachnstu': {'acanthus'},
#              'aaacinp': {'acapnia'},
#              'aaacilnp': {'acapnial'},
#              'aaaclprsu': {'acapsular'},
#              'aacpu': {'acapu'},
#              'aacclopu': {'acapulco'},
#              'aaacr': {'acara', 'araca'},
#              'aaaciprs': {'acarapis'},
#              'aaacdir': {'acardia', 'acarida', 'arcadia'},
#              'aaaccdir': {'acardiac'},
#              'aacir': {'acari'},
#              'aaacinr': {'acarian', 'acarina', 'acrania'},
#              'aaaciirss': {'acariasis'},
#              'aaaccdiilr': {'acaricidal'},
#              'aaccdeiir': {'acaricide'},
#              'aacdir': {'acarid', 'cardia', 'carida'},
#              'aaacdeir': {'acaridea'},
#              'aaacdeinr': {'acaridean'},
#              'aaacdiimmortu': {'acaridomatium'},
#              'aacfimorr': {'acariform'},
#              'aaceinr': {'acarine', 'acraein', 'arecain'},
#              'aaciinorss': {'acarinosis'},
#              'aacccdeiimoru': {'acarocecidium'},
#              'aaacdeiimorrstt': {'acarodermatitis'},
#              'aacdior': {'acaroid'},
#              'aaclor': {'acarol'},
#              'aacgiloorst': {'acarologist'},
#              'aacgloory': {'acarology'},
#              'aachilooprsu': {'acarophilous'},
#              'aaabchioopr': {'acarophobia'},
#              'aaccioortx': {'acarotoxic'},
#              'aaceloprsu': {'acarpelous'},
#              'aacoprsu': {'acarpous'},
#              'aacrsu': {'acarus'},
#              'aacsstu': {'acastus', 'astacus'},
#              'aaaccceiltt': {'acatalectic'},
#              'aaaaceilpst': {'acatalepsia'},
#              'aaacelpsty': {'acatalepsy'},
#              'aaacceilptt': {'acataleptic'},
#              'aaaacccilltt': {'acatallactic'},
#              'aaaaacehimstt': {'acatamathesia'},
#              'aaaaachipst': {'acataphasia'},
#              'aaaciopsst': {'acataposis'},
#              'aaaaacisstt': {'acatastasia'},
#              'aaaaccisttt': {'acatastatic'},
#              'aacet': {'acate'},
#              'aaaccegilort': {'acategorical'},
#              'aacerty': {'acatery'},
#              'aaaachirst': {'acatharsia'},
#              'aaachrsty': {'acatharsy'},
#              'aacchilot': {'acatholic', 'chaotical'},
#              'aaacdlu': {'acaudal'},
#              'aaacdetu': {'acaudate', 'ecaudata'},
#              'aacceelnstu': {'acaulescent'},
#              'aaceilnu': {'acauline'},
#              'aacelosu': {'acaulose'},
#              'aaclosuu': {'acaulous'},
#              'aacc': {'acca', 'caca'},
#              'accdee': {'accede'},
#              'acccdeeen': {'accedence'},
#              'accdeer': {'acceder'},
#              'aabcceeellr': {'accelerable'},
#              'aaccdeelnor': {'accelerando'},
#              'aacceelnrt': {'accelerant'},
#              'aacceeelrt': {'accelerate'},
#              'aaccdeeelrt': {'accelerated'},
#              'aaccdeeellrty': {'acceleratedly'},
#              'aacceeilnort': {'acceleration'},
#              'aacceeeilrtv': {'accelerative'},
#              'aacceelorrt': {'accelerator', 'retrocaecal'},
#              'aacceelorrty': {'acceleratory'},
#              'aacceeghloprr': {'accelerograph'},
#              'acceeeelmorrt': {'accelerometer'},
#              'accden': {'accend'},
#              'abccdeiiilnty': {'accendibility'},
#              'abccdeeiln': {'accendible'},
#              'acceinnos': {'accension'},
#              'accenors': {'accensor'},
#              'accent': {'accent'},
#              'acceelnsst': {'accentless'},
#              'accenort': {'accentor'},
#              'aabcceelntu': {'accentuable'},
#              'aaccelntu': {'accentual'},
#              'aacceilnttuy': {'accentuality'},
#              'aaccellntuy': {'accentually'},
#              'aacceenttu': {'accentuate'},
#              'aacceinnottu': {'accentuation'},
#              'aaccenorttu': {'accentuator'},
#              'accenstu': {'accentus'},
#              'accept': {'accept'},
#              'aabcceiilptty': {'acceptability'},
#              'aabcceelpt': {'acceptable'},
#              'aabcceeelnpsst': {'acceptableness'},
#              'aabccelpty': {'acceptably'},
#              'aaccceenpt': {'acceptance'},
#              'aacccenpty': {'acceptancy'},
#              'aaccenptt': {'acceptant'},
#              'aacceinoptt': {'acceptation'},
#              'accdeept': {'accepted'},
#              'accdeelpty': {'acceptedly'},
#              'acceeprt': {'accepter'},
#              'aacceeilptt': {'acceptilate'},
#              'aacceiilnoptt': {'acceptilation'},
#              'acceinopt': {'acception', 'peccation'},
#              'acceeiptv': {'acceptive'},
#              'acceoprt': {'acceptor'},
#              'acceeprsst': {'acceptress'},
#              'acceers': {'accerse'},
#              'acceiinorst': {'accersition'},
#              'acceiorrst': {'accersitor'},
#              'access': {'access'},
#              'aacceilrssy': {'accessarily'},
#              'aacceeinrssss': {'accessariness'},
#              'aaccerssy': {'accessary'},
#              'aaccehiprsssy': {'accessaryship'},
#              'abcceiiilssty': {'accessibility'},
#              'abcceeilss': {'accessible'},
#              'abcceilssy': {'accessibly'},
#              'acceinoss': {'accession'},
#              'aacceilnoss': {'accessional'},
#              'acceeinorss': {'accessioner', 'reaccession'},
#              'acceeissv': {'accessive'},
#              'acceeilssvy': {'accessively'},
#              'acceelssss': {'accessless'},
#              'aacceilorss': {'accessorial'},
#              'acceilorssy': {'accessorily'},
#              'acceeinorssss': {'accessoriness'},
#              'acceiorsssu': {'accessorius'},
#              'acceorssy': {'accessory'},
#              'acccdeein': {'accidence'},
#              'acccdeiny': {'accidency'},
#              'accdeint': {'accident'},
#              'aaccdeilnt': {'accidental'},
#              'aaccdeiilmnst': {'accidentalism'},
#              'aaccdeiilnstt': {'accidentalist'},
#              'aaccdeiilntty': {'accidentality'},
#              'aaccdeillnty': {'accidentally'},
#              'aaccdeeilnnsst': {'accidentalness'},
#              'accddeeint': {'accidented'},
#              'aaccdeiilnt': {'accidential'},
#              'aaccdeiiilntty': {'accidentiality'},
#              'accdeilnty': {'accidently'},
#              'aaccdii': {'accidia'},
#              'accdeii': {'accidie'},
#              'accegin': {'accinge'},
#              'acceiinpt': {'accipient'},
#              'acceiiprt': {'accipiter'},
#              'aacciilprt': {'accipitral'},
#              'aacciiprrty': {'accipitrary'},
#              'acceiiprst': {'accipitres', 'preascitic'},
#              'acceiiinprt': {'accipitrine'},
#              'accimssu': {'accismus'},
#              'acceit': {'accite', 'acetic'},
#              'aaccilm': {'acclaim'},
#              'aaabcceillm': {'acclaimable'},
#              'aacceilmr': {'acclaimer'},
#              'aaaccilmnot': {'acclamation'},
#              'aaacclmort': {'acclamator'},
#              'aaacclmorty': {'acclamatory'},
#              'aaabcceillmt': {'acclimatable'},
#              'aaacciilmnott': {'acclimatation'},
#              'aacceilmt': {'acclimate'},
#              'aacceeilmmntt': {'acclimatement'},
#              'aacciilmnot': {'acclimation'},
#              'aaabcceiillmtz': {'acclimatizable'},
#              'aaacciiilmnottz': {'acclimatization'},
#              'aacceiilmtz': {'acclimatize'},
#              'aacceiilmrtz': {'acclimatizer'},
#              'aacceilmrtu': {'acclimature'},
#              'aaccilln': {'acclinal'},
#              'aacceilnt': {'acclinate', 'analectic'},
#              'acciilostuv': {'acclivitous'},
#              'acciiltvy': {'acclivity'},
#              'accilosuv': {'acclivous'},
#              'accloy': {'accloy'},
#              'aaccost': {'accoast'},
#              'accilo': {'accoil', 'calico'},
#              'aaccdelo': {'accolade'},
#              'aaccddelo': {'accoladed'},
#              'aaccdelot': {'accolated'},
#              'accelnot': {'accolent'},
#              'accello': {'accolle'},
#              'aabcciimnnoot': {'accombination'},
#              'aabccdelmmoo': {'accommodable'},
#              'aabccdeelmmnooss': {'accommodableness'},
#              'aaccdemmoot': {'accommodate'},
#              'aaccdelmmooty': {'accommodately'},
#              'aaccdeemmnoosst': {'accommodateness'},
#              'aaccdgimmnoot': {'accommodating'},
#              'aaccdgilmmnooty': {'accommodatingly'},
#              'aaccdimmnooot': {'accommodation'},
#              'aaaccdilmmnooot': {'accommodational'},
#              'aaccdeimmootv': {'accommodative'},
#              'aaccdeeimmnoosstv': {'accommodativeness'},
#              'aaccdmmooort': {'accommodator'},
#              'aacceimnopr': {'accompanier'},
#              'aacceimmnnopt': {'accompaniment'},
#              'aaacceilmmnnopt': {'accompanimental'},
#              'aaccimnopst': {'accompanist'},
#              'aaccmnopy': {'accompany'},
#              'aaccimnopsty': {'accompanyist'},
#              'acceeilmoptv': {'accompletive'},
#              'accceilmop': {'accomplice'},
#              'acccehiilmopps': {'accompliceship'},
#              'accciilmopty': {'accomplicity'},
#              'acchilmops': {'accomplish'},
#              'aabccehillmops': {'accomplishable'},
#              'accdehilmops': {'accomplished'},
#              'accehilmoprs': {'accomplisher', 'reaccomplish'},
#              'accehilmmnopst': {'accomplishment'},
#              'acchilmopst': {'accomplisht'},
#              'accmopt': {'accompt', 'compact'},
#              'accdor': {'accord'},
#              'aabccdelor': {'accordable'},
#              'aacccdenor': {'accordance'},
#              'aacccdnory': {'accordancy'},
#              'aaccdnort': {'accordant'},
#              'aaccdlnorty': {'accordantly'},
#              'accdeorr': {'accorder', 'reaccord'},
#              'accdginor': {'according'},
#              'accdgilnory': {'accordingly'},
#              'accdinoor': {'accordion'},
#              'accdiinoorst': {'accordionist'},
#              'aacceooprrt': {'accorporate'},
#              'aaccinoooprrt': {'accorporation'},
#              'accost': {'accost'},
#              'aabccelost': {'accostable'},
#              'accdeost': {'accosted'},
#              'acccehou': {'accouche'},
#              'accceehmnotu': {'accouchement'},
#              'acccehoruu': {'accoucheur'},
#              'accceehosuu': {'accoucheuse'},
#              'accnotu': {'account'},
#              ...})

# %%
anagramBySignature = {sig: wordset for sig, wordset in wordsBySignature.items() if len(wordset) > 1}

# %%
anagramBySignature
# Out:
# {'aal': {'aal', 'ala'},
#  'aam': {'aam', 'ama'},
#  'aacinor': {'aaronic', 'nicarao', 'ocarina'},
#  'aaeinort': {'aaronite', 'aeration'},
#  'aaru': {'aaru', 'aura'},
#  'ab': {'ab', 'ba'},
#  'aab': {'aba', 'baa'},
#  'aabc': {'abac', 'caba'},
#  'aabcort': {'abactor', 'acrobat'},
#  'aabft': {'abaft', 'bafta'},
#  'aabelno': {'abalone', 'balonea'},
#  'aabdennor': {'abandoner', 'reabandon'},
#  'aabcin': {'abanic', 'bianca'},
#  'aabirs': {'abaris', 'arabis'},
#  'aabs': {'abas', 'saba'},
#  'aabers': {'abaser', 'abrase'},
#  'aabet': {'abate', 'ateba', 'batea', 'beata'},
#  'aabert': {'abater', 'artabe', 'eartab', 'trabea'},
#  'abb': {'abb', 'bab'},
#  'aabb': {'abba', 'baba'},
#  'abbey': {'abbey', 'bebay'},
#  'abby': {'abby', 'baby'},
#  'aabdt': {'abdat', 'batad'},
#  'abdeil': {'abdiel', 'baldie'},
#  'aaabdgiilmnnoov': {'abdominovaginal', 'vaginoabdominal'},
#  'aabcdeiilmnoosv': {'abdominovesical', 'vesicoabdominal'},
#  'abe': {'abe', 'bae', 'bea'},
#  'abde': {'abed', 'bade', 'bead'},
#  'abel': {'abel', 'able', 'albe', 'bale', 'beal', 'bela', 'blae'},
#  'abeel': {'abele', 'albee'},
#  'aabeiln': {'abelian', 'nebalia'},
#  'abceeinrt': {'abenteric', 'bicrenate'},
#  'aabeir': {'aberia', 'baeria', 'baiera'},
#  'abet': {'abet', 'bate', 'beat', 'beta'},
#  'abeemntt': {'abetment', 'batement'},
#  'abeortt': {'abettor', 'taboret'},
#  'abehnorrt': {'abhorrent', 'earthborn'},
#  'abehorrr': {'abhorrer', 'harborer'},
#  'abdeir': {'abider', 'bardie'},
#  'abeis': {'abies', 'beisa'},
#  'aabill': {'abilla', 'labial'},
#  'abilo': {'abilo', 'aboil'},
#  'abir': {'abir', 'bari', 'rabi'},
#  'abinost': {'abiston', 'bastion'},
#  'abeirtu': {'abiuret', 'aubrite', 'biurate', 'rubiate'},
#  'aabkr': {'abkar', 'arkab'},
#  'aabhks': {'abkhas', 'kasbah'},
#  'aaabceltt': {'ablactate', 'cabaletta'},
#  'aabelr': {'ablare', 'arable', 'arbela'},
#  'aabceilmst': {'ablastemic', 'masticable'},
#  'aabilnot': {'ablation', 'obtainal'},
#  'aabltu': {'ablaut', 'tabula'},
#  'abeelnss': {'ableness', 'blaeness', 'sensable'},
#  'aabeilps': {'ablepsia', 'epibasal'},
#  'abelr': {'abler', 'baler', 'belar', 'blare', 'blear'},
#  'abelst': {'ablest', 'stable', 'tables'},
#  'ablmoo': {'abloom', 'mabolo'},
#  'ablow': {'ablow', 'balow', 'bowla'},
#  'abdelu': {'ablude', 'belaud'},
#  'abelntu': {'abluent', 'tunable'},
#  'abilnotu': {'ablution', 'abutilon'},
#  'ably': {'ably', 'blay', 'yalb'},
#  'abhmo': {'abmho', 'abohm'},
#  'abenr': {'abner', 'arneb', 'reban'},
#  'abent': {'abnet', 'beant'},
#  'abo': {'abo', 'boa'},
#  'aabdor': {'aboard', 'aborad', 'abroad'},
#  'abdeo': {'abode', 'adobe'},
#  'abehilors': {'abolisher', 'reabolish'},
#  'abgnoo': {'abongo', 'gaboon'},
#  'aablor': {'aboral', 'arbalo'},
#  'abdor': {'abord', 'bardo', 'board', 'broad', 'dobra', 'dorab'},
#  'abort': {'abort', 'tabor'},
#  'abcdeiiort': {'aborticide', 'bacterioid'},
#  'abeinortt': {'abortient', 'torbanite'},
#  'abinort': {'abortin', 'taborin'},
#  'abinoort': {'abortion', 'robotian'},
#  'abeiortv': {'abortive', 'bravoite'},
#  'abostu': {'abouts', 'basuto'},
#  'aabmr': {'abram', 'ambar'},
#  'aabimrs': {'abramis', 'arabism'},
#  'aaabrsx': {'abrasax', 'abraxas'},
#  'aabinors': {'abrasion', 'sorabian'},
#  'aablorst': {'abrastol', 'albatros'},
#  'aabcert': {'abreact', 'bractea', 'cabaret'},
#  'abert': {'abret', 'bater', 'berat'},
#  'abdegir': {'abridge', 'brigade'},
#  'abimr': {'abrim', 'birma'},
#  'abinr': {'abrin', 'bairn', 'brain', 'brian', 'rabin'},
#  'abeilrst': {'abristle', 'libertas'},
#  'abeinort': {'abrotine', 'baritone', 'obtainer', 'reobtain'},
#  'abrsu': {'abrus', 'bursa', 'subra'},
#  'aablmos': {'absalom', 'balsamo'},
#  'abceiss': {'abscise', 'scabies'},
#  'abenst': {'absent', 'basten'},
#  'abeenrst': {'absenter', 'reabsent'},
#  'abis': {'absi', 'bais', 'bias', 'isba'},
#  'abist': {'absit', 'batis'},
#  'abhmos': {'absmho', 'absohm'},
#  'abbeorrs': {'absorber', 'reabsorb'},
#  'aboprst': {'absorpt', 'barpost'},
#  'aabhint': {'abthain', 'habitan'},
#  'abcilu': {'abulic', 'baculi'},
#  'abtu': {'abut', 'tabu', 'tuba'},
#  'aabtu': {'abuta', 'bauta'},
#  'aby': {'aby', 'bay'},
#  'aablmsy': {'abysmal', 'balsamy'},
#  'aacdeeimt': {'academite', 'acetamide'},
#  'aacdei': {'acadie', 'acedia', 'adicea'},
#  'aacehlp': {'acaleph', 'acephal'},
#  'aaacehlp': {'acalepha', 'acephala'},
#  'aaaceehlp': {'acalephae', 'apalachee'},
#  'aaacehlnp': {'acalephan', 'acephalan'},
#  'aaacelprtty': {'acalyptrate', 'calyptratae'},
#  'aaacmr': {'acamar', 'camara', 'maraca'},
#  'aachnt': {'acanth', 'anchat', 'tanach'},
#  'aaachint': {'acanthia', 'achatina'},
#  'aaachilnt': {'acanthial', 'calathian'},
#  'aachinnt': {'acanthin', 'chinanta'},
#  'aaacr': {'acara', 'araca'},
#  'aaacdir': {'acardia', 'acarida', 'arcadia'},
#  'aaacinr': {'acarian', 'acarina', 'acrania'},
#  'aacdir': {'acarid', 'cardia', 'carida'},
#  'aaceinr': {'acarine', 'acraein', 'arecain'},
#  'aacsstu': {'acastus', 'astacus'},
#  'aacchilot': {'acatholic', 'chaotical'},
#  'aaacdetu': {'acaudate', 'ecaudata'},
#  'aacc': {'acca', 'caca'},
#  'aacceelorrt': {'accelerator', 'retrocaecal'},
#  'acceinopt': {'acception', 'peccation'},
#  'acceeinorss': {'accessioner', 'reaccession'},
#  'acceiiprst': {'accipitres', 'preascitic'},
#  'acceit': {'accite', 'acetic'},
#  'aacceilnt': {'acclinate', 'analectic'},
#  'accilo': {'accoil', 'calico'},
#  'accehilmoprs': {'accomplisher', 'reaccomplish'},
#  'accmopt': {'accompt', 'compact'},
#  'accdeorr': {'accorder', 'reaccord'},
#  'accoy': {'accoy', 'ccoya'},
#  'acceinort': {'accretion', 'anorectic', 'neoarctic'},
#  'aacclru': {'accrual', 'carucal'},
#  'aaccertu': {'accurate', 'carucate'},
#  'accersu': {'accurse', 'accuser'},
#  'aabccelsu': {'accusable', 'subcaecal'},
#  'accdesu': {'accused', 'succade'},
#  'acdey': {'acedy', 'decay'},
#  'acceinrt': {'acentric', 'encratic', 'nearctic'},
#  'acenorstu': {'acentrous', 'courtesan', 'nectarous'},
#  'aacehilp': {'acephali', 'phacelia'},
#  'aaacehilnp': {'acephalina', 'phalaecian'},
#  'acer': {'acer', 'acre', 'care', 'crea', 'race'},
#  'aaacceeer': {'aceraceae', 'arecaceae'},
#  'aacceeorsu': {'aceraceous', 'arecaceous'},
#  'abcer': {'acerb', 'brace', 'caber'},
#  'abcceir': {'acerbic', 'breccia'},
#  'acdelor': {'acerdol', 'coraled'},
#  'aceinr': {'acerin', 'cearin'},
#  'aceorsu': {'acerous', 'carouse', 'euscaro'},
#  'aaceertv': {'acervate', 'revacate'},
#  'aaceinortv': {'acervation', 'vacationer'},
#  'aceeilnruv': {'acervuline', 'avirulence'},
#  'aacdeimot': {'acetamido', 'coadamite'},
#  'aacdeiilnt': {'acetanilid', 'laciniated', 'teniacidal'},
#  'aaceinnot': {'acetanion', 'antoecian'},
#  'aaceinott': {'acetation', 'itaconate'},
#  'aceint': {'acetin', 'actine', 'enatic'},
#  'aacdeeehiillmntty': {'acetmethylanilide', 'methylacetanilide'},
#  'aceinot': {'acetoin', 'aconite', 'anoetic', 'antoeci', 'cetonia'},
#  'acelot': {'acetol', 'colate', 'locate'},
#  'aceenot': {'acetone', 'oceanet'},
#  'aaceinortu': {'acetonuria', 'aeronautic'},
#  'aceinoprty': {'acetopyrin', 'capernoity'},
#  'aceostu': {'acetous', 'outcase'},
#  'acemtu': {'acetum', 'tecuma'},
#  'acceirtu': {'aceturic', 'cruciate'},
#  'ach': {'ach', 'cha'},
#  'aachr': {'achar', 'chara'},
#  'aaceht': {'achate', 'chaeta'},
#  'aceh': {'ache', 'each', 'haec'},
#  'acehirsu': {'acheirus', 'eucharis'},
#  'acehn': {'achen', 'chane', 'chena', 'hance'},
#  'acehr': {'acher', 'arche', 'chare', 'chera', 'rache', 'reach'},
#  'accehinort': {'acherontic', 'anchoretic'},
#  'aaccehilnort': {'acherontical', 'anchoretical'},
#  'aceeht': {'achete', 'hecate', 'teache', 'thecae'},
#  'aaceehlnu': {'acheulean', 'euchlaena'},
#  'achill': {'achill', 'cahill', 'chilla'},
#  'aacehill': {'achillea', 'heliacal'},
#  'aachilo': {'acholia', 'alochia'},
#  'acdehinort': {'achondrite', 'ditrochean', 'ordanchite'},
#  'achor': {'achor', 'chora', 'corah', 'orach', 'roach'},
#  'aachrs': {'achras', 'charas'},
#  'aachmort': {'achromat', 'trachoma'},
#  'aachimnort': {'achromatin', 'chariotman', 'machinator'},
#  'aacchiimnort': {'achromatinic', 'chromatician'},
#  'acehlt': {'achtel', 'chalet', 'thecal', 'thecla'},
#  'achy': {'achy', 'chay'},
#  'aaccdeiltu': {'aciculated', 'claudicate'},
#  'acdi': {'acid', 'cadi', 'caid'},
#  'aaacdehinrt': {'acidanthera', 'cantharidae'},
#  'acdeir': {'acider', 'ericad'},
#  'acdeeiimrt': {'acidimeter', 'mediatrice'},
#  'acdiity': {'acidity', 'adicity'},
#  'acdily': {'acidly', 'acidyl'},
#  'acdeimorty': {'acidometry', 'medicatory', 'radiectomy'},
#  'acdhiiloopsu': {'acidophilous', 'aphidicolous'},
#  'aceir': {'acier', 'aeric', 'ceria', 'erica'},
#  'aaceilr': {'acieral', 'aerical'},
#  'acfimor': {'aciform', 'formica'},
#  'aciilsu': {'acilius', 'iliacus'},
#  'aacinr': {'acinar',
#   'arnica',
#   'canari',
#   'carian',
#   'carina',
#   'crania',
#   'narica'},
#  'acciin': {'acinic', 'incaic'},
#  'acfiimnor': {'aciniform', 'formicina'},
#  'acdeeiinprs': {'acipenserid', 'presidencia'},
#  'acis': {'acis', 'asci', 'saic'},
#  'acekr': {'acker', 'caker', 'crake', 'creak'},
#  'aceky': {'ackey', 'cakey'},
#  'acel': {'acle', 'alec', 'lace'},
#  'aceilosstu': {'acleistous', 'ossiculate'},
#  'acelmno': {'aclemon', 'cloamen'},
#  'aacilln': {'aclinal', 'ancilla'},
#  'aclsy': {'aclys', 'scaly'},
#  'acem': {'acme', 'came', 'mace'},
#  'aceimt': {'acmite', 'micate'},
#  'acen': {'acne', 'cane', 'nace'},
#  'aaceimn': {'acnemia', 'anaemic'},
#  'aacdin': {'acnida', 'anacid', 'dacian'},
#  'aacdlno': {'acnodal', 'canadol', 'locanda'},
#  'acdeno': {'acnode', 'deacon'},
#  'acino': {'acoin', 'oncia'},
#  'aacmo': {'acoma', 'macao'},
#  'aceno': {'acone', 'canoe', 'ocean'},
#  'aacilnot': {'aconital', 'actional', 'anatolic'},
#  'acciinot': {'aconitic', 'cationic', 'itaconic'},
#  'aciinnot': {'aconitin', 'inaction', 'nicotian'},
#  'acimnotu': {'aconitum', 'acontium'},
#  'aacinost': {'acontias', 'tacsonia'},
#  'acinostu': {'acontius', 'anticous'},
#  'acnoop': {'acopon', 'poonac'},
#  'acor': {'acor', 'caro', 'cora', 'orca'},
#  'acnor': {'acorn', 'acron', 'racon'},
#  'acorsu': {'acorus', 'soucar'},
#  'acimosst': {'acosmist', 'massicot', 'somatics'},
#  'aceqstu': {'acquest', 'casquet'},
#  'aabcr': {'acrab', 'braca'},
#  'aaaceinrt': {'acraniate', 'carinatae'},
#  'aaacirt': {'acratia', 'cataria'},
#  'aacemr': {'acream', 'camera', 'mareca'},
#  'acder': {'acred', 'cader', 'cadre', 'cedar'},
#  'acdir': {'acrid', 'caird', 'carid', 'darci', 'daric', 'dirca'},
#  'aacdinr': {'acridan', 'craniad'},
#  'aacdiinr': {'acridian', 'cnidaria'},
#  'aacddeiir': {'acrididae', 'cardiidae', 'cidaridae'},
#  'acdilry': {'acridly', 'acridyl'},
#  'acdiimnoru': {'acridonium', 'dicoumarin'},
#  'aciimnoorsu': {'acrimonious', 'isocoumarin'},
#  'aciirssu': {'acrisius', 'sicarius'},
#  'aacirt': {'acrita', 'arctia'},
#  'aacinrt': {'acritan', 'arctian'},
#  'aceirt': {'acrite', 'arcite', 'tercia', 'triace', 'tricae'},
#  'aacor': {'acroa', 'caroa'},
#  'aacceorr': {'acrocera', 'caracore'},
#  'acciilmnoru': {'acroclinium', 'alcicornium'},
#  'acdorsu': {'acrodus', 'crusado'},
#  'acegnor': {'acrogen', 'cornage'},
#  'aceilnor': {'acrolein',
#   'arecolin',
#   'caroline',
#   'colinear',
#   'cornelia',
#   'creolian',
#   'lonicera'},
#  'achilort': {'acrolith', 'trochila'},
#  'aaccilnor': {'acronical', 'alcoranic'},
#  'acmnory': {'acronym', 'romancy'},
#  'aaceloprt': {'acropetal', 'cleopatra'},
#  'aceors': {'acrose', 'coarse'},
#  'acciorst': {'acrostic', 'sarcotic', 'socratic'},
#  'aaccilorst': {'acrostical', 'socratical'},
#  'aaccillorsty': {'acrostically', 'socratically'},
#  'acciimorsst': {'acrosticism', 'socraticism'},
#  'acciort': {'acrotic', 'carotic'},
#  'acimorst': {'acrotism', 'rotacism'},
#  'acchiooprrt': {'acrotrophic', 'prothoracic'},
#  'aclry': {'acryl', 'caryl', 'clary'},
#  'act': {'act', 'cat'},
#  'aaacdeeinot': {'actaeonidae', 'donatiaceae'},
#  'aacint': {'actian', 'natica', 'tanica'},
#  'acefiirt': {'actifier', 'artifice'},
#  'acint': {'actin', 'antic'},
#  'aacilnt': {'actinal', 'alantic', 'alicant', 'antical'},
#  'acfiimnort': {'actiniform', 'naticiform'},
#  'aceiinnt': {'actinine', 'naticine'},
#  'aciimnst': {'actinism', 'manistic'},
#  'aacgimnort': {'actinogram', 'morganatic'},
#  'acdiinot': {'actinoid', 'diatonic', 'naticoid'},
#  'acinnot': {'actinon', 'cantion', 'contain'},
#  'aaceinnoprtt': {'actinopteran', 'precantation'},
#  'aceiinoprtt': {'actinopteri', 'crepitation', 'precitation'},
#  'acinostt': {'actinost', 'oscitant'},
#  'aacilntu': {'actinula', 'nautical'},
#  'acinot': {'action', 'atonic', 'cation'},
#  'aceinort': {'actioner', 'anerotic', 'ceration', 'creation', 'reaction'},
#  'aabceiltv': {'activable', 'biclavate'},
#  'aaceittv': {'activate', 'cavitate'},
#  'aaciinottv': {'activation', 'cavitation'},
#  'aciintv': {'activin', 'civitan'},
#  'acimnoosty': {'actomyosin', 'inocystoma'},
#  'acnot': {'acton', 'canto', 'octan'},
#  'acort': {'actor', 'corta', 'croat', 'rocta', 'taroc', 'troca'},
#  'achioprst': {'actorship', 'strophaic'},
#  'acst': {'acts', 'cast', 'scat'},
#  'aacorttu': {'actuator', 'autocrat'},
#  'acertu': {'acture', 'cauter', 'curate'},
#  'aacnu': {'acuan', 'aucan'},
#  'abcensu': {'acubens', 'benacus'},
#  'acemnu': {'acumen', 'cueman'},
#  'aceimnosu': {'acuminose', 'mniaceous'},
#  'aaccelmntuuu': {'acutenaculum', 'unaccumulate'},
#  'aceensstu': {'acuteness', 'encaustes'},
#  'acinoorstu': {'acutorsion', 'octonarius'},
#  'acly': {'acyl', 'clay', 'lacy'},
#  'aacilnoty': {'acylation', 'claytonia'},
#  'aceglnoy': {'acylogen', 'cynogale'},
#  'ad': {'ad', 'da'},
#  'aadd': {'adad', 'adda', 'dada'},
#  'aadeg': {'adage', 'agade'},
#  'aadm': {'adam', 'dama'},
#  'aacdim': {'adamic', 'cadmia'},
#  'aadeimn': {'adamine', 'manidae'},
#  'aadeimt': {'adamite', 'amidate'},
#  'aadeimst': {'adamsite', 'diastema'},
#  'aacden': {'adance', 'ecanda'},
#  'aadeprt': {'adapter', 'predata', 'readapt'},
#  'aadinopt': {'adaption', 'adoptian'},
#  'aadiimnopst': {'adaptionism', 'adoptianism'},
#  'aadr': {'adar', 'arad', 'raad', 'rada'},
#  'aademr': {'adarme', 'adream'},
#  'aadt': {'adat', 'data'},
#  'aadnw': {'adawn', 'wadna'},
#  'aadsy': {'adays', 'dasya'},
#  'add': {'add', 'dad'},
#  'adddemnu': {'addendum', 'unmadded'},
#  'adder': {'adder', 'dread', 'readd'},
#  'acddeint': {'addicent', 'dedicant'},
#  'addgilns': {'addlings', 'saddling'},
#  'addeerrss': {'addresser', 'readdress'},
#  'addu': {'addu', 'dadu', 'daud', 'duad'},
#  'addy': {'addy', 'dyad'},
#  'ade': {'ade', 'dae'},
#  'adeem': {'adeem', 'ameed', 'edema'},
#  'aadel': {'adela', 'dalea'},
#  'adeeiln': {'adeline', 'daniele', 'delaine'},
#  'adegiln': {'adeling', 'dealing', 'leading'},
#  'adelops': {'adelops', 'deposal'},
#  'adeimnost': {'ademonist', 'demoniast', 'staminode'},
#  'adeimnopt': {'ademption', 'tampioned'},
#  'acddeinr': {'adendric', 'riddance'},
#  'accdeeinopt': {'adenectopic', 'pentadecoic'},
#  'aadein': {'adenia', 'idaean'},
#  'aacddehmnnooor': {'adenochondroma', 'chondroadenoma'},
#  'aacdemnoosty': {'adenocystoma', 'cystoadenoma'},
#  'aabdefimnoor': {'adenofibroma', 'fibroadenoma'},
#  'aadeilmnoop': {'adenolipoma', 'palaemonoid'},
#  'aaacdemnoors': {'adenosarcoma', 'sarcoadenoma'},
#  'acdeilny': {'adenylic', 'lycaenid'},
#  'adeenpsst': {'adeptness', 'pedantess'},
#  'aadeinoqtu': {'adequation', 'deaquation'},
#  'aadeimr': {'adermia', 'madeira'},
#  'adeimnr': {'adermin', 'amerind', 'dimeran'},
#  'adet': {'adet', 'date', 'tade', 'tead', 'teda'},
#  'adeimsv': {'adevism', 'vedaism'},
#  'adeehr': {'adhere', 'header', 'hedera', 'rehead'},
#  'adeehnrt': {'adherent', 'headrent', 'neatherd', 'threaden'},
#  'aadhinop': {'adiaphon', 'aphodian'},
#  'abdi': {'adib', 'ibad'},
#  'adeil': {'adiel', 'delia', 'ideal'},
#  'adeiux': {'adieux', 'exaudi'},
#  'adeghi': {'adighe', 'hidage'},
#  'adin': {'adin', 'andi', 'dain', 'dani', 'dian', 'naid'},
#  'adeilno': {'adinole', 'idoneal'},
#  'adino': {'adion', 'danio', 'doina', 'donia'},
#  'acdeeilop': {'adipocele', 'cepolidae', 'ploceidae'},
#  'acdeeiopr': {'adipocere', 'percoidea'},
#  'adilpy': {'adipyl', 'plaidy'},
#  'adit': {'adit', 'dita'},
#  'aadilt': {'adital', 'altaid'},
#  'adistu': {'aditus', 'studia'},
#  'adejrstu': {'adjuster', 'readjust'},
#  'aadil': {'adlai', 'alida'},
#  'aadly': {'adlay', 'dayal'},
#  'adelt': {'adlet', 'dealt', 'delta', 'lated', 'taled'},
#  'adeilmnu': {'adlumine', 'unmailed'},
#  'aadmn': {'adman', 'daman', 'namda'},
#  'adim': {'admi', 'amid', 'madi', 'maid'},
#  'acdeiilmn': {'adminicle', 'medicinal'},
#  'adeimr': {'admire', 'armied', 'damier', 'dimera', 'merida'},
#  'addeimr': {'admired', 'diaderm'},
#  'adeimrr': {'admirer', 'madrier', 'married'},
#  'adeiimssv': {'admissive', 'misadvise'},
#  'adimt': {'admit', 'atmid'},
#  'adeeimtt': {'admittee', 'meditate'},
#  'adehimnors': {'admonisher', 'rhamnoside'},
#  'adiimnnoot': {'admonition', 'domination'},
#  'adeiimnotv': {'admonitive', 'dominative'},
#  'adimnoort': {'admonitor', 'dominator'},
#  'aaccdeenns': {'adnascence', 'ascendance'},
#  'aacdennst': {'adnascent', 'ascendant'},
#  'aadent': {'adnate', 'entada'},
#  'ado': {'ado', 'dao', 'oda'},
#  'adhlop': {'adolph', 'pholad'},
#  'aadino': {'adonai', 'adonia'},
#  'acdino': {'adonic', 'anodic'},
#  'adinno': {'adonin', 'nanoid', 'nonaid'},
#  'aadimnor': {'adoniram', 'radioman'},
#  'adeinoz': {'adonize', 'anodize'},
#  'adeoprt': {'adopter', 'protead', 'readopt'},
#  'aadilnoopt': {'adoptional', 'aplodontia'},
#  'aabdiilorty': {'adorability', 'roadability'},
#  'aabdelor': {'adorable', 'roadable'},
#  'aadnort': {'adorant', 'ondatra'},
#  'adeor': {'adore', 'oared', 'oread'},
#  'adeorr': {'adorer', 'roader'},
#  'adnor': {'adorn', 'donar', 'drona', 'radon'},
#  'adenorr': {'adorner', 'readorn'},
#  'aadop': {'adpao', 'apoda'},
#  'adiimnooprss': {'adpromission', 'proadmission'},
#  'adeinnr': {'adrenin', 'nardine'},
#  'adeeinnr': {'adrenine', 'adrienne'},
#  'acdeilnorty': {'adrenolytic', 'declinatory'},
#  'acdeinooprrt': {'adrenotropic', 'incorporated'},
#  'aadinr': {'adrian', 'andira', 'andria', 'radian', 'randia'},
#  'adipr': {'adrip', 'rapid'},
#  'adilorty': {'adroitly', 'dilatory', 'idolatry'},
#  'adopr': {'adrop', 'pardo'},
#  'adry': {'adry', 'dray', 'yard'},
#  'acddeennst': {'adscendent', 'descendant'},
#  'adhimst': {'adsmith', 'mahdist'},
#  'aadlru': {'adular', 'aludra', 'radula'},
#  'aadilnotu': {'adulation', 'laudation'},
#  'aadlortu': {'adulator', 'laudator'},
#  'aadlortuy': {'adulatory', 'laudatory'},
#  'adltu': {'adult', 'dulat'},
#  'adeeilnrtu': {'adulterine', 'laurentide'},
#  'adelnsstu': {'adultness', 'dauntless'},
#  'adinostu': {'adustion', 'sudation'},
#  'adeenv': {'advene', 'evadne'},
#  'adeimnstv': {'adventism', 'vedantism'},
#  'adeinsttv': {'adventist', 'vedantist'},
#  'adeenrtuv': {'adventure', 'unaverted'},
#  'acdeiv': {'advice', 'vedaic'},
#  'ady': {'ady', 'day', 'yad'},
#  'adz': {'adz', 'zad'},
#  'adez': {'adze', 'daze'},
#  'aderz': {'adzer', 'zerda'},
#  'ae': {'ae', 'ea'},
#  'acdefiimoor': {'aecidioform', 'formicoidea'},
#  'aadeiiln': {'aedilian', 'laniidae'},
#  'acdeiil': {'aedilic', 'elaidic'},
#  'adeiilty': {'aedility', 'ideality'},
#  'aaeginp': {'aegipan', 'apinage'},
#  'aeegiinr': {'aegirine', 'erigenia'},
#  'aeegiirt': {'aegirite', 'ariegite'},
#  'aeegl': {'aegle', 'eagle', 'galee'},
#  'aaeenn': {'aenean', 'enaena'},
#  'aaacehilmnoor': {'aeolharmonica', 'chloroanaemia'},
#  'aaeilno': {'aeolian', 'aeolina', 'aeonial'},
#  'aceilo': {'aeolic', 'coelia'},
#  'aeilos': {'aeolis', 'laiose'},
#  'aeilost': {'aeolist', 'isolate'},
#  'aceiilost': {'aeolistic', 'socialite'},
#  'aeno': {'aeon', 'eoan'},
#  'aeinost': {'aeonist', 'asiento', 'satieno'},
#  'aer': {'aer', 'are', 'ear', 'era', 'rea'},
#  'aaeegr': {'aerage', 'graeae'},
#  'aaaeinrr': {'aerarian', 'arenaria'},
#  'aaeilr': {'aerial', 'aralie'},
#  'adeeir': {'aeried', 'dearie'},
#  'aceeginor': {'aerogenic', 'recoinage'},
#  'aaeeghoprrr': {'aerographer', 'areographer'},
#  'aaceghioprr': {'aerographic', 'areographic'},
#  'aaaceghiloprr': {'aerographical', 'areographical'},
#  'aaeghoprry': {'aerography', 'areography'},
#  'acegiloor': {'aerologic', 'areologic'},
#  'aacegilloor': {'aerological', 'areological'},
#  'aegiloorst': {'aerologist', 'areologist'},
#  'aegloory': {'aerology', 'areology'},
#  'aaceimnort': {'aeromantic', 'cameration', 'maceration', 'racemation'},
#  'aeeemorrt': {'aerometer', 'areometer'},
#  'aceeimorrt': {'aerometric', 'areometric'},
#  'aeemorrty': {'aerometry', 'areometry'},
#  'aaeimnorstu': {'aeronautism', 'measuration'},
#  'aeeopr': {'aerope', 'operae'},
#  'acehiilopr': {'aerophilic', 'epichorial'},
#  'aeloors': {'aerosol', 'roseola'},
#  'aaceiorsstt': {'aerostatics', 'aortectasis'},
#  'aery': {'aery', 'eyra', 'yare', 'year'},
#  'aes': {'aes', 'ase', 'sea'},
#  'aceehistt': {'aesthetic', 'chaetites'},
#  'aadehiilot': {'aethalioid', 'haliotidae'},
#  'aaeint': {'aetian', 'antiae', 'taenia'},
#  'aabeosttu': {'aetobatus', 'eastabout'},
#  'abeefilr': {'afebrile', 'balefire', 'fireable'},
#  'aefiln': {'afenil', 'finale'},
#  'aaffir': {'affair', 'raffia'},
#  'aceeffrt': {'affecter', 'reaffect'},
#  'aeeffr': {'affeer', 'raffee'},
#  'aaceffin': {'affiance', 'caffeina'},
#  'aeffimrr': {'affirmer', 'reaffirm'},
#  'aceffilrt': {'afflicter', 'reafflict'},
#  'affy': {'affy', 'yaff'},
#  'aafghn': {'afghan', 'hafgan'},
#  'adefil': {'afield', 'defial'},
#  'aefir': {'afire', 'feria'},
#  'aaeflr': {'aflare', 'rafael'},
#  'aaflt': {'aflat', 'fatal'},
#  'aefhrs': {'afresh', 'fasher', 'ferash'},
#  'aefrt': {'afret', 'after'},
#  'acfir': {'afric', 'firca'},
#  'aafhrs': {'afshar', 'ashraf'},
#  'aft': {'aft', 'fat'},
#  'aacefrtt': {'afteract', 'artefact', 'farcetta', 'farctate'},
#  'aaeefgrt': {'afterage', 'fregatae'},
#  'abeflortw': {'afterblow', 'batfowler'},
#  'aceefmort': {'aftercome', 'forcemeat'},
#  'acefoprrt': {'aftercrop', 'prefactor'},
#  'aefgort': {'aftergo', 'fagoter'},
#  'aefgnrstu': {'afterguns', 'transfuge'},
#  'aaefhmrtt': {'aftermath', 'hamfatter'},
#  'aaeefrsttt': {'afterstate', 'aftertaste'},
#  'aacfilnnotu': {'afunctional', 'unfactional'},
#  'aagl': {'agal', 'agla', 'alga', 'gala'},
#  'aaegilt': {'agalite', 'tailage', 'taliage'},
#  'aaaglm': {'agalma', 'malaga'},
#  'aaagm': {'agama', 'amaga'},
#  'aadgim': {'agamid', 'madiga'},
#  'aaegipt': {'agapeti', 'agpaite'},
#  'aaginoprs': {'agapornis', 'sporangia'},
#  'aagr': {'agar', 'agra', 'gara', 'raga'},
#  'aacgiinr': {'agaricin', 'garcinia'},
#  'aagu': {'agau', 'agua'},
#  'adeg': {'aged', 'egad', 'gade'},
#  'aeeglss': {'ageless', 'eagless'},
#  'aegn': {'agen', 'gaen', 'gane', 'gean', 'gena'},
#  'aceegins': {'agenesic', 'genesiac'},
#  'aeeginss': {'agenesis', 'assignee'},
#  'aaegilnt': {'agential', 'alginate'},
#  'aeegintv': {'agentive', 'negative'},
#  'aegr': {'ager', 'agre', 'gare', 'gear', 'rage'},
#  'aeggr': {'agger', 'gager', 'regga'},
#  'aaegginort': {'aggeration', 'agregation'},
#  'aggry': {'aggry', 'raggy'},
#  'aadgiil': {'agialid', 'galidia'},
#  'abgi': {'agib', 'biga', 'gabi'},
#  'aegil': {'agiel', 'agile', 'galei'},
#  'aeegilnss': {'agileness', 'signalese'},
#  'aegimnstt': {'agistment', 'magnetist'},
#  'agiorst': {'agistor', 'agrotis', 'orgiast'},
#  'aaglos': {'aglaos', 'salago'},
#  'aaeglr': {'aglare', 'alegar', 'galera', 'laager'},
#  'aeglt': {'aglet', 'galet'},
#  'aegly': {'agley', 'galey'},
#  'aaegimnt': {'agmatine', 'agminate'},
#  'aadegimnt': {'agminated', 'diamagnet'},
#  'aagiln': {'agnail', 'linaga'},
#  'aaegmn': {'agname', 'manage'},
#  'aegln': {'agnel', 'angel', 'angle', 'galen', 'genal', 'glean', 'lagen'},
#  'aegns': {'agnes', 'gesan'},
#  'aeginz': {'agnize', 'ganzie'},
#  'aginoss': {'agnosis', 'ganosis'},
#  'acginost': {'agnostic', 'coasting'},
#  'agnsu': {'agnus', 'angus', 'sugan'},
#  'ago': {'ago', 'goa'},
#  'agno': {'agon', 'ango', 'gaon', 'goan', 'gona'},
#  'aaglno': {'agonal', 'angola'},
#  'aegno': {'agone', 'genoa'},
#  'aadgiinno': {'agoniadin', 'anangioid', 'ganoidian'},
#  'acgino': {'agonic', 'angico', 'gaonic', 'goniac'},
#  'aaginost': {'agonista', 'santiago'},
#  'aeginorz': {'agonizer', 'orangize', 'organize'},
#  'aaglr': {'agral', 'argal'},
#  'aaaginr': {'agrania', 'angaria', 'niagara'},
#  'aeegr': {'agree', 'eager', 'eagre'},
#  'adeegr': {'agreed', 'geared'},
#  'aeeggr': {'agrege', 'raggee'},
#  'aaeginrst': {'agrestian', 'gerastian', 'stangeria'},
#  'acegirst': {'agrestic', 'ergastic'},
#  'aagir': {'agria', 'igara'},
#  'acgiilorst': {'agricolist', 'algoristic'},
#  'agilrsu': {'agrilus', 'gularis'},
#  'aginr': {'agrin', 'grain'},
#  'agiort': {'agrito', 'ortiga'},
#  'aagnor': {'agroan', 'angora', 'anogra', 'arango', 'argoan', 'onagra'},
#  'agmor': {'agrom', 'morga'},
#  'adgnoru': {'aground', 'durango'},
#  'aefgru': {'agrufe', 'gaufer', 'gaufre'},
#  'aaginpry': {'agrypnia', 'paginary'},
#  'aagms': {'agsam', 'magas'},
#  'aegu': {'ague', 'auge'},
#  'aghsu': {'agush', 'saugh'},
#  'agstu': {'agust', 'tsuga'},
#  'agy': {'agy', 'gay'},
#  'ah': {'ah', 'ha'},
#  'aehm': {'ahem', 'haem', 'hame'},
#  'aeht': {'ahet', 'haet', 'hate', 'heat', 'thea'},
#  'aehy': {'ahey', 'eyah', 'yeah'},
#  'adhin': {'ahind', 'dinah'},
#  'ahint': {'ahint', 'hiant', 'tahin'},
#  'ahir': {'ahir', 'hair'},
#  'adehm': {'ahmed', 'hemad'},
#  'aehmt': {'ahmet', 'thema'},
#  'aho': {'aho', 'hao'},
#  'ahmo': {'ahom', 'moha'},
#  'aghno': {'ahong', 'hogan'},
#  'aehors': {'ahorse', 'ashore', 'hoarse', 'shorea'},
#  'ahoy': {'ahoy', 'hoya'},
#  'aahimnr': {'ahriman', 'miranha'},
#  'aahns': {'ahsan', 'hansa', 'hasan'},
#  'aht': {'aht', 'hat', 'tha'},
#  'aaehnt': {'ahtena', 'aneath', 'athena'},
#  'ahu': {'ahu', 'auh', 'hau'},
#  'ahmu': {'ahum', 'huma'},
#  'ahntu': {'ahunt', 'haunt', 'thuan', 'unhat'},
#  'adi': {'aid', 'ida'},
#  'aacdein': {'aidance', 'canidae'},
#  'adei': {'aide', 'idea'},
#  'adeinn': {'aidenn', 'andine', 'dannie', 'indane'},
#  'adeir': {'aider', 'deair', 'irade', 'redia'},
#  'adeis': {'aides', 'aside', 'sadie'},
#  'aeil': {'aiel', 'aile', 'elia'},
#  'aegilt': {'aiglet', 'ligate', 'taigle', 'tailge'},
#  'ail': {'ail', 'ila', 'lai'},
#  'aaeiilnnt': {'ailantine', 'antialien'},
#  'aailnot': {'ailanto', 'alation', 'laotian', 'notalia'},
#  'aeeiln': {'aileen', 'elaine'},
#  'aeilnor': {'aileron', 'alienor'},
#  'agiiln': {'ailing', 'angili', 'nilgai'},
#  'aeilmnt': {'ailment', 'aliment'},
#  'aim': {'aim', 'ami', 'ima'},
#  'aeimr': {'aimer', 'maire', 'marie', 'ramie'},
#  'aeilmss': {'aimless', 'melissa', 'seismal'},
#  'aaehiln': {'ainaleh', 'halenia'},
#  'aint': {'aint', 'anti', 'tain', 'tina'},
#  'aino': {'aion', 'naio'},
#  'air': {'air', 'ira', 'ria'},
#  'aair': {'aira', 'aria', 'raia'},
#  'aainr': {'airan', 'arain', 'arian'},
#  'adeimorr': {'airdrome', 'armoried'},
#  'aeir': {'aire', 'eria'},
#  'aeirr': {'airer', 'arrie'},
#  'aeiiklr': {'airlike', 'kiliare'},
#  'aaimnr': {'airman', 'amarin', 'marian', 'marina', 'mirana'},
#  'aaeilnpr': {'airplane', 'perianal'},
#  'aaiilnprst': {'airplanist', 'triplasian'},
#  'airt': {'airt', 'rita', 'tari', 'tiar'},
#  'airy': {'airy', 'yair'},
#  'aeils': {'aisle', 'elias'},
#  'adeils': {'aisled', 'deasil', 'ladies', 'sailed'},
#  'agiilns': {'aisling', 'sailing'},
#  'aiorss': {'aissor', 'rissoa'},
#  'ait': {'ait', 'ati', 'ita', 'tai'},
#  'achit': {'aitch', 'chait', 'chati', 'chita', 'taich', 'tchai'},
#  'aiinot': {'aition', 'itonia'},
#  'aeilz': {'aizle', 'eliza'},
#  'aajr': {'ajar', 'jara', 'raja'},
#  'aahjr': {'ajhar', 'rajah'},
#  'aagju': {'ajuga', 'jagua'},
#  'ak': {'ak', 'ka'},
#  'aakl': {'akal', 'kala'},
#  'aaikl': {'akali', 'alaki'},
#  'aakn': {'akan', 'kana'},
#  'aek': {'ake', 'kea'},
#  'abeik': {'akebi', 'bakie'},
#  'aahk': {'akha', 'kaha'},
#  'aikm': {'akim', 'maki'},
#  'aikn': {'akin', 'kina', 'naik'},
#  'aakk': {'akka', 'kaka'},
#  'aeekn': {'aknee', 'ankee', 'keena'},
#  'ako': {'ako', 'koa', 'oak', 'oka'},
#  'aaakmos': {'akoasma', 'amakosa'},
#  'aku': {'aku', 'auk', 'kua'},
#  'al': {'al', 'la'},
#  'aacilorstu': {'alacritous', 'lactarious', 'lactosuria'},
#  'aailn': {'alain', 'alani', 'liana'},
#  'aaeillt': {'alalite', 'tillaea'},
#  'aalmo': {'alamo', 'aloma'},
#  'aaln': {'alan', 'anal', 'lana'},
#  'aagilnn': {'alangin', 'anginal', 'anglian', 'nagnail'},
#  'aaegilnn': {'alangine', 'angelina', 'galenian'},
#  'aaeilnn': {'alanine', 'linnaea'},
#  'aalns': {'alans', 'lanas', 'nasal'},
#  'aacillnot': {'alantolic', 'allantoic'},
#  'aallny': {'alanyl', 'anally'},
#  'aaelrs': {'alares', 'arales'},
#  'aaailr': {'alaria', 'aralia'},
#  'aacilr': {'alaric', 'racial'},
#  'aalmr': {'alarm', 'malar', 'maral', 'marla', 'ramal'},
#  'aaabellmr': {'alarmable', 'ambarella'},
#  'aadellmry': {'alarmedly', 'medallary'},
#  'aagilmnr': {'alarming', 'marginal'},
#  'aagillmnry': {'alarmingly', 'marginally'},
#  'aailmrst': {'alarmist', 'alastrim'},
#  'aals': {'alas', 'lasa'},
#  'aaailrst': {'alastair', 'salariat'},
#  'aaelrst': {'alaster', 'tarsale'},
#  'aaelnrt': {'alatern', 'lateran'},
#  'aaelnrstu': {'alaternus', 'saturnale'},
#  'abl': {'alb', 'bal', 'lab'},
#  'aabl': {'alba', 'baal', 'bala'},
#  'aabln': {'alban', 'balan', 'banal', 'laban', 'nabal', 'nabla'},
#  'aabeilnt': {'albanite', 'balanite', 'nabalite'},
#  'aabdeilnr': {'albardine', 'drainable'},
#  'aabilmru': {'albarium', 'brumalia'},
#  'aaablt': {'albata', 'atabal', 'balata'},
#  'abdelo': {'albedo', 'doable'},
#  'abeilt': {'albeit',
#   'albite',
#   'baltei',
#   'belait',
#   'betail',
#   'bletia',
#   'libate'},
#  'abelrt': {'albert', 'balter', 'labret', 'tabler'},
#  'aabelrt': {'alberta', 'latebra', 'ratable'},
#  'aabeilnrt': {'albertina', 'trainable'},
#  'abelort': {'alberto', 'bloater', 'latrobe'},
#  'aabdelt': {'albetad', 'datable'},
#  'abil': {'albi', 'bail', 'bali'},
#  'aabiln': {'albian', 'bilaan'},
#  'abiln': {'albin', 'binal', 'blain'},
#  'abilno': {'albino', 'albion', 'alboin', 'oliban'},
#  'aabeilnort': {'alboranite', 'rationable'},
#  'abelnorz': {'albronze', 'blazoner'},
#  'aabclu': {'albuca', 'bacula'},
#  'aabeilmntu': {'albuminate', 'antelabium'},
#  'ablmnruu': {'alburnum', 'laburnum'},
#  'aaccil': {'alcaic', 'cicala'},
#  'aacdeil': {'alcaide', 'alcidae'},
#  'aaceilmn': {'alcamine', 'analcime', 'calamine', 'camelina'},
#  'aaaceilnnrst': {'alcantarines', 'lancasterian'},
#  'acdelo': {'alcedo', 'dacelo'},
#  'acels': {'alces', 'casel', 'scale'},
#  'accehilm': {'alchemic', 'chemical'},
#  'accehiilmst': {'alchemistic', 'hemiclastic'},
#  'aacehlr': {'alchera', 'archeal'},
#  'aachilnrt': {'alchitran', 'clathrina'},
#  'acdeiiln': {'alcidine', 'danielic', 'lecaniid'},
#  'aceiln': {'alcine', 'ancile'},
#  'aclo': {'alco', 'coal', 'cola', 'loca'},
#  'aacelot': {'alcoate', 'coelata'},
#  'acegllo': {'alcogel', 'collage'},
#  'aclor': {'alcor', 'calor', 'carlo', 'carol', 'claro', 'coral'},
#  'aaclnor': {'alcoran', 'ancoral', 'carolan'},
#  'acelov': {'alcove', 'coeval', 'volcae'},
#  'aclnoy': {'alcyon', 'cyanol'},
#  'acelnoy': {'alcyone', 'cyanole'},
#  'aadeilmn': {'aldamine', 'lamnidae'},
#  'aadeelmnt': {'aldeament', 'mandelate'},
#  'adelr': {'alder', 'daler', 'lader'},
#  'aadelmnrry': {'aldermanry', 'marylander'},
#  'adelnr': {'aldern',
#   'darnel',
#   'enlard',
#   'lander',
#   'lenard',
#   'randle',
#   'reland'},
#  'adeilm': {'aldime', 'mailed', 'medial'},
#  'adeiln': {'aldine', 'daniel', 'delian', 'denial', 'enalid', 'leadin'},
#  'adlsu': {'aldus', 'sauld'},
#  'ael': {'ale', 'lea'},
#  'aceelnnor': {'aleconner', 'noncereal'},
#  'acelost': {'alecost', 'lactose', 'scotale', 'talcose'},
#  'aceilorst': {'alectoris', 'sarcolite', 'sclerotia', 'sectorial'},
#  'aceilnort': {'alectrion', 'clarionet', 'crotaline', 'locarnite'},
#  'acelnorty': {'alectryon', 'tolerancy'},
#  'acelpu': {'alecup', 'clupea'},
#  'aefl': {'alef', 'feal', 'flea', 'leaf'},
#  'aeflt': {'aleft', 'alfet', 'fetal', 'fleta'},
#  'aelm': {'alem', 'alme', 'lame', 'leam', 'male', 'meal', 'mela'},
#  'aaeilmnn': {'alemanni', 'melanian'},
#  'aeeilmt': {'alemite', 'elamite'},
#  'aeln': {'alen', 'lane', 'lean', 'lena', 'nael', 'neal'},
#  'aehlp': {'aleph', 'pheal'},
#  'aelopt': {'alepot', 'pelota'},
#  'aceelr': {'alerce', 'cereal', 'relace'},
#  'aeelrs': {'alerse', 'leaser', 'reales', 'resale', 'reseal', 'sealer'},
#  'aelrt': {'alert', 'alter', 'artel', 'later', 'ratel', 'taler', 'telar'},
#  'aellrty': {'alertly', 'elytral'},
#  'aaeeklst': {'alestake', 'eastlake'},
#  'aaelpt': {'aletap', 'palate', 'platea'},
#  'aeilrst': {'aletris', 'alister', 'listera', 'realist', 'saltier'},
#  'aceilnoru': {'aleuronic', 'urceolina'},
#  'aeltu': {'aleut', 'atule'},
#  'aceiltu': {'aleutic', 'auletic', 'caulite', 'lutecia'},
#  'aeilnv': {'alevin', 'alvine', 'valine', 'veinal', 'venial', 'vineal'},
#  'aelx': {'alex', 'axel', 'axle'},
#  'aaadeilnnrx': {'alexandrian', 'alexandrina'},
#  'aeilnx': {'alexin', 'xenial'},
#  'aadelry': {'aleyard', 'already'},
#  'adeefiln': {'alfenide', 'enfilade'},
#  'adeflr': {'alfred', 'fardel'},
#  'aflru': {'alfur', 'fural'},
#  'aaegl': {'algae', 'galea'},
#  'aagll': {'algal', 'galla'},
#  'aabeglr': {'algebar', 'algebra'},
#  'adegil': {'algedi', 'galeid'},
#  'adeglo': {'algedo', 'geodal'},
#  'acdegilno': {'algedonic', 'genocidal'},
#  'abegiln': {'algenib', 'bealing', 'belgian', 'bengali'},
#  'aaegilnr': {'algerian', 'geranial', 'regalian'},
#  'aeglnnor': {'algernon', 'nonglare'},
#  'aaegils': {'algesia', 'sailage'},
#  'aegilss': {'algesis', 'glassie'},
#  'aabegil': {'algieba', 'bailage'},
#  'agiln': {'algin', 'align', 'langi', 'liang', 'linga'},
#  'aegiln': {'algine', 'genial', 'linage'},
#  'agilst': {'algist', 'gaslit'},
#  'aeeglmort': {'algometer', 'glomerate'},
#  'acegilmort': {'algometric', 'melotragic'},
#  'aagilmno': {'algomian', 'magnolia'},
#  'aglor': {'algor', 'argol', 'goral', 'largo'},
#  'aghilmort': {'algorithm', 'logarithm'},
#  'acghiilmort': {'algorithmic', 'logarithmic'},
#  'aacghilpr': {'algraphic', 'graphical'},
#  'aglmu': {'algum', 'almug', 'glaum', 'gluma', 'mulga'},
#  'abiiillty': {'alibility', 'liability'},
#  'abeill': {'alible', 'belial', 'labile', 'liable'},
#  'aceil': {'alice', 'celia', 'ileac'},
#  'acehill': {'alichel', 'challie', 'helical'},
#  'aeiln': {'alien', 'aline', 'anile', 'elain', 'elian', 'laine', 'linea'},
#  'aaeiilnnot': {'alienation', 'alineation'},
#  'aaeilnort': {'alienator', 'rationale'},
#  'aeiilmns': {'alienism', 'milesian'},
#  'afil': {'alif', 'fail'},
#  'aegilorsu': {'aligerous', 'glaireous'},
#  'aegilnr': {'aligner', 'engrail', 'realign', 'reginal'},
#  'aegilmnnt': {'alignment', 'lamenting'},
#  'aeikl': {'alike', 'lakie'},
#  'aeeiklnss': {'alikeness', 'leakiness'},
#  'aailm': {'alima', 'lamia'},
#  'aeeilmnrt': {'alimenter', 'marteline'},
#  'aceiilmnt': {'alimentic', 'antilemic', 'melanitic', 'metanilic'},
#  'adeiilmno': {'alimonied', 'maleinoid'},
#  'ailn': {'alin', 'anil', 'lain', 'lina', 'nail'},
#  'adeilp': {'aliped', 'elapid'},
#  'aeilpst': {'aliptes', 'pastile', 'talipes'},
#  'aciilpt': {'aliptic', 'aplitic'},
#  'aaeillpst': {'aliseptal', 'pallasite'},
#  'ahils': {'alish', 'hilsa'},
#  'aeiilrs': {'alisier', 'israeli'},
#  'ailos': {'aliso', 'alois'},
#  'ailnos': {'alison', 'anolis'},
#  'ailps': {'alisp', 'lapsi'},
#  'ailst': {'alist', 'litas', 'slait', 'talis'},
#  'ailt': {'alit', 'tail', 'tali'},
#  'aeilt': {'alite', 'laeti'},
#  'adeilnu': {'aliunde', 'unideal'},
#  'aeeilnssv': {'aliveness', 'vealiness'},
#  'ailx': {'alix', 'axil'},
#  'akl': {'alk', 'lak'},
#  'aaeikllrz': {'alkalizer', 'lazarlike'},
#  'aaiklmn': {'alkamin', 'malakin'},
#  'aeekln': {'alkene', 'lekane'},
#  'aekls': {'alkes', 'sakel', 'slake'},
#  'aeikln': {'alkine', 'ilkane', 'inlake', 'inleak'},
#  'akly': {'alky', 'laky'},
#  'aciklly': {'alkylic', 'lilacky'},
#  'aaegillt': {'allagite', 'alligate', 'talliage'},
#  'aahll': {'allah', 'halal'},
#  'aally': {'allay', 'yalla'},
#  'aaellry': {'allayer', 'yallaer'},
#  'abellno': {'allbone', 'bellona'},
#  'aell': {'alle', 'ella', 'leal'},
#  'aceellrt': {'allecret', 'cellaret'},
#  'aaeegllt': {'allegate', 'ellagate'},
#  'aegillorst': {'allegorist', 'legislator'},
#  'aeegllnr': {'allergen', 'generall'},
#  'aaegillr': {'allergia', 'galleria'},
#  'aegillnr': {'allergin', 'gralline'},
#  'aegllry': {'allergy', 'gallery', 'largely', 'regally'},
#  'aabeilll': {'alliable', 'labiella'},
#  'aabillly': {'alliably', 'labially'},
#  'aaceilln': {'alliance', 'canaille'},
#  'aaceillnr': {'alliancer', 'ralliance'},
#  'aeill': {'allie', 'leila', 'lelia'},
#  'aeills': {'allies', 'aselli'},
#  'aillmu': {'allium', 'alulim', 'muilla'},
#  'aacillnoot': {'allocation', 'locational'},
#  'acellotu': {'allocute', 'loculate'},
#  'acillnootu': {'allocution', 'loculation'},
#  'acegillno': {'allogenic', 'collegian'},
#  'allmnoy': {'allonym', 'malonyl'},
#  'aahllopty': {'allopathy', 'lalopathy'},
#  'aacilloprt': {'allopatric', 'patrilocal'},
#  'allot': {'allot', 'atoll'},
#  'aceghillnoot': {'allothogenic', 'ethnological'},
#  'aellorv': {'allover', 'overall'},
#  'aellorw': {'allower', 'reallow'},
#  'alloy': {'alloy', 'loyal'},
#  'adellu': {'allude', 'aludel'},
#  'aellru': {'allure', 'laurel'},
#  'aalm': {'alma', 'amla', 'lama', 'mala'},
#  'aachlm': {'almach', 'chamal'},
#  'aaacgilm': {'almaciga', 'macaglia'},
#  'aailmn': {'almain', 'animal', 'lamina', 'manila'},
#  'aalmn': {'alman', 'lamna', 'manal'},
#  'aadeilmnt': {'almandite', 'laminated'},
#  'aaeilmnr': {'almerian', 'manerial'},
#  'agilmno': {'almoign', 'loaming'},
#  'almno': {'almon', 'monal'},
#  'adlmno': {'almond', 'dolman'},
#  'aelmnor': {'almoner', 'moneral', 'nemoral'},
#  'almnory': {'almonry', 'romanly'},
#  'alms': {'alms', 'salm', 'slam'},
#  'acelmu': {'almuce', 'caelum', 'macule'},
#  'adelmu': {'almude', 'maudle'},
#  'aelmntu': {'almuten', 'emulant'},
#  'aln': {'aln', 'lan'},
#  'aaegln': {'alnage', 'angela', 'galena', 'lagena'},
#  'acilno': {'alnico', 'cliona', 'oilcan'},
#  'aaillmn': {'alnilam', 'manilla'},
#  'aeilnot': {'alnoite', 'elation', 'toenail'},
#  'ailnnu': {'alnuin', 'unnail'},
#  'alo': {'alo', 'lao', 'loa'},
#  'adlo': {'alod', 'dola', 'load', 'odal'},
#  'aelo': {'aloe', 'olea'},
#  'aceilot': {'aloetic', 'coalite'},
#  'aflot': {'aloft', 'float', 'flota'},
#  'aagilno': {'alogian', 'logania'},
#  'aacgillo': {'alogical', 'colalgia'},
#  'adilo': {'aloid', 'dolia', 'idola'},
#  'ailno': {'aloin', 'anoil', 'anoli'},
#  'aelno': {'alone', 'anole', 'olena'},
#  'aglno': {'along', 'gonal', 'lango', 'longa', 'nogal'},
#  'alnoos': {'alonso', 'alsoon', 'saloon'},
#  'alnooz': {'alonzo', 'zoonal'},
#  'alop': {'alop', 'opal'},
#  'aceilopst': {'alopecist', 'altiscope', 'epicostal', 'scapolite'},
#  'aalos': {'alosa', 'loasa', 'oasal'},
#  'aelos': {'alose', 'osela', 'solea'},
#  'alow': {'alow', 'awol', 'lowa'},
#  'aeilotx': {'aloxite', 'oxalite'},
#  'alp': {'alp', 'lap', 'pal'},
#  'aeelnp': {'alpeen', 'lenape', 'pelean'},
#  'aelnp': {'alpen', 'nepal', 'panel', 'penal', 'plane'},
#  'aaellprst': {'alpestral', 'palestral'},
#  'aaeilnprst': {'alpestrian', 'palestrian', 'psalterian'},
#  'aeeilnprst': {'alpestrine', 'episternal', 'interlapse', 'presential'},
#  'acehilnp': {'alphenic', 'cephalin'},
#  'aehlnops': {'alphonse', 'phenosal'},
#  'ahlops': {'alphos', 'pholas'},
#  'ahilopss': {'alphosis', 'haplosis'},
#  'adilp': {'alpid', 'plaid'},
#  'aeilpu': {'alpieu', 'paulie'},
#  'aeilnp': {'alpine', 'nepali', 'penial', 'pineal'},
#  'aiilnpst': {'alpinist', 'antislip'},
#  'ailpst': {'alpist', 'pastil', 'spital'},
#  'aalnru': {'alraun', 'alruna', 'ranula'},
#  'aghilrty': {'alrighty', 'arightly'},
#  'aeilns': {'alsine', 'neslia', 'saline', 'selina', 'silane'},
#  'alos': {'also', 'sola'},
#  'adeiilnnost': {'alstonidine', 'nonidealist'},
#  'aeilnnost': {'alstonine', 'tensional'},
#  'alt': {'alt', 'lat', 'tal'},
#  'aaailnt': {'altaian', 'latania', 'natalia'},
#  'aacilt': {'altaic', 'altica'},
#  'aailrt': {'altair', 'atrail', 'atrial', 'lariat', 'latria', 'talari'},
#  'aaailmrt': {'altamira', 'matralia'},
#  'aalrt': {'altar', 'artal', 'ratal', 'talar'},
#  'aadelrt': {'altared', 'laterad'},
#  'aailrstt': {'altarist', 'striatal'},
#  'aabeiillrtty': {'alterability', 'bilaterality', 'relatability'},
#  'aabeellrt': {'alterable', 'relatable'},
#  'aaelnrtt': {'alterant', 'tarletan'},
#  'aeelrrt': {'alterer', 'realter', 'relater'},
#  'aelnrt': {'altern', 'antler', 'learnt', 'rental', 'ternal'},
#  'aeelnrt': {'alterne', 'enteral', 'eternal', 'teleran', 'teneral'},
#  'aaehlt': {'althea', 'elatha'},
#  'ahlot': {'altho', 'lhota', 'loath'},
#  'ahlnort': {'althorn', 'anthrol', 'thronal'},
#  'ailnt': {'altin', 'latin'},
#  'adeilttu': {'altitude', 'latitude'},
#  'aadiillnttu': {'altitudinal', 'latitudinal'},
#  'aaadiiilnnrttu': {'altitudinarian', 'latitudinarian'},
#  'alot': {'alto', 'lota'},
#  'aceilrst': {'altrices', 'selictar'},
#  'ailmrstu': {'altruism', 'muralist', 'traulism', 'ultraism'},
#  'ailrsttu': {'altruist', 'ultraist'},
#  'aciilrsttu': {'altruistic', 'truistical', 'ultraistic'},
#  'aelltu': {'alulet', 'luteal'},
#  'almu': {'alum', 'maul'},
#  'aaeilmntu': {'aluminate', 'alumniate'},
#  'adeiilmnu': {'aluminide', 'unimedial'},
#  'aaceiiillmnostu': {'aluminosilicate', 'silicoaluminate'},
#  'aalmnu': {'alumna', 'manual'},
#  'ailmnu': {'alumni', 'unmail'},
#  'alru': {'alur', 'laur', 'lura', 'raul', 'ural'},
#  'aelru': {'alure', 'ureal'},
#  'aegilrtu': {'alurgite', 'ligature'},
#  'aaltu': {'aluta', 'taula'},
#  'aalnv': {'alvan', 'naval'},
#  'aalrv': {'alvar', 'arval', 'larva'},
#  'aelsuv': {'alveus', 'avulse'},
#  'ailnv': {'alvin', 'anvil', 'nival', 'vinal'},
#  'aly': {'aly', 'lay'},
#  'ailnpy': {'alypin', 'pialyn'},
#  'aelsty': {'alytes', 'astely', 'lysate', 'stealy'},
#  'am': {'am', 'ma'},
#  'aaceimnr': {'amacrine', 'american', 'camerina', 'cinerama'},
#  'aadim': {'amadi', 'damia', 'madia', 'maida'},
#  'aaehmnot': {'amaethon', 'thomaean'},
#  'aahm': {'amah', 'maha'},
#  'aaimn': {'amain', 'amani', 'amnia', 'anima', 'mania'},
#  'aaaglmm': {'amalgam', 'malagma'},
#  'aagmn': {'amang', 'ganam', 'manga'},
#  'aaimnst': {'amanist', 'stamina'},
#  'aaiimnnt': {'amanitin', 'maintain'},
#  ...}

# %%
def fastAnagrams(myWord):
    sig = signature(myWord)
    
    return anagramBySignature[sig]

# %%
fastAnagrams('tops')
# Out:
# {'post', 'spot', 'stop', 'tops'}

# %%
def fastAnagrams(myWord):
    sig = signature(myWord)
    
    try:
        return anagramBySignature[sig]
    except KeyError:
        return set()

# %%
fastAnagrams('Nife')
# Out:
# set()

# %%
# %time fastAnagrams('stop')
# Out:
# Wall time: 0 ns
# {'post', 'spot', 'stop', 'tops'}

# %%
sorted(anagramBySignature.keys(), key=len, reverse=True)
# Out:
# ['ccddeehlmnooooossttuyy',
#  'acddeehiimmnoopprrruuy',
#  'aaaaccghiillmnooooptt',
#  'acghhhhilmooooopprrtt',
#  'aaccddeeemnnoooprttuy',
#  'aaabegghilllnoooprssy',
#  'aaccghiiilmnoooopsty',
#  'acceeeeeghillmnnnoop',
#  'aaabeggillllnooorssy',
#  'aaaccghiilmnooooptt',
#  'aacccghiiilllnooopt',
#  'aceeeghiiilmnnnopst',
#  'aaegghmooooprssstty',
#  'bceiiiilnnoorrtttvy',
#  'aacccdeehiiinopprrr',
#  'accghhiilloooppssyy',
#  'aaccdhmmnoooorrsxy',
#  'cdehiiiiinooorrstt',
#  'accghhhinoooopprrt',
#  'ceeeeehlmmoorrrttt',
#  'addeiimmooopsstvyy',
#  'aaeeeghlmmnoorrttv',
#  'aadeeehhiknorrsttx',
#  'aagghiilnnoprrstyy',
#  'aaceghlmnooorrttyy',
#  'acceghillnoooprsuy',
#  'aacdeeehiillmntty',
#  'aaaabchiimnoprrst',
#  'aaccceeiilloorssu',
#  'aceeghiiilmnnopst',
#  'bceeegiiimnnorrst',
#  'aacccceehhiilmmno',
#  'acghhhilmoooprrty',
#  'acghhhmoooopprrty',
#  'acghhhnoooopprrty',
#  'aciiilmnnoosstttu',
#  'acdegiilmoooopsuy',
#  'aacceeegillmnortt',
#  'aceeehiillmnopsty',
#  'aacdeehhiknoorstx',
#  'adehhmnoooprrtuxy',
#  'aaehlmoooprrsttyy',
#  'ceehmmmooorsttyyy',
#  'aaaegghllnnoprryy',
#  'accghhiimooopprrt',
#  'ccceeimooopprrsst',
#  'aeeeiimnnoprrsstt',
#  'aacdeeiillopprrru',
#  'aabdeeiilmnnotxz',
#  'acdhhiinoorrrstt',
#  'aaacdghiiooprrtu',
#  'abccghiillooopsy',
#  'aaccceelnooorrsu',
#  'acghhhnoooopprrt',
#  'acfgiiimnnoorstu',
#  'aaccdeeillmnorty',
#  'accdefhiinorrryy',
#  'accdefhinoorrryy',
#  'aabcfimmooorrsxy',
#  'aceeghhloopprsty',
#  'aeghhhilooopprty',
#  'aeehhmmnoooprtux',
#  'bceeiilnnoorrttv',
#  'aceeiiilnnossttv',
#  'aaellmnooopprsty',
#  'aghhhilooopprtty',
#  'ceeeegillmmnnooy',
#  'acghhimooopprrty',
#  'cehilmnoopprrsuu',
#  'acceiilmooopprtt',
#  'aaaeilmoopqrsstu',
#  'aaceeiinnnoppttt',
#  'aaceghillopprrty',
#  'aghhiiinnoprrsty',
#  'aeeghhooopprrstt',
#  'aceeghhiloopprtt',
#  'cghhiloooppssyyy',
#  'cceghhlnooopstyy',
#  'aeeeglmooprrrtuy',
#  'aacccillorrstuuu',
#  'aacchilmnnoopsst',
#  'cceeeeloopprsstt',
#  'cehiiooprrsssttt',
#  'aaabdgiilmnnoov',
#  'aabcdeiilmnoosv',
#  'aaceiiillmnostu',
#  'aaadghiooprrtuy',
#  'aabeghhmooprrrt',
#  'abccgiiilloooos',
#  'acccehhiilmopsy',
#  'aaceeghimnoprrt',
#  'aabceilmnootttu',
#  'aceiinnoorssttv',
#  'cciimnnoorssttu',
#  'cehiiorrsstttuy',
#  'aacddeeiloprtty',
#  'adeeimnoorrsstu',
#  'adeiilnorrssttx',
#  'accceeiiilmssst',
#  'acceeegilmnortt',
#  'aeegiinorrssttt',
#  'adeehhilmnoopst',
#  'accfiilnoooprtt',
#  'aacefgiiimnnort',
#  'aacghillmnoopry',
#  'aadeeehhnorrttx',
#  'bceeiiilmpprrst',
#  'beeeiilmnprssss',
#  'eefiinoooprrrst',
#  'ehhilmnoooprtty',
#  'aacghhmooopprrt',
#  'eegiiilmmnnosty',
#  'acghhimooopprrt',
#  'ccehimoooopprst',
#  'acdeeiimmoorrrt',
#  'addeeimnnrrsstu',
#  'aaeeilmoopprrtt',
#  'aaceeiiloprrstv',
#  'aeeghhloopprtty',
#  'aghhoooppprttyy',
#  'aehmnooopprtuxy',
#  'eeiooopprrrsstu',
#  'aeiimnnoprrssst',
#  'acegiilnosstttu',
#  'ceeeeelooprsstt',
#  'abeeelnorrrsttv',
#  'aabceeelnnrsstu',
#  'aacddehmnnooor',
#  'aaadiiilnnrttu',
#  'aacdghimnnooor',
#  'aaacchiilnrstt',
#  'aeefiinnoorrrt',
#  'aeeinooprrrstu',
#  'aaciiimnoossst',
#  'aaadghiooprrtu',
#  'abcelmoossttuy',
#  'bcdfhilooorruy',
#  'aaacccimnoorrs',
#  'accceeiilorsvv',
#  'acchiillnooprt',
#  'abcdfhimnooorr',
#  'aaceilnnoorstv',
#  'ceiinnoorstttu',
#  'abceeloorrsttv',
#  'cehinooprsssty',
#  'aadeeenorrsttt',
#  'aadeeinnostttu',
#  'acdegiillooprt',
#  'adellnoorrstvy',
#  'addeejjlnnoouu',
#  'accdeeilmnorty',
#  'cceeehilmorrtt',
#  'ehhillnoprrtyy',
#  'aeiiinoprstttx',
#  'aaefilnooprrtt',
#  'aeflmnoooprrtt',
#  'aaccghilnopsvy',
#  'eeegiimnoprsss',
#  'adeehhhillmoor',
#  'aceeghillooprt',
#  'dehhinooprrssy',
#  'beiiiilmprssty',
#  'eeeiimnprssssv',
#  'aceegilmnnoort',
#  'aeeiillnnoprtt',
#  'aceeiilnnorstt',
#  'aeiiinnoprrstt',
#  'cdeiiloorrssuu',
#  'accdehiilmopsy',
#  'beehiilmoprstt',
#  'eeeeimnprrrsst',
#  'aaciillnrsttuy',
#  'eehiilnopprsty',
#  'cehinooprsssuy',
#  'acdeeinnnoorst',
#  'aaaacdiillprsy',
#  'aaeegiilnnoprv',
#  'aabeilnoprrttu',
#  'aaceghilopprrt',
#  'acegilllooprty',
#  'aaelmoopqrsstu',
#  'aeeghhloopprtt',
#  'aceeilloprrsuv',
#  'aaeeiilnoprrtz',
#  'eeeeinnprssstv',
#  'aegimmnooprstu',
#  'ahinnopprrtuux',
#  'adeeehilnooprt',
#  'aaeiiilnorttvz',
#  'adefiilnoorttu',
#  'aabceelorrrstv',
#  'aeeilnoorrsstu',
#  'aaceiiilnosttt',
#  'ccgiiilnossttu',
#  'abdeeghinnrrtu',
#  'aaaiimnnnorstt',
#  'aabeeelmnnnssu',
#  'aaacehilmnoor',
#  'aaaceghiloprr',
#  'aacefiiilmnot',
#  'aacfiiilmnopt',
#  'acghiiilnoost',
#  'aaaegikmnoort',
#  'aciiilmnnortu',
#  'acfiiinooprst',
#  'aeefginorrstu',
#  'aehiiorrssttt',
#  'aeeeinnsstttv',
#  'aeehioorssttu',
#  'abdeeelnrssss',
#  'beeeflnnooruz',
#  'bcghilooopsyy',
#  'abcceilmostty',
#  'abhiilnoopstt',
#  'aaabccfhiilor',
#  'abcccceiloruv',
#  'acceehilmoprt',
#  'acdehloooppsu',
#  'accefiiinortt',
#  'acceefiiirttv',
#  'accefiiorrtty',
#  'accdeiloorrsv',
#  'aacccefiilorv',
#  'aabcceiillorv',
#  'aabceeehlnsst',
#  'aceeehilmorst',
#  'accdhlnooorst',
#  'acdhilmnooopr',
#  'acdhmmnooorxy',
#  'ceeiilnoorstt',
#  'cciiloooprstt',
#  'ceeiimnooprtt',
#  'ciimmnoooprss',
#  'acdlmnooostuy',
#  'acdeeiinorstv',
#  'acdeenorrsttu',
#  'ceeeilmnrssss',
#  'acgiilnnorruu',
#  'acemooprsttty',
#  'ceiilopssttyy',
#  'acdeloprsttuy',
#  'aacdeehiilnop',
#  'adeiimnnooprt',
#  'cdeeeilmorrst',
#  'adegiimooprst',
#  'acdehilloppsu',
#  'degiilooprstt',
#  'acdiiimnorrst',
#  'deghiiinrsstu',
#  'adeeiinorrstt',
#  'deehhimnoopst',
#  'eeiimnoprsssx',
#  'abfilnooorrtt',
#  'aeggilnnnooru',
#  'aaceghioprstt',
#  'aceghinoprrst',
#  'aegiinnorrtuy',
#  'aacghilmnoopr',
#  'aaadeglnnprrt',
#  'aacgghilloopr',
#  'aaghinoprrstu',
#  'aaceehilmpsty',
#  'aaaeeghilmopt',
#  'aceehhinopprt',
#  'adehhloprstuy',
#  'acceiilmnoort',
#  'aeiimnnooprst',
#  'eiiimmnoprsss',
#  'aacdeilllmnou',
#  'aiiinnnoosttv',
#  'aciilnnorsttu',
#  'aaceiilnnortt',
#  'aceiiimnnorrt',
#  'cceefiiinprst',
#  'aaceilnrrstuv',
#  'aegiiinnosttv',
#  'aaachllmnorsy',
#  'aaeellnorrttv',
#  'aeghlmnooopsu',
#  'aaeegillmnops',
#  'achimnooprrst',
#  'aceilmooprstu',
#  'ceeiimnopprst',
#  'eggiimnossstu',
#  'eeiilmnorstuy',
#  'aaccdehinoprr',
#  'achiimnnoortt',
#  'aceeilmoorstt',
#  'acceeilorrtuv',
#  'aceeinorsssuv',
#  'aaehiinpprrst',
#  'aaehnnoprstty',
#  'acdeeiimnoprt',
#  'aabeilmnoprtu',
#  'aabelmoprrtuy',
#  'acdeiiiloprst',
#  'aceiilnoprsst',
#  'ceehilnnopprs',
#  'aehmnnoopptuy',
#  'admoooopssttu',
#  'cdeeiinoprrst',
#  'aaeiloopprrrt',
#  'dehiloopprstu',
#  'acchimoopssty',
#  'aceeiimoppsty',
#  'cceeiimoppsty',
#  'adeeginorrrtt',
#  'eiinoopprsstu',
#  'aaccfiiinorst',
#  'abccillorstuy',
#  'deeeinnprrstu',
#  'aabeiilmnntuy',
#  'abceefiilnrtu',
#  'abceelnnorsuv',
#  'beeiilmnprssu',
#  'ceeeiklnprstu',
#  'bceeilnpsstuu',
#  'aacegiilnosvv',
#  'accehilmoprs',
#  'aaccehilnort',
#  'aacchiimnort',
#  'acdhiiloopsu',
#  'aaccillorsty',
#  'aaceinnoprtt',
#  'aaccelmntuuu',
#  'aacdemnoosty',
#  'aabdefimnoor',
#  'aaacdemnoors',
#  'adiimnooprss',
#  'acdeinooprrt',
#  'aaaceilnnrst',
#  'aceghillnoot',
#  'aabeiillrtty',
#  'ahimoopprstu',
#  'aaceghimnopr',
#  'aabfgiimnoor',
#  'aaeilmnnrtuy',
#  'aaceeiinrttv',
#  'acfiiinnortt',
#  'aiimnooqsttu',
#  'acehiinnoptt',
#  'aaeeinoprstt',
#  'aaiilnorstty',
#  'aaciilnoprtt',
#  'aachiilmoprs',
#  'aeeginooqsuu',
#  'aeeinoprrsty',
#  'aabceillprry',
#  'aabceehloprr',
#  'aabcdhinoopr',
#  'abdehmoorrty',
#  'aacccdeimnoo',
#  'acceiillnost',
#  'acdeiilmortt',
#  'accelmopstuy',
#  'abcddehiorry',
#  'aaceiimnrsst',
#  'aacdeflmooru',
#  'aaacdellortu',
#  'acdelnoorrst',
#  'aceeillnnort',
#  'aacceehlortt',
#  'accefiiorrtt',
#  'accdeiinorvy',
#  'aaceehlmprst',
#  'aceehlnoprss',
#  'cdehiiooprst',
#  'accehiilmotv',
#  'acchiimnorst',
#  'chhiiooprsst',
#  'aacehilmnoor',
#  'cddehiilooor',
#  'accehmoortty',
#  'acghhoprrsyy',
#  'ccciilnnooot',
#  'aciiilnoostt',
#  'cceeillnoort',
#  'ceelnoprrtuy',
#  'aacghilooprr',
#  'aaceilmmnort',
#  'ceiimmnoorss',
#  'aceeemnoprtt',
#  'cdeeehmnoprr',
#  'cceeinnoorss',
#  'acceinnnooss',
#  'aceinnoorstv',
#  'aceeinorstvv',
#  'abcinnoorttu',
#  'ceeinnnoortv',
#  'acghioopprst',
#  'acceinooprtu',
#  'aceilooprrst',
#  'cceeinoorrrt',
#  'acelnoorsstt',
#  'acceenorrttu',
#  'accehmnorrtu',
#  'acdegnorrtuu',
#  'acdeelnoprtu',
#  'acdeehnorstu',
#  'acdennorsttu',
#  'cehiioprrstu',
#  'aceeeinrsstv',
#  'cdehiioprrst',
#  'ceeeimorrstt',
#  'ccdhiioorrty',
#  'acegilnorrtu',
#  'abcfimoorsty',
#  'acdeeiilmrst',
#  'acdeeeilnsst',
#  'adeiiilmnott',
#  'aadeeilllmpr',
#  'adegiillnntu',
#  'adegillnnotu',
#  'adeiilnoopst',
#  'acdeeiinoprt',
#  'aadeiilnortv',
#  'adeehmnooprt',
#  'acdeeioprstu',
#  'addeeinrstuv',
#  'adeeiimrsstt',
#  'cdeiinnorstu',
#  'cdeeeinrssst',
#  'aadelloorrst',
#  'addenoorrstv',
#  'adelnoorrstv',
#  'aacehillmpty',
#  'ceeegiinrstt',
#  'aeeghhoprrty',
#  'aeehiinorttz',
#  'aaeeinoprstx',
#  'aeeeflmnssss',
#  'abefiilmoort',
#  'abefimnoorru',
#  'eeffgilnorrw',
#  'adefinnoortu',
#  'aaaegllnnott',
#  'aacghioprstt',
#  'degghloooryy',
#  'aabgilllooss',
#  'defgiinoorsu',
#  'aghimnooprst',
#  'acghhinooppr',
#  'ahhooopprstu',
#  'aceehiinortt',
#  'aceehoprrstu',
#  'eeghnoorstuy',
#  'acehilmoopty',
#  'aadehilmorru',
#  'achiilmorstu',
#  'eehlnrsssstu',
#  'achimoopstty',
#  'aehhoprsttyy',
#  'aaciiilprstt',
#  'abeeeilmnprt',
#  'abeeilmnprty',
#  'aceimnnoprtu',
#  'eeiilmprssvy',
#  'aaciiinnottv',
#  'abceilmnoptu',
#  'ceiinnnosstt',
#  'ddeefiiinntu',
#  'abdeeiilnprv',
#  'cdeeiilnrsty',
#  'aabbeiilnnot',
#  'aaceilnoprtu',
#  'ceeiinnorsst',
#  'ceiiiimnrstt',
#  'ceeinooprrtt',
#  'aeeeillnprtt',
#  'cdeeinoprrtu',
#  'aeeiinrstttu',
#  'aeiinnorsttt',
#  'eeiinnnorttv',
#  'aegiilnnortt',
#  'aabeiilnorrt',
#  'aceeeinnprrt',
#  'accehiilorst',
#  'aaccchiiorss',
#  'aceilnooprtt',
#  'aadeiiloprsu',
#  'aacehilnopst',
#  'aehhiilnoprt',
#  'acegillmoort',
#  'aacehilmpsty',
#  'aacgillmoost',
#  'aaeghlmnrstu',
#  'aeeelmnsssst',
#  'adeeilmnortv',
#  'aacehilmoprt',
#  'aceilmmnoort',
#  'accehilmopry',
#  'ceimooprrstu',
#  'adiiimnorstt',
#  'acdeimnoosty',
#  'hllmnooopsuy',
#  'chimmnoopssy',
#  'chimooopprrt',
#  'eeilmnorstuv',
#  'aeghhmoprrty',
#  'aacceinnorst',
#  'aaciilnrsttu',
#  'aehmnnooptty',
#  'ceeehlnoopps',
#  'aceghillnoop',
#  'eghilnooprst',
#  'acehhinopprt',
#  'adeehinopprs',
#  'aehinoopprst',
#  'ehinoopprssy',
#  'cdeefiinnort',
#  'acinnnorsttu',
#  'aceiilmnnopr',
#  'aceiilnnoprt',
#  'eeelnnosssst',
#  'abcinorssttu',
#  'acchiooprstt',
#  'aeghiilnoopr',
#  'ceghiilnoopr',
#  'aehinooprrtt',
#  'aacfiiilnopt',
#  'aabdeillmopt',
#  'acilnooprstu',
#  'aceghloppryy',
#  'adeeenprrtuv',
#  'ceeeilpprtvy',
#  'aceellpprtuy',
#  'aceinnooprtt',
#  'ceeinoprrssu',
#  'aefiilnooprt',
#  'aeefimoprrtv',
#  'aeeilpprsttu',
#  'eeinoprsssuv',
#  'aeeghopprrrt',
#  'aceghiopprrt',
#  'aeghhoopprrt',
#  'acehlnooprst',
#  'dhlloooppsuy',
#  'eeghinopssty',
#  'ceeghinoptty',
#  'aaellnprstty',
#  'accilooprsuy',
#  'adhiioprrstt',
#  'aaceiloprstt',
#  'cdehilloopry',
#  'eeinooprssss',
#  'aaghoopprssu',
#  'aceiiopprrtt',
#  'abceilnnopru',
#  'celnooprrstu',
#  'acdeiiloprst',
#  'eeeilnprstvy',
#  'einooopprrrt',
#  'cdeinooprrtu',
#  'chiooopprrtt',
#  'deelnoprstuy',
#  'cehhimopssty',
#  'aacceehinrst',
#  'aaceinorrttt',
#  'acceeilorstv',
#  'adeeiinorrtv',
#  'aeeillrrsttu',
#  'eeiimnoprrss',
#  'aeeimnnorrtu',
#  'ceeeiprrssuv',
#  'aeeghinrrstt',
#  'eeeghnnrrstt',
#  'aeiinnoprstu',
#  'aaelnnprrstt',
#  'eeeilnrsssst',
#  'abcfiiinortu',
#  'aaccfiiorrst',
#  'aaaadilmnnrs',
#  'eeimnoprsstu',
#  'eeinnoprsstu',
#  'aceimooprstz',
#  'chimooprrstu',
#  'eelnopssssst',
#  'aeeflnsssttu',
#  'aceehmnrrstt',
#  'aehilooprstt',
#  'abeeilnssstu',
#  'aabeelnrrstu',
#  'aacelnprrsuu',
#  'eeimnprrsstu',
#  'adhimnoprssw',
#  'abeehiinnrtt',
#  'aaelmnnorttu',
#  'abcdeeelnrtu',
#  'aacdeglnotuu',
#  'abceeelnptux',
#  'eeiimnprssuv',
#  'abeeelnnprtu',
#  'adeeinnrsttu',
#  'ceeinpsstuuv',
#  'aaacelprtty',
#  'aacceelorrt',
#  'acceeinorss',
#  'aaacdehinrt',
#  'acdeeiinprs',
#  'aciimnoorsu',
#  'acciilmnoru',
#  'acciimorsst',
#  'acchiooprrt',
#  'aaacdeeinot',
#  'aceiinoprtt',
#  'aadiimnopst',
#  'accdeeinopt',
#  'aadeilmnoop',
#  'aabdiilorty',
#  'acdeilnorty',
#  'acdefiimoor',
#  'aaeeghoprrr',
#  'aaceghioprr',
#  'aacegilloor',
#  'aaeimnorstu',
#  'aaceiorsstt',
#  'aacfilnnotu',
#  'accehiilmst',
#  'aaadeilnnrx',
#  'acghiilmort',
#  'adeiilnnost',
#  'aadiillnttu',
#  'aabeiilmnty',
#  'aaeehlmnorr',
#  'adehilmnoop',
#  'acilmmnooty',
#  'aeeeemmprrt',
#  'aeghimnopsu',
#  'achhiilmopp',
#  'adhimooppsu',
#  'aacceinnort',
#  'aaaceillnpt',
#  'aaachilnopr',
#  'aadhnooprrt',
#  'acehimnorst',
#  'achiimnorst',
#  'aaeghmnopry',
#  'aacegilllny',
#  'aaehimnosst',
#  'addehiinryz',
#  'aceiimnorst',
#  'aehiinorttt',
#  'aeghnnoostu',
#  'aabdiilmntu',
#  'acciilnnotu',
#  'aacdiilnott',
#  'aeeeimnrttx',
#  'aaeiillmnnt',
#  'aceiinnoptt',
#  'aaeilnnrttu',
#  'aahiinprsst',
#  'aceiinprtty',
#  'acdeeinrrtu',
#  'adeinooprtt',
#  'acdhiioprst',
#  'ahoopprsstu',
#  'aeinoopprrt',
#  'aaabeilpprs',
#  'adeeehnpprr',
#  'aaccdhiinor',
#  'aacehloprst',
#  'aaceehlprrt',
#  'aceeiilnort',
#  'aaceeinrrst',
#  'aaeilnorsst',
#  'aceghimnost',
#  'aeeilntttvy',
#  'aaiillnootv',
#  'abcefimorrt',
#  'abehiimorsv',
#  'beilnnoortz',
#  'abcegilnost',
#  'abceilmorst',
#  'beilorrsttw',
#  'aaabbcceemo',
#  'abeilnoosst',
#  'abcdehioopr',
#  'aabcdeorrst',
#  'aabddeoprrs',
#  'aaacdeilnnr',
#  'aacceilltuv',
#  'aaacdeillnr',
#  'aacghillpry',
#  'aacceilnort',
#  'acdeeinoprt',
#  'aaceillmnpt',
#  'aaciillprty',
#  'aacdeinnort',
#  'aacgiilnnor',
#  'acceeioprrt',
#  'aacgilnoopr',
#  'aaceilprttu',
#  'aacddloorsu',
#  'aaciillnotv',
#  'ceeelnrsssu',
#  'aceilmnnort',
#  'aaceinnortx',
#  'ccelnnstuuu',
#  'acceiloprst',
#  'abceefiilrt',
#  'ccehimooprt',
#  'abcehlnoosu',
#  'aaceghhnott',
#  'aacehilnrty',
#  'acdeehilnot',
#  'acehiimrstt',
#  'acehiilostt',
#  'acddehiiino',
#  'acchiimnort',
#  'achiloprsty',
#  'acehilmnoor',
#  'acdhlnooort',
#  'achiinoortz',
#  'cchimooprty',
#  'accdehiiort',
#  'aciiinnortt',
#  'ceegilnosty',
#  'acceeilrrtu',
#  'acdeiilnort',
#  'cceeehinnor',
#  'aceillnoort',
#  'aciillnoost',
#  'acdegimorty',
#  'aciimmnnoot',
#  'aciimnooprt',
#  'cdeiinnoort',
#  'ceegnnoorsu',
#  'acceilnnotv',
#  'abceelnorsv',
#  'accennorsvy',
#  'acdeeinorst',
#  'ccenorrsttu',
#  'acccehnorty',
#  'ceghioprrty',
#  'aciimnorrty',
#  'acdeinoorrt',
#  'acceiimnost',
#  'aciilnopsst',
#  'aceinoprrst',
#  'acdeeinortu',
#  'acelnoprtuy',
#  'aceelnorstu',
#  'aceilnorttu',
#  'aceilnortuv',
#  'aceinorrtuv',
#  'acceimnorty',
#  'acgimnnoory',
#  'acefimorrrt',
#  'acceimorrtt',
#  'aaceinorrty',
#  'aceiinorstt',
#  'aaceilmorrt',
#  'aceeilnnort',
#  'aceeiilmnrs',
#  'ccdeiiloort',
#  'aceimoprrty',
#  'cehilnosssu',
#  'acchinnopyy',
#  'acmmoostxyy',
#  'acdlmnootyy',
#  'cdeeimoostx',
#  'aacdeilnort',
#  'adehinoortt',
#  'acdefiiinot',
#  'acdefiiorty',
#  'acdeiillsty',
#  'deiilnosstu',
#  'addegilmnny',
#  'aacdeimnort',
#  'acdeiimmnos',
#  'degilmnrruy',
#  'aabdeillnot',
#  'acdeinnortu',
#  'adeiinoprtt',
#  'acdeeiopttt',
#  'adeilnooprt',
#  'adegilnprvy',
#  'cdeiinoprst',
#  'accdeiinost',
#  'adeeinoprst',
#  'adeeimnnrtt',
#  'adehiimnopr',
#  'adehhiinprt',
#  'adehhioppst',
#  'degilooprty',
#  'aadeeipprrs',
#  'cdeeimnnrst',
#  'bdeeeimmrrs',
#  'aadiinoprst',
#  'abdeeilnpss',
#  'diiiimnossv',
#  'aacdilooprs',
#  'addeilmoors',
#  'aacdloorrss',
#  'aceehlmopsy',
#  'eilooprssty',
#  'aehinorrsst',
#  'adeegilnnry',
#  'deimnooprsu',
#  'aeegilmnnrt',
#  'ceeehlnprsu',
#  'aabeelnrttu',
#  'ehilmnoopty',
#  'aceilnopstt',
#  'aeeimnnortu',
#  'aceiinnnotu',
#  'ceioorrsuuv',
#  'aeeimnprsst',
#  'aceghilloot',
#  'aceelloptuy',
#  'aceeinoprtu',
#  'adeeehilrtv',
#  'aaeiimnnotx',
#  'aefiinnostt',
#  'abfiilmoopr',
#  'bcfimoorsuu',
#  'abfimmoorxy',
#  'befioorrssu',
#  'adefnorrssw',
#  'abefgiillor',
#  'aaflnnoorst',
#  'cefilorstuu',
#  'afilmnortuy',
#  'aacgillnnot',
#  'aabegggllry',
#  'aceeggimnot',
#  'acgimnoorst',
#  'aeegiilnrtz',
#  'acegilnopty',
#  'eeghimoorst',
#  'aceegilmort',
#  'cceeginoott',
#  'aeghmnooprr',
#  'ceegiilnryz',
#  'deghlmnootu',
#  'eeggnooqrsu',
#  'afgiimmnorr',
#  'acghimnoopr',
#  'aegginorrsu',
#  'acgghiloopr',
#  'aeeghmoprrt',
#  'acghiopprty',
#  'aeghopprrss',
#  'ahhilmopsty',
#  'aabeehklrrt',
#  'aacdehinppr',
#  'achhioopprt',
#  'achioopprtt',
#  'adeeehnrsst',
#  'accehiilott',
#  'beeehillnor',
#  'aehhimoprty',
#  'aeehiimprss',
#  'accehiloopt',
#  'aehmoopstty',
#  'adehiloppty',
#  'aceehillrty',
#  'aceehimortt',
#  'ceeehilortt',
#  'deehmoorrty',
#  'aeehhoprtty',
#  'adeehlooprt',
#  'cdehilnoort',
#  'eeghmnooosu',
#  'efhlnrsstuu',
#  'acdhhiorrsy',
#  'ghilmnoosty',
#  'dehhioortyy',
#  'aeghmoprsuy',
#  'ghiloopstty',
#  'acehlloprsy',
#  'aeehilrssty',
#  'adeiiilnort',
#  'acchiiiilos',
#  'aadillortuy',
#  'acdeiillort',
#  'aaeiilmmrst',
#  'aeeeimnprtt',
#  'aeeimnoprst',
#  'aeimnoprttu',
#  'beeiilmprss',
#  'beiilmprssy',
#  'aceimnoprrt',
#  'aceiinnnost',
#  'acinnnnoost',
#  'aceinooprrt',
#  'aceiinorstv',
#  'aeegiinrttv',
#  'aaeilnrrstt',
#  'eefgiinnrrt',
#  'aeeeilnrrtv',
#  'aeilmnrttuu',
#  'aeiilnnrtty',
#  'ceeeiinnrtv',
#  'aeeilnoprtt',
#  'eeinoprrstu',
#  'eeeinprrrtt',
#  'eeinprrrttu',
#  'aceiilnorst',
#  'aeilnoprrst',
#  'abeeilnrrtv',
#  'eeeiinrrtvw',
#  'acciimnorst',
#  'aacilnorstt',
#  'aaeilnprstt',
#  'aaiilnnprst',
#  'aeeiilnrstv',
#  'ahhillopsty',
#  'abceiijlstu',
#  'aabeillmnot',
#  'aceilmmnoty',
#  'aeglmnoorty',
#  'aeilorrsstt',
#  'aciilmnortu',
#  'adeehilnort',
#  'agilmnnoosu',
#  'aabcllmorsu',
#  'aadehilmnpy',
#  'aehilmnoppy',
#  'adeimmnorst',
#  'eegimnorstu',
#  'ceehimnorst',
#  'acegillmoos',
#  'aeelmnorstv',
#  'aaceilmpstt',
#  'acehimoprtt',
#  'ceeiimorstt',
#  'aaceeimrstt',
#  'aeimooprstt',
#  'accehilmopr',
#  'acceiimmnor',
#  'aeiilmnorst',
#  'eeimoprrrst',
#  'achiiimrstt',
#  'cdeiimnorst',
#  'aacdillmnoy',
#  'cilmnnooosu',
#  'acgillmnooo',
#  'chimmnooopr',
#  'ailmnnoopst',
#  'acilmnoopty',
#  'aemmnnortuy',
#  'acghimooprt',
#  'acghimopsty',
#  'ciilmoopsty',
#  'aghimoprsty',
#  'emmnooottyy',
#  'aaehhilnptz',
#  'aabilnoorst',
#  'aaaallnopst',
#  'aaceeinnrss',
#  'aceilnooprt',
#  'eghilnoopst',
#  'ccehilnoopr',
#  'aehhnopprty',
#  'aehmnooprst',
#  'einoprrstuy',
#  'aeelnnrsstu',
#  'aceinnnoort',
#  'aceeinnortv',
#  'aeilnnnoort',
#  'aaelnnnoprt',
#  'abceeijottv',
#  'abiiillotvy',
#  'abccinorstu',
#  'acffinoostu',
#  'ceeimnoorst',
#  'acgillnooot',
#  'aeiinoprtty',
#  'abeelnopsst',
#  'acgillooopt',
#  'aeiilnorstt',
#  'aghilnooort',
#  'aeinnoosttt',
#  'ceeimoorstt',
#  'deeinossstu',
#  'aabiloortuv',
#  'deeinooprtv',
#  'aacillnopty',
#  'aaceilprsst',
#  'aciiilnpstu',
#  'achiinnoprt',
#  'aaciiloprst',
#  'aaaeghpprrr',
#  'aacehinpprr',
#  'aaachinprsu',
#  'aaeilmnprst',
#  'aaeilnprtty',
#  'acdeeiinprt',
#  'aeiinoprrtt',
#  'aeenoprrstt',
#  'adeilnnoptu',
#  'adeeimnoprt',
#  'aabeelmprtu',
#  'cdemnooppru',
#  'aeefioprrtv',
#  'aceeiipprtt',
#  'aadeeiipprt',
#  'aaeeilnpprt',
#  'eeiopprrstu',
#  ...]

# %%
[anagramBySignature[sig] for sig in sorted(anagramBySignature.keys(), key=len, reverse=True)]
# Out:
# [{'cholecystoduodenostomy', 'duodenocholecystostomy'},
#  {'hydropneumopericardium', 'pneumohydropericardium'},
#  {'anatomicopathological', 'pathologicoanatomical'},
#  {'chromophotolithograph', 'photochromolithograph'},
#  {'duodenopancreatectomy', 'pancreatoduodenectomy'},
#  {'glossolabiopharyngeal', 'labioglossopharyngeal'},
#  {'anatomicophysiologic', 'physiologicoanatomic'},
#  {'encephalomeningocele', 'meningoencephalocele'},
#  {'glossolabiolaryngeal', 'labioglossolaryngeal'},
#  {'anatomicopathologic', 'pathologicoanatomic'},
#  {'clinicopathological', 'pathologicoclinical'},
#  {'encephalomeningitis', 'meningoencephalitis'},
#  {'esophagogastrostomy', 'gastroesophagostomy'},
#  {'incontrovertibility', 'introconvertibility'},
#  {'pericardiacophrenic', 'phrenicopericardiac'},
#  {'physiopsychological', 'psychophysiological'},
#  {'chondromyxosarcoma', 'myxochondrosarcoma'},
#  {'chorioidoretinitis', 'retinochorioiditis'},
#  {'chronophotographic', 'photochronographic'},
#  {'electrothermometer', 'thermoelectrometer'},
#  {'epididymovasostomy', 'vasoepididymostomy'},
#  {'galvanothermometer', 'thermogalvanometer'},
#  {'hexakistetrahedron', 'tetrakishexahedron'},
#  {'laryngopharyngitis', 'pharyngolaryngitis'},
#  {'laryngotracheotomy', 'tracheolaryngotomy'},
#  {'neuropsychological', 'psychoneurological'},
#  {'acetmethylanilide', 'methylacetanilide'},
#  {'basiparachromatin', 'marsipobranchiata'},
#  {'calcareosiliceous', 'siliceocalcareous'},
#  {'cephalomeningitis', 'meningocephalitis'},
#  {'cerebromeningitis', 'meningocerebritis'},
#  {'chemicomechanical', 'mechanicochemical'},
#  {'chromolithography', 'lithochromography'},
#  {'chromophotography', 'photochromography'},
#  {'chronophotography', 'photochronography'},
#  {'constitutionalism', 'misconstitutional'},
#  {'dioeciopolygamous', 'polygamodioecious'},
#  {'electromagnetical', 'magnetoelectrical'},
#  {'encephalomyelitis', 'myeloencephalitis'},
#  {'hexakisoctahedron', 'octakishexahedron'},
#  {'hydropneumothorax', 'pneumohydrothorax'},
#  {'hysterolaparotomy', 'laparohysterotomy'},
#  {'hysteromyomectomy', 'myomohysterectomy'},
#  {'laryngopharyngeal', 'pharyngolaryngeal'},
#  {'microphotographic', 'photomicrographic'},
#  {'microspectroscope', 'spectromicroscope'},
#  {'misrepresentation', 'representationism'},
#  {'pericardiopleural', 'pleuropericardial'},
#  {'antibenzaldoxime', 'benzantialdoxime'},
#  {'arthrochondritis', 'chondroarthritis'},
#  {'autoradiographic', 'radioautographic'},
#  {'biopsychological', 'psychobiological'},
#  {'calcareocorneous', 'corneocalcareous'},
#  {'chronophotograph', 'photochronograph'},
#  {'configurationism', 'misconfiguration'},
#  {'dynamoelectrical', 'electrodynamical'},
#  {'ferrihydrocyanic', 'hydroferricyanic'},
#  {'ferrohydrocyanic', 'hydroferrocyanic'},
#  {'fibromyxosarcoma', 'myxofibrosarcoma'},
#  {'glycerophosphate', 'phosphoglycerate'},
#  {'heliophotography', 'photoheliography'},
#  {'hemopneumothorax', 'pneumohemothorax'},
#  {'incontrovertible', 'introconvertible'},
#  {'intestinovesical', 'vesicointestinal'},
#  {'laparosplenotomy', 'splenolaparotomy'},
#  {'lithophotography', 'photolithography'},
#  {'meningomyelocele', 'myelomeningocele'},
#  {'microphotography', 'photomicrography'},
#  {'monopersulphuric', 'permonosulphuric'},
#  {'occipitotemporal', 'temporooccipital'},
#  {'parietosquamosal', 'squamosoparietal'},
#  {'pectinatopinnate', 'pinnatopectinate'},
#  {'petrographically', 'pterylographical'},
#  {'pharyngorhinitis', 'rhinopharyngitis'},
#  {'photostereograph', 'stereophotograph'},
#  {'phototelegraphic', 'telephotographic'},
#  {'physiopsychology', 'psychophysiology'},
#  {'psychotechnology', 'technopsychology'},
#  {'pyeloureterogram', 'ureteropyelogram'},
#  {'sacculoutricular', 'utriculosaccular'},
#  {'somatosplanchnic', 'splanchnosomatic'},
#  {'spectrotelescope', 'telespectroscope'},
#  {'streptothricosis', 'streptotrichosis'},
#  {'abdominovaginal', 'vaginoabdominal'},
#  {'abdominovesical', 'vesicoabdominal'},
#  {'aluminosilicate', 'silicoaluminate'},
#  {'autoradiography', 'radioautography'},
#  {'barothermograph', 'thermobarograph'},
#  {'biosociological', 'sociobiological'},
#  {'chemicophysical', 'physicochemical'},
#  {'cinematographer', 'megachiropteran'},
#  {'columbotitanate', 'titanocolumbate'},
#  {'conservationist', 'conversationist'},
#  {'constructionism', 'misconstruction'},
#  {'cystourethritis', 'urethrocystitis'},
#  {'dactylopteridae', 'pterodactylidae'},
#  {'dermatoneurosis', 'neurodermatosis'},
#  {'dextrosinistral', 'sinistrodextral'},
#  {'ecclesiasticism', 'misecclesiastic'},
#  {'electromagnetic', 'magnetoelectric'},
#  {'enterogastritis', 'gastroenteritis'},
#  {'ethmosphenoidal', 'sphenoethmoidal'},
#  {'frontooccipital', 'occipitofrontal'},
#  {'germanification', 'remagnification'},
#  {'gramophonically', 'monographically', 'nomographically', 'phonogramically'},
#  {'hexatetrahedron', 'tetrahexahedron'},
#  {'imperscriptible', 'imprescriptible'},
#  {'impressibleness', 'permissibleness'},
#  {'inferoposterior', 'posteroinferior'},
#  {'lithonephrotomy', 'nephrolithotomy'},
#  {'macrophotograph', 'photomacrograph'},
#  {'meningomyelitis', 'myelomeningitis'},
#  {'microphotograph', 'photomicrograph'},
#  {'microphotoscope', 'photomicroscope'},
#  {'microradiometer', 'radiomicrometer'},
#  {'misunderstander', 'remisunderstand'},
#  {'parietotemporal', 'temporoparietal'},
#  {'parietovisceral', 'visceroparietal'},
#  {'phototelegraphy', 'telephotography'},
#  {'phototypography', 'phytotopography'},
#  {'pneumopyothorax', 'pyopneumothorax'},
#  {'posterosuperior', 'superoposterior'},
#  {'pretransmission', 'transimpression'},
#  {'silicotungstate', 'tungstosilicate'},
#  {'stereotelescope', 'telestereoscope'},
#  {'sternovertebral', 'vertebrosternal'},
#  {'uncreatableness', 'untraceableness'},
#  {'adenochondroma', 'chondroadenoma'},
#  {'altitudinarian', 'latitudinarian'},
#  {'angiochondroma', 'chondroangioma'},
#  {'antarchistical', 'charlatanistic'},
#  {'anteroinferior', 'inferoanterior'},
#  {'anterosuperior', 'superoanterior'},
#  {'associationism', 'misassociation'},
#  {'autoradiograph', 'radioautograph'},
#  {'blastomycetous', 'cytoblastemous'},
#  {'borofluohydric', 'hydrofluoboric'},
#  {'carcinosarcoma', 'sarcocarcinoma'},
#  {'cervicovesical', 'vesicocervical'},
#  {'chloroplatinic', 'platinochloric'},
#  {'chondrofibroma', 'fibrochondroma'},
#  {'conservational', 'conversational'},
#  {'constitutioner', 'reconstitution'},
#  {'costovertebral', 'vertebrocostal'},
#  {'cystonephrosis', 'nephrocystosis'},
#  {'dentatoserrate', 'serratodentate'},
#  {'dentatosinuate', 'sinuatodentate'},
#  {'dipterological', 'pteridological'},
#  {'dorsoventrally', 'ventrodorsally'},
#  {'duodenojejunal', 'jejunoduodenal'},
#  {'dynamoelectric', 'electrodynamic'},
#  {'electrothermic', 'thermoelectric'},
#  {'erythrophyllin', 'phylloerythrin'},
#  {'extirpationist', 'sextipartition'},
#  {'frontoparietal', 'parietofrontal'},
#  {'frontotemporal', 'temporofrontal'},
#  {'galvanopsychic', 'psychogalvanic'},
#  {'geissospermine', 'spermiogenesis'},
#  {'hemiholohedral', 'holohemihedral'},
#  {'herpetological', 'pretheological'},
#  {'hydronephrosis', 'nephrohydrosis'},
#  {'impressibility', 'permissibility'},
#  {'impressiveness', 'permissiveness'},
#  {'inconglomerate', 'nongeometrical'},
#  {'interpellation', 'interpollinate'},
#  {'intersectional', 'intraselection'},
#  {'interspiration', 'repristination'},
#  {'ludicroserious', 'serioludicrous'},
#  {'medicophysical', 'physicomedical'},
#  {'metrophlebitis', 'phlebometritis'},
#  {'misrepresenter', 'remisrepresent'},
#  {'naturistically', 'unartistically'},
#  {'nephropyelitis', 'pyelonephritis'},
#  {'neuropsychosis', 'psychoneurosis'},
#  {'nondesecration', 'recondensation'},
#  {'paradisaically', 'paradisiacally'},
#  {'perineovaginal', 'vaginoperineal'},
#  {'perturbational', 'protuberantial'},
#  {'petrographical', 'pterographical'},
#  {'petrologically', 'pterylological'},
#  {'petrosquamosal', 'squamopetrosal'},
#  {'phototelegraph', 'telephotograph'},
#  {'pleurovisceral', 'visceropleural'},
#  {'prerealization', 'proletarianize'},
#  {'presentiveness', 'pretensiveness'},
#  {'protomagnesium', 'spermatogonium'},
#  {'purpuroxanthin', 'xanthopurpurin'},
#  {'radiotelephone', 'teleradiophone'},
#  {'relativization', 'revitalization'},
#  {'rotundifoliate', 'titanofluoride'},
#  {'sacrovertebral', 'vertebrosacral'},
#  {'salinoterreous', 'soliterraneous'},
#  {'silicotitanate', 'titanosilicate'},
#  {'silicotungstic', 'tungstosilicic'},
#  {'thunderbearing', 'underbreathing'},
#  {'transamination', 'transanimation'},
#  {'unamenableness', 'unnameableness'},
#  {'aeolharmonica', 'chloroanaemia'},
#  {'aerographical', 'areographical'},
#  {'amelification', 'maleficiation'},
#  {'amplification', 'palmification'},
#  {'angiocholitis', 'cholangioitis'},
#  {'angiokeratoma', 'keratoangioma'},
#  {'anticlinorium', 'inclinatorium'},
#  {'antisoporific', 'prosification', 'sporification'},
#  {'argentiferous', 'garnetiferous'},
#  {'arthrosteitis', 'ostearthritis'},
#  {'attentiveness', 'tentativeness'},
#  {'autoheterosis', 'heteroousiast'},
#  {'beardlessness', 'breadlessness'},
#  {'benzofluorene', 'fluorobenzene'},
#  {'biopsychology', 'psychobiology'},
#  {'blastomycetic', 'cytoblastemic'},
#  {'botanophilist', 'philobotanist'},
#  {'brachiofacial', 'faciobrachial'},
#  {'buccocervical', 'cervicobuccal'},
#  {'cephalometric', 'petrochemical'},
#  {'cephalopodous', 'podocephalous'},
#  {'certification', 'cretification', 'rectification'},
#  {'certificative', 'rectificative'},
#  {'certificatory', 'rectificatory'},
#  {'cervicodorsal', 'dorsocervical'},
#  {'cervicofacial', 'faciocervical'},
#  {'cervicolabial', 'labiocervical'},
#  {'cheatableness', 'teachableness'},
#  {'cholesteremia', 'heteroecismal'},
#  {'chondrocostal', 'costochondral'},
#  {'chondrolipoma', 'lipochondroma'},
#  {'chondromyxoma', 'myxochondroma'},
#  {'coloenteritis', 'enterocolitis'},
#  {'coloproctitis', 'proctocolitis'},
#  {'competitioner', 'recompetition'},
#  {'compromission', 'procommission'},
#  {'condylomatous', 'monodactylous'},
#  {'considerative', 'devisceration'},
#  {'countertrades', 'unstercorated'},
#  {'crimelessness', 'mercilessness'},
#  {'cruroinguinal', 'inguinocrural'},
#  {'cryptostomate', 'prostatectomy'},
#  {'cystopyelitis', 'pyelocystitis'},
#  {'dactylopterus', 'pterodactylus'},
#  {'deinocephalia', 'palaeechinoid'},
#  {'demipronation', 'preadmonition', 'predomination'},
#  {'dermosclerite', 'sclerodermite'},
#  {'diageotropism', 'geodiatropism'},
#  {'diplocephalus', 'pseudophallic'},
#  {'dipterologist', 'pteridologist'},
#  {'discriminator', 'doctrinairism'},
#  {'distinguisher', 'redistinguish'},
#  {'endoarteritis', 'sideronatrite'},
#  {'ethmosphenoid', 'sphenoethmoid'},
#  {'expressionism', 'misexpression'},
#  {'frontoorbital', 'orbitofrontal'},
#  {'ganglioneuron', 'neuroganglion'},
#  {'gastrohepatic', 'hepatogastric'},
#  {'gastrophrenic', 'nephrogastric', 'phrenogastric'},
#  {'genitourinary', 'urinogenitary'},
#  {'gramophonical', 'monographical', 'nomographical'},
#  {'grandparental', 'grandpaternal'},
#  {'graphological', 'logographical'},
#  {'guarantorship', 'uranographist'},
#  {'hemicatalepsy', 'mesaticephaly'},
#  {'hepatomegalia', 'megalohepatia'},
#  {'hepatonephric', 'phrenohepatic'},
#  {'hydrosulphate', 'sulphohydrate'},
#  {'iconometrical', 'intracoelomic'},
#  {'impersonation', 'prosemination', 'semipronation'},
#  {'impressionism', 'misimpression'},
#  {'incudomalleal', 'malleoincudal'},
#  {'innovationist', 'nonvisitation'},
#  {'instructional', 'nonaltruistic'},
#  {'interactional', 'intercalation'},
#  {'intermorainic', 'recrimination'},
#  {'interspecific', 'prescientific'},
#  {'intervascular', 'vernacularist'},
#  {'investigation', 'tenovaginitis'},
#  {'lachrymonasal', 'nasolachrymal'},
#  {'lateroventral', 'ventrolateral'},
#  {'megalophonous', 'omphalogenous'},
#  {'megalosplenia', 'splenomegalia'},
#  {'micranthropos', 'promonarchist'},
#  {'micropetalous', 'somatopleuric'},
#  {'misperception', 'perceptionism'},
#  {'missuggestion', 'suggestionism'},
#  {'myeloneuritis', 'neuromyelitis'},
#  {'nephrocardiac', 'phrenocardiac'},
#  {'ornithomantic', 'orthantimonic'},
#  {'osteometrical', 'stereotomical'},
#  {'overcirculate', 'uterocervical'},
#  {'oversauciness', 'veraciousness'},
#  {'paranephritis', 'paraphrenitis'},
#  {'parasyntheton', 'thysanopteran'},
#  {'pedometrician', 'premedication'},
#  {'perambulation', 'preambulation'},
#  {'perambulatory', 'preambulatory'},
#  {'peridiastolic', 'periodicalist', 'proidealistic'},
#  {'personalistic', 'pictorialness'},
#  {'phrenosplenic', 'splenonephric', 'splenophrenic'},
#  {'pneumatophony', 'pneumonopathy'},
#  {'podostomatous', 'stomatopodous'},
#  {'prediscretion', 'redescription'},
#  {'propraetorial', 'protoperlaria'},
#  {'protosulphide', 'sulphoproteid'},
#  {'psychosomatic', 'somatopsychic'},
#  {'pyosepticemia', 'septicopyemia'},
#  {'pyosepticemic', 'septicopyemic'},
#  {'redintegrator', 'retrogradient'},
#  {'resupposition', 'superposition'},
#  {'sacrification', 'scarification'},
#  {'scorbutically', 'subcortically'},
#  {'superintender', 'unenterprised'},
#  {'unamenability', 'unnameability'},
#  {'uncertifiable', 'unrectifiable'},
#  {'unconservable', 'unconversable'},
#  {'unimpressible', 'unpermissible'},
#  {'unspecterlike', 'unspectrelike'},
#  {'unsusceptible', 'unsuspectible'},
#  {'vaginovesical', 'vesicovaginal'},
#  {'accomplisher', 'reaccomplish'},
#  {'acherontical', 'anchoretical'},
#  {'achromatinic', 'chromatician'},
#  {'acidophilous', 'aphidicolous'},
#  {'acrostically', 'socratically'},
#  {'actinopteran', 'precantation'},
#  {'acutenaculum', 'unaccumulate'},
#  {'adenocystoma', 'cystoadenoma'},
#  {'adenofibroma', 'fibroadenoma'},
#  {'adenosarcoma', 'sarcoadenoma'},
#  {'adpromission', 'proadmission'},
#  {'adrenotropic', 'incorporated'},
#  {'alcantarines', 'lancasterian'},
#  {'allothogenic', 'ethnological'},
#  {'alterability', 'bilaterality', 'relatability'},
#  {'amphitropous', 'pastophorium'},
#  {'anemographic', 'phanerogamic'},
#  {'angiofibroma', 'fibroangioma'},
#  {'anteluminary', 'unalimentary'},
#  {'anticreative', 'antireactive'},
#  {'antifriction', 'nitrifaction'},
#  {'antimosquito', 'misquotation'},
#  {'antiphonetic', 'pentathionic'},
#  {'antiprotease', 'entoparasite'},
#  {'antiroyalist', 'stationarily'},
#  {'antitropical', 'practitional'},
#  {'aphorismical', 'parochialism'},
#  {'aqueoigneous', 'igneoaqueous'},
#  {'arsenopyrite', 'pyroarsenite'},
#  {'bicarpellary', 'prebacillary'},
#  {'blepharocera', 'reproachable'},
#  {'branchiopoda', 'podobranchia'},
#  {'bromohydrate', 'hydrobromate'},
#  {'cacodaemonic', 'cacodemoniac'},
#  {'callisection', 'clinoclasite'},
#  {'calotermitid', 'dilatometric'},
#  {'capsulectomy', 'scapulectomy'},
#  {'carbohydride', 'hydrocarbide'},
#  {'cartesianism', 'sectarianism'},
#  {'caudofemoral', 'femorocaudal'},
#  {'caudolateral', 'laterocaudal'},
#  {'centrodorsal', 'dorsocentral'},
#  {'centrolineal', 'crenellation'},
#  {'ceratothecal', 'chloracetate'},
#  {'certificator', 'rectificator'},
#  {'cervicodynia', 'corycavidine'},
#  {'chapelmaster', 'spermathecal'},
#  {'chaperonless', 'proseneschal'},
#  {'cheiropodist', 'coeditorship'},
#  {'chemicovital', 'vitochemical'},
#  {'chiromancist', 'monarchistic'},
#  {'chirosophist', 'opisthorchis'},
#  {'chloroanemia', 'choleromania'},
#  {'chloroiodide', 'iodochloride'},
#  {'chromatocyte', 'thoracectomy'},
#  {'chrysography', 'psychorrhagy'},
#  {'clonicotonic', 'tonicoclonic'},
#  {'coalitionist', 'solicitation'},
#  {'collectioner', 'recollection'},
#  {'colpeurynter', 'counterreply'},
#  {'colporrhagia', 'orographical'},
#  {'commentarial', 'manometrical'},
#  {'commissioner', 'recommission'},
#  {'compenetrate', 'contemperate'},
#  {'comprehender', 'recomprehend'},
#  {'concessioner', 'reconcession'},
#  {'connoissance', 'nonaccession'},
#  {'conservation', 'conversation'},
#  {'conservative', 'conversative'},
#  {'conturbation', 'obtruncation'},
#  {'conventioner', 'reconvention'},
#  {'coprophagist', 'topographics'},
#  {'cornucopiate', 'reoccupation'},
#  {'corporealist', 'prosectorial'},
#  {'correctioner', 'recorrection'},
#  {'costosternal', 'sternocostal'},
#  {'counteracter', 'countercarte'},
#  {'countercharm', 'countermarch'},
#  {'counterguard', 'uncorrugated'},
#  {'counterpaled', 'counterplead', 'unpercolated'},
#  {'countershade', 'decantherous'},
#  {'counterstand', 'uncontrasted'},
#  {'courtiership', 'peritrichous'},
#  {'creativeness', 'reactiveness'},
#  {'creditorship', 'directorship'},
#  {'crestmoreite', 'stereometric'},
#  {'cricothyroid', 'thyrocricoid'},
#  {'crurogenital', 'genitocrural'},
#  {'cystofibroma', 'fibrocystoma'},
#  {'decimestrial', 'sedimetrical'},
#  {'delicateness', 'delicatessen'},
#  {'delimitation', 'mniotiltidae'},
#  {'demiparallel', 'imparalleled'},
#  {'dentilingual', 'indulgential', 'linguidental'},
#  {'dentolingual', 'linguodental'},
#  {'depositional', 'despoliation'},
#  {'depreciation', 'predeication'},
#  {'derivational', 'revalidation'},
#  {'dermatophone', 'herpetomonad'},
#  {'dipteraceous', 'epiceratodus'},
#  {'disadventure', 'unadvertised'},
#  {'disastimeter', 'semistriated'},
#  {'discontinuer', 'undiscretion'},
#  {'discreetness', 'discreteness'},
#  {'dorsolateral', 'laterodorsal'},
#  {'dorsoventrad', 'ventrodorsad'},
#  {'dorsoventral', 'ventrodorsal'},
#  {'empathically', 'emphatically'},
#  {'energeticist', 'energetistic'},
#  {'erythrophage', 'heterography'},
#  {'etherization', 'heterization'},
#  {'exasperation', 'xenoparasite'},
#  {'famelessness', 'selfsameness'},
#  {'femorotibial', 'tibiofemoral'},
#  {'fibroneuroma', 'neurofibroma'},
#  {'fingerflower', 'fringeflower'},
#  {'foundationer', 'refoundation'},
#  {'gallotannate', 'tannogallate'},
#  {'gastropathic', 'graphostatic'},
#  {'geohydrology', 'hydrogeology'},
#  {'glossolabial', 'labioglossal'},
#  {'gonidiferous', 'indigoferous'},
#  {'gramophonist', 'monographist'},
#  {'graphophonic', 'phonographic'},
#  {'haptophorous', 'pathophorous'},
#  {'heretication', 'theoretician'},
#  {'heterocarpus', 'urethrascope'},
#  {'heterogynous', 'thyreogenous'},
#  {'homeotypical', 'polymetochia'},
#  {'humeroradial', 'radiohumeral'},
#  {'humoralistic', 'humoristical'},
#  {'hurtlessness', 'ruthlessness'},
#  {'hypostomatic', 'somatophytic'},
#  {'hysteropathy', 'hysterophyta'},
#  {'iatraliptics', 'partialistic'},
#  {'impenetrable', 'intemperable'},
#  {'impenetrably', 'intemperably'},
#  {'importunance', 'unimportance'},
#  {'impressively', 'permissively'},
#  {'inactivation', 'vaticination'},
#  {'incomputable', 'uncompatible'},
#  {'inconsistent', 'nonscientist'},
#  {'indefinitude', 'unidentified'},
#  {'indeprivable', 'predivinable'},
#  {'indiscreetly', 'indiscretely', 'iridescently'},
#  {'inobtainable', 'nonbilabiate'},
#  {'inoperculata', 'precautional'},
#  {'intercession', 'recensionist'},
#  {'interimistic', 'trimesitinic'},
#  {'interoceptor', 'reprotection'},
#  {'interpellate', 'pantellerite'},
#  {'interproduce', 'prereduction'},
#  {'intersituate', 'tenuistriate'},
#  {'interstation', 'strontianite'},
#  {'intervention', 'introvenient'},
#  {'intolerating', 'nitrogelatin'},
#  {'irrationable', 'orbitelarian'},
#  {'irrepentance', 'pretercanine'},
#  {'ischiorectal', 'sciotherical'},
#  {'isosaccharic', 'sacroischiac'},
#  {'lactoprotein', 'protectional'},
#  {'lepidosauria', 'pliosauridae'},
#  {'lipsanotheca', 'sphacelation'},
#  {'lithonephria', 'philotherian'},
#  {'logometrical', 'metrological'},
#  {'lymphectasia', 'metaphysical'},
#  {'malacologist', 'mastological'},
#  {'manslaughter', 'slaughterman'},
#  {'matelessness', 'tamelessness'},
#  {'medioventral', 'ventromedial'},
#  {'metaphorical', 'pharmacolite'},
#  {'metronomical', 'monometrical'},
#  {'microcephaly', 'pyrochemical'},
#  {'micropterous', 'prosectorium'},
#  {'mistradition', 'traditionism'},
#  {'monocystidae', 'monocystidea'},
#  {'monophyllous', 'nomophyllous'},
#  {'monopsychism', 'psychomonism'},
#  {'morphotropic', 'protomorphic'},
#  {'multinervose', 'volunteerism'},
#  {'mythographer', 'thermography'},
#  {'narcaciontes', 'transoceanic'},
#  {'naturalistic', 'unartistical'},
#  {'nematophyton', 'tenontophyma'},
#  {'nepheloscope', 'phonelescope'},
#  {'nephological', 'phenological'},
#  {'nephrologist', 'phrenologist'},
#  {'nephropathic', 'phrenopathic'},
#  {'nephropsidae', 'praesphenoid'},
#  {'nephroptosia', 'prosiphonate'},
#  {'nephropyosis', 'pyonephrosis'},
#  {'noncertified', 'nonrectified'},
#  {'noncurantist', 'unconstraint'},
#  {'nonempirical', 'prenominical'},
#  {'nonpearlitic', 'pratincoline'},
#  {'notelessness', 'tonelessness'},
#  {'obscurantist', 'substraction'},
#  {'octastrophic', 'postthoracic'},
#  {'oligonephria', 'oligophrenia'},
#  {'oligonephric', 'oligophrenic'},
#  {'ornithoptera', 'prototherian'},
#  {'palification', 'pontificalia'},
#  {'palmatilobed', 'palmilobated'},
#  {'patroclinous', 'pratincolous'},
#  {'pelycography', 'pyrgocephaly'},
#  {'peradventure', 'preadventure'},
#  {'perceptively', 'preceptively'},
#  {'perceptually', 'preceptually'},
#  {'percontation', 'pernoctation'},
#  {'percussioner', 'repercussion'},
#  {'perfoliation', 'prefoliation'},
#  {'performative', 'preformative'},
#  {'perpetualist', 'pluriseptate'},
#  {'perviousness', 'previousness', 'viperousness'},
#  {'petrographer', 'pterographer'},
#  {'petrographic', 'pterographic'},
#  {'photographer', 'rephotograph'},
#  {'phrenocostal', 'plastochrone'},
#  {'phyllopodous', 'podophyllous'},
#  {'phytogenesis', 'pythogenesis'},
#  {'phytogenetic', 'pythogenetic'},
#  {'platysternal', 'transeptally'},
#  {'plousiocracy', 'procaciously'},
#  {'podarthritis', 'traditorship'},
#  {'poetastrical', 'spectatorial'},
#  {'policyholder', 'polychloride'},
#  {'possessioner', 'repossession'},
#  {'prasophagous', 'saprophagous'},
#  {'precipitator', 'prepatriotic'},
#  {'preconnubial', 'pronunciable'},
#  {'preconsultor', 'supercontrol'},
#  {'prediastolic', 'psiloceratid'},
#  {'presentively', 'pretensively'},
#  {'proportioner', 'reproportion'},
#  {'proreduction', 'reproduction'},
#  {'prototrophic', 'trophotropic'},
#  {'pseudelytron', 'unproselyted'},
#  {'psychotheism', 'theopsychism'},
#  {'rachianectes', 'rhacianectes'},
#  {'reattraction', 'retractation'},
#  {'rectovesical', 'vesicorectal'},
#  {'rederivation', 'veratroidine'},
#  {'reillustrate', 'ultrasterile'},
#  {'reimpression', 'repermission'},
#  {'remuneration', 'renumeration'},
#  {'repercussive', 'superservice'},
#  {'restraighten', 'straightener'},
#  {'restrengthen', 'strengthener'},
#  {'resupination', 'uranospinite'},
#  {'retransplant', 'transplanter'},
#  {'ritelessness', 'tirelessness'},
#  {'rubification', 'urbification'},
#  {'sacrificator', 'scarificator'},
#  {'salamandarin', 'salamandrian', 'salamandrina'},
#  {'sempiternous', 'supermoisten'},
#  {'serpentinous', 'supertension'},
#  {'spermatozoic', 'zoospermatic'},
#  {'sporotrichum', 'trichosporum'},
#  {'spotlessness', 'stoplessness'},
#  {'statefulness', 'tastefulness'},
#  {'stretcherman', 'trenchmaster'},
#  {'strophiolate', 'theatropolis'},
#  {'subessential', 'suitableness'},
#  {'subterraneal', 'unarrestable'},
#  {'supernacular', 'supranuclear'},
#  {'surprisement', 'trumperiness'},
#  {'swordmanship', 'wordsmanship'},
#  {'terebinthian', 'terebinthina'},
#  {'tournamental', 'ultramontane'},
#  {'unbraceleted', 'uncelebrated'},
#  {'uncatalogued', 'uncoagulated'},
#  {'unexceptable', 'unexpectable'},
#  {'unimpressive', 'unpermissive'},
#  {'unpenetrable', 'unrepentable'},
#  {'unreinstated', 'unstraitened'},
#  {'unsusceptive', 'unsuspective'},
#  {'acalyptrate', 'calyptratae'},
#  {'accelerator', 'retrocaecal'},
#  {'accessioner', 'reaccession'},
#  {'acidanthera', 'cantharidae'},
#  {'acipenserid', 'presidencia'},
#  {'acrimonious', 'isocoumarin'},
#  {'acroclinium', 'alcicornium'},
#  {'acrosticism', 'socraticism'},
#  {'acrotrophic', 'prothoracic'},
#  {'actaeonidae', 'donatiaceae'},
#  {'actinopteri', 'crepitation', 'precitation'},
#  {'adaptionism', 'adoptianism'},
#  {'adenectopic', 'pentadecoic'},
#  {'adenolipoma', 'palaemonoid'},
#  {'adorability', 'roadability'},
#  {'adrenolytic', 'declinatory'},
#  {'aecidioform', 'formicoidea'},
#  {'aerographer', 'areographer'},
#  {'aerographic', 'areographic'},
#  {'aerological', 'areological'},
#  {'aeronautism', 'measuration'},
#  {'aerostatics', 'aortectasis'},
#  {'afunctional', 'unfactional'},
#  {'alchemistic', 'hemiclastic'},
#  {'alexandrian', 'alexandrina'},
#  {'algorithmic', 'logarithmic'},
#  {'alstonidine', 'nonidealist'},
#  {'altitudinal', 'latitudinal'},
#  {'amenability', 'nameability'},
#  {'amenorrheal', 'melanorrhea'},
#  {'amidophenol', 'monodelphia'},
#  {'ammonolytic', 'commonality'},
#  {'amperemeter', 'permeameter'},
#  {'amphigenous', 'musophagine'},
#  {'amphiphloic', 'amphophilic'},
#  {'amphipodous', 'hippodamous'},
#  {'anacreontic', 'canceration'},
#  {'analeptical', 'placentalia'},
#  {'anaphorical', 'pharaonical'},
#  {'anarthropod', 'arthropodan'},
#  {'anchoretism', 'trichomanes'},
#  {'anchoritism', 'chiromantis', 'chrismation', 'harmonistic'},
#  {'anemography', 'phanerogamy'},
#  {'angelically', 'englacially'},
#  {'anhematosis', 'somasthenia'},
#  {'anhydridize', 'hydrazidine'},
#  {'anisometric', 'creationism', 'miscreation', 'ramisection', 'reactionism'},
#  {'anorthitite', 'trithionate'},
#  {'anthogenous', 'neognathous'},
#  {'antialbumid', 'balantidium'},
#  {'anticouncil', 'inculcation'},
#  {'antidotical', 'dictational'},
#  {'antiextreme', 'exterminate'},
#  {'antimallein', 'inalimental'},
#  {'antinepotic', 'pectination'},
#  {'antineutral', 'triannulate'},
#  {'antiphrasis', 'artisanship'},
#  {'antipyretic', 'pertinacity'},
#  {'antireducer', 'reincrudate', 'untraceried'},
#  {'antitorpedo', 'deportation'},
#  {'aphrodistic', 'diastrophic'},
#  {'apostrophus', 'pastophorus'},
#  {'apportioner', 'reapportion'},
#  {'appraisable', 'parablepsia'},
#  {'apprehender', 'reapprehend'},
#  {'arachidonic', 'characinoid'},
#  {'archapostle', 'thecasporal'},
#  {'archprelate', 'pretracheal'},
#  {'arenicolite', 'ricinoleate'},
#  {'ascertainer', 'reascertain', 'secretarian'},
#  {'assertional', 'sensatorial'},
#  {'asthmogenic', 'mesognathic'},
#  {'attentively', 'tentatively'},
#  {'avolitional', 'violational'},
#  {'bacteriform', 'bracteiform'},
#  {'behaviorism', 'misbehavior'},
#  {'benzonitrol', 'nitrobenzol'},
#  {'blastogenic', 'genoblastic'},
#  {'blastomeric', 'meroblastic'},
#  {'blisterwort', 'bristlewort'},
#  {'bombacaceae', 'cabombaceae'},
#  {'bosselation', 'eosinoblast'},
#  {'brachiopode', 'cardiophobe'},
#  {'broadcaster', 'rebroadcast'},
#  {'broadspread', 'spreadboard'},
#  {'calandrinae', 'calendarian'},
#  {'calculative', 'claviculate'},
#  {'calendarial', 'dalecarlian'},
#  {'calligraphy', 'graphically'},
#  {'calonectria', 'ectocranial'},
#  {'capernoited', 'deprecation'},
#  {'capillament', 'implacental'},
#  {'capillarity', 'piratically'},
#  {'carnationed', 'dinoceratan'},
#  {'carolingian', 'inorganical'},
#  {'carpocerite', 'reciprocate'},
#  {'carpogonial', 'coprolagnia'},
#  {'catapultier', 'particulate'},
#  {'caudodorsal', 'dorsocaudal'},
#  {'cavillation', 'vacillation'},
#  {'censureless', 'recluseness'},
#  {'centinormal', 'conterminal', 'nonmetrical'},
#  {'centraxonia', 'excarnation'},
#  {'centunculus', 'unsucculent'},
#  {'ceroplastic', 'cleistocarp', 'coreplastic'},
#  {'certifiable', 'rectifiable'},
#  {'cetomorphic', 'chemotropic', 'ectomorphic'},
#  {'chaenolobus', 'unchoosable'},
#  {'chaetognath', 'gnathotheca'},
#  {'chatelainry', 'trachylinae'},
#  {'chelidonate', 'endothecial'},
#  {'chemiatrist', 'chrismatite', 'theatricism'},
#  {'chiastolite', 'heliostatic'},
#  {'chionididae', 'onchidiidae'},
#  {'chiromantic', 'chromatinic'},
#  {'chiroplasty', 'polyarchist'},
#  {'chloroamine', 'melanochroi'},
#  {'chordotonal', 'notochordal'},
#  {'chorization', 'rhizoctonia', 'zonotrichia'},
#  {'chromotypic', 'cormophytic', 'mycotrophic'},
#  {'citharoedic', 'diachoretic'},
#  {'citrination', 'intrication'},
#  {'cleistogeny', 'lysogenetic'},
#  {'clericature', 'recirculate'},
#  {'clitoridean', 'directional'},
#  {'coinherence', 'incoherence'},
#  {'collationer', 'recollation'},
#  {'colonialist', 'oscillation'},
#  {'comitragedy', 'tragicomedy'},
#  {'commination', 'monamniotic'},
#  {'comparition', 'proamniotic'},
#  {'conditioner', 'recondition'},
#  {'congenerous', 'necrogenous'},
#  {'connectival', 'conventical'},
#  {'conservable', 'conversable'},
#  {'conservancy', 'conversancy'},
#  {'considerate', 'desecration'},
#  {'constructer', 'reconstruct'},
#  {'conycatcher', 'technocracy'},
#  {'copyrighter', 'recopyright'},
#  {'coriamyrtin', 'criminatory'},
#  {'corrodentia', 'recordation'},
#  {'cosmetician', 'encomiastic'},
#  {'costispinal', 'pansciolist'},
#  {'cotranspire', 'pornerastic'},
#  {'counteridea', 'decurionate'},
#  {'counterpaly', 'counterplay'},
#  {'countersale', 'counterseal'},
#  {'countertail', 'reluctation'},
#  {'countervail', 'involucrate'},
#  {'countervair', 'overcurtain', 'recurvation'},
#  {'craniectomy', 'cyanometric'},
#  {'craniognomy', 'organonymic'},
#  {'crateriform', 'terraciform'},
#  {'cratometric', 'metrocratic'},
#  {'creationary', 'reactionary'},
#  {'creationist', 'reactionist'},
#  {'crematorial', 'mercatorial'},
#  {'crenelation', 'intolerance'},
#  {'criminalese', 'misreliance'},
#  {'crocidolite', 'crocodilite'},
#  {'cryptomeria', 'imprecatory'},
#  {'cushionless', 'slouchiness'},
#  {'cyanophycin', 'phycocyanin'},
#  {'cystomyxoma', 'myxocystoma'},
#  {'dactylonomy', 'monodactyly'},
#  {'decimosexto', 'sextodecimo'},
#  {'declaration', 'redactional'},
#  {'dehortation', 'theriodonta'},
#  {'deification', 'edification'},
#  {'deificatory', 'edificatory'},
#  {'deistically', 'dialystelic'},
#  {'delusionist', 'indissolute'},
#  {'demandingly', 'maddeningly'},
#  {'demarcation', 'democratian'},
#  {'demoniacism', 'seminomadic'},
#  {'demurringly', 'murderingly'},
#  {'dentolabial', 'labiodental'},
#  {'denunciator', 'underaction'},
#  {'departition', 'partitioned', 'trepidation'},
#  {'depetticoat', 'petticoated'},
#  {'deploration', 'periodontal'},
#  {'depravingly', 'pervadingly'},
#  {'description', 'discerption'},
#  {'desiccation', 'discoactine'},
#  {'desperation', 'esperantido'},
#  {'determinant', 'detrainment'},
#  {'diamorphine', 'phronimidae'},
#  {'diaphtherin', 'diphtherian'},
#  {'diphosphate', 'phosphatide'},
#  {'dipterology', 'pteridology'},
#  {'disappearer', 'redisappear'},
#  {'discernment', 'rescindment'},
#  {'dismemberer', 'disremember'},
#  {'disparation', 'tridiapason'},
#  {'dispensable', 'piebaldness'},
#  {'divisionism', 'misdivision'},
#  {'dorsoapical', 'prosodiacal'},
#  {'dorsomedial', 'mediodorsal'},
#  {'dorsosacral', 'sacrodorsal'},
#  {'elaphomyces', 'mesocephaly'},
#  {'elytroposis', 'proteolysis'},
#  {'enarthrosis', 'nearthrosis'},
#  {'endearingly', 'engrainedly'},
#  {'endosporium', 'imponderous'},
#  {'engrailment', 'realignment'},
#  {'ensepulcher', 'ensepulchre'},
#  {'entablature', 'untreatable'},
#  {'entomophily', 'monophylite'},
#  {'entoplastic', 'spinotectal', 'tectospinal', 'tenoplastic'},
#  {'enumeration', 'mountaineer'},
#  {'enunciation', 'incuneation'},
#  {'erucivorous', 'overcurious'},
#  {'esperantism', 'strepsinema'},
#  {'ethological', 'lethologica', 'theological'},
#  {'eucalypteol', 'eucalyptole'},
#  {'eucatropine', 'neurectopia'},
#  {'evilhearted', 'vilehearted'},
#  {'examination', 'exanimation'},
#  {'festination', 'infestation', 'sinfonietta'},
#  {'fibrolipoma', 'lipofibroma'},
#  {'fibromucous', 'mucofibrous'},
#  {'fibromyxoma', 'myxofibroma'},
#  {'fibroserous', 'serofibrous'},
#  {'forwardness', 'frowardness'},
#  {'frigolabile', 'glorifiable'},
#  {'frontonasal', 'nasofrontal'},
#  {'fruticulose', 'luctiferous'},
#  {'fulminatory', 'unformality'},
#  {'gallotannic', 'tannogallic'},
#  {'gallybagger', 'gallybeggar'},
#  {'gametogenic', 'gamogenetic', 'geomagnetic'},
#  {'gastronomic', 'monogastric'},
#  {'gelatinizer', 'integralize'},
#  {'genotypical', 'ptyalogenic'},
#  {'geoisotherm', 'isogeotherm'},
#  {'geometrical', 'glaciometer'},
#  {'geotectonic', 'tocogenetic'},
#  {'geranomorph', 'monographer', 'nomographer'},
#  {'glycerinize', 'glycerizine'},
#  {'goldenmouth', 'longmouthed'},
#  {'gongoresque', 'gorgonesque'},
#  {'graminiform', 'marginiform'},
#  {'gramophonic', 'monographic', 'nomographic', 'phonogramic'},
#  {'grangousier', 'gregarinous'},
#  {'graphologic', 'logographic'},
#  {'graphometer', 'meteorgraph'},
#  {'graphotypic', 'pictography', 'typographic'},
#  {'grasshopper', 'hoppergrass'},
#  {'halophytism', 'hylopathism'},
#  {'halterbreak', 'leatherbark'},
#  {'handicapper', 'prehandicap'},
#  {'haptophoric', 'pathophoric'},
#  {'haptotropic', 'protopathic'},
#  {'heartedness', 'neatherdess'},
#  {'heliotactic', 'thiolacetic'},
#  {'helleborein', 'helleborine'},
#  {'hemiatrophy', 'hypothermia'},
#  {'hemiparesis', 'phariseeism'},
#  {'hepatocolic', 'otocephalic'},
#  {'hepatostomy', 'somatophyte'},
#  {'heptaploidy', 'typhlopidae'},
#  {'heretically', 'heterically'},
#  {'heteratomic', 'theorematic'},
#  {'heteroclite', 'heterotelic'},
#  {'heterodromy', 'hydrometeor'},
#  {'heteropathy', 'theotherapy'},
#  {'heteropodal', 'prelatehood'},
#  {'holocentrid', 'lechriodont'},
#  {'homeogenous', 'homogeneous'},
#  {'hurtfulness', 'ruthfulness'},
#  {'hydrocharis', 'hydrorachis'},
#  {'hymnologist', 'smoothingly'},
#  {'hyothyreoid', 'thyreohyoid'},
#  {'hypergamous', 'museography'},
#  {'hypoglottis', 'phytologist'},
#  {'hyposcleral', 'phylloceras'},
#  {'hysteresial', 'hysteriales'},
#  {'idioretinal', 'litorinidae'},
#  {'ilioischiac', 'ischioiliac'},
#  {'illaudatory', 'laudatorily'},
#  {'illoricated', 'lacertiloid'},
#  {'immaterials', 'materialism'},
#  {'impenetrate', 'intemperate'},
#  {'impersonate', 'proseminate'},
#  {'importunate', 'permutation'},
#  {'impressible', 'permissible'},
#  {'impressibly', 'permissibly'},
#  {'improcreant', 'preromantic'},
#  {'incensation', 'inscenation'},
#  {'inconsonant', 'nonsanction'},
#  {'incorporate', 'procreation'},
#  {'insectivora', 'visceration'},
#  {'integrative', 'vertiginate', 'vinaigrette'},
#  {'interastral', 'intertarsal'},
#  {'interfering', 'interfinger'},
#  {'interleaver', 'reverential'},
#  {'intermutual', 'ultraminute'},
#  {'internality', 'itinerantly'},
#  {'internecive', 'reincentive'},
#  {'interpolate', 'triantelope'},
#  {'interposure', 'neuropteris'},
#  {'interpreter', 'reinterpret'},
#  {'interrupter', 'reinterrupt'},
#  {'intersocial', 'orleanistic', 'sclerotinia'},
#  {'intersporal', 'tripersonal'},
#  {'interverbal', 'invertebral'},
#  {'interviewer', 'reinterview'},
#  {'intracosmic', 'narcoticism'},
#  {'intracostal', 'stratonical'},
#  {'intraseptal', 'paternalist', 'prenatalist'},
#  {'intraspinal', 'pinnitarsal'},
#  {'inversatile', 'serviential'},
#  {'isophthalyl', 'lithophysal'},
#  {'jebusitical', 'justiciable'},
#  {'labiomental', 'mentolabial'},
#  {'laminectomy', 'metonymical'},
#  {'laryngotome', 'maternology'},
#  {'latirostres', 'setirostral'},
#  {'latrocinium', 'tourmalinic'},
#  {'leonhardite', 'lionhearted'},
#  {'longanimous', 'longimanous'},
#  {'lumbosacral', 'sacrolumbal'},
#  {'lymphadenia', 'nymphalidae'},
#  {'lymphopenia', 'polyphemian'},
#  {'memorandist', 'moderantism', 'semidormant'},
#  {'mentigerous', 'tergeminous'},
#  {'merosthenic', 'microsthene'},
#  {'mesological', 'semological'},
#  {'mesoventral', 'ventromesal'},
#  {'metaplastic', 'palmatisect'},
#  {'metatrophic', 'metropathic'},
#  {'meteoristic', 'meteoritics'},
#  {'metrectasia', 'remasticate'},
#  {'metroptosia', 'prostomiate'},
#  {'microcephal', 'prochemical'},
#  {'microcinema', 'microcnemia'},
#  {'misrelation', 'orientalism', 'relationism'},
#  {'misreporter', 'reporterism'},
#  {'mithraicist', 'mithraistic'},
#  {'modernistic', 'monstricide'},
#  {'monadically', 'nomadically'},
#  {'monoclinous', 'monoclonius'},
#  {'monological', 'nomological'},
#  {'monomorphic', 'morphonomic'},
#  {'monoplanist', 'postnominal'},
#  {'monotypical', 'toponymical'},
#  {'monumentary', 'unmomentary'},
#  {'motographic', 'tomographic'},
#  {'mycophagist', 'phagocytism'},
#  {'myocolpitis', 'polysomitic'},
#  {'myographist', 'pythagorism'},
#  {'myotenotomy', 'tenomyotomy'},
#  {'naphthalize', 'phthalazine'},
#  {'nasoorbital', 'orbitonasal'},
#  {'nasopalatal', 'palatonasal'},
#  {'necessarian', 'renaissance'},
#  {'neotropical', 'percolation'},
#  {'nephologist', 'phenologist'},
#  {'nephrocolic', 'phrenocolic'},
#  {'nephropathy', 'phrenopathy'},
#  {'nephrostoma', 'strophomena'},
#  {'neurotripsy', 'tripyrenous'},
#  {'neutralness', 'unalertness'},
#  {'noncreation', 'nonreaction'},
#  {'noncreative', 'nonreactive'},
#  {'nonoriental', 'nonrelation'},
#  {'nonparental', 'nonpaternal'},
#  {'objectative', 'objectivate'},
#  {'obliviality', 'violability'},
#  {'obscurantic', 'subnarcotic'},
#  {'offuscation', 'suffocation'},
#  {'oncosimeter', 'semicoronet'},
#  {'ontological', 'tonological'},
#  {'opiniatrety', 'petitionary'},
#  {'optableness', 'potableness'},
#  {'optological', 'topological'},
#  {'orientalist', 'relationist'},
#  {'orthogonial', 'orthologian'},
#  {'ostentation', 'tionontates'},
#  {'osteometric', 'stereotomic'},
#  {'outsideness', 'tediousness'},
#  {'ovariotubal', 'tuboovarial'},
#  {'overpointed', 'predevotion'},
#  {'pactionally', 'polyactinal'},
#  {'palaestrics', 'paracelsist'},
#  {'paniculitis', 'paulinistic'},
#  {'panornithic', 'rhaponticin'},
#  {'paracolitis', 'piscatorial'},
#  {'paragrapher', 'reparagraph'},
#  {'paranephric', 'paraphrenic'},
#  {'parasuchian', 'unpharasaic'},
#  {'parentalism', 'paternalism'},
#  {'parentality', 'paternality'},
#  {'parenticide', 'preindicate'},
#  {'partitioner', 'repartition'},
#  {'paternoster', 'prosternate', 'transportee'},
#  {'pendulation', 'pennatuloid'},
#  {'pentameroid', 'predominate'},
#  {'perambulate', 'preambulate'},
#  {'percompound', 'precompound'},
#  {'perforative', 'prefavorite'},
#  {'peripatetic', 'precipitate'},
#  {'peripatidae', 'peripatidea'},
#  {'periplaneta', 'prepalatine'},
#  {'peripterous', 'prepositure'},
#  ...]

# %%
sorted(anagramBySignature.values(), key=len, reverse=True)
# Out:
# [{'angor',
#   'argon',
#   'goran',
#   'grano',
#   'groan',
#   'nagor',
#   'orang',
#   'organ',
#   'rogan',
#   'ronga'},
#  {'elaps',
#   'lapse',
#   'lepas',
#   'pales',
#   'salep',
#   'saple',
#   'sepal',
#   'slape',
#   'spale',
#   'speal'},
#  {'armet',
#   'mater',
#   'merat',
#   'metra',
#   'ramet',
#   'tamer',
#   'terma',
#   'trame',
#   'trema'},
#  {'asteer',
#   'easter',
#   'eastre',
#   'reseat',
#   'saeter',
#   'seater',
#   'staree',
#   'teaser',
#   'teresa'},
#  {'caret',
#   'carte',
#   'cater',
#   'crate',
#   'creat',
#   'creta',
#   'react',
#   'recta',
#   'trace'},
#  {'ester',
#   'estre',
#   'reest',
#   'reset',
#   'steer',
#   'stere',
#   'stree',
#   'terse',
#   'tsere'},
#  {'ante', 'aten', 'etna', 'nate', 'neat', 'taen', 'tane', 'tean'},
#  {'arist', 'astir', 'sitar', 'stair', 'stria', 'tarsi', 'tisar', 'trias'},
#  {'laster',
#   'lastre',
#   'rastle',
#   'relast',
#   'resalt',
#   'salter',
#   'slater',
#   'stelar'},
#  {'leapt', 'palet', 'patel', 'pelta', 'petal', 'plate', 'pleat', 'tepal'},
#  {'abel', 'able', 'albe', 'bale', 'beal', 'bela', 'blae'},
#  {'acinar', 'arnica', 'canari', 'carian', 'carina', 'crania', 'narica'},
#  {'acrolein',
#   'arecolin',
#   'caroline',
#   'colinear',
#   'cornelia',
#   'creolian',
#   'lonicera'},
#  {'agnel', 'angel', 'angle', 'galen', 'genal', 'glean', 'lagen'},
#  {'albeit', 'albite', 'baltei', 'belait', 'betail', 'bletia', 'libate'},
#  {'aldern', 'darnel', 'enlard', 'lander', 'lenard', 'randle', 'reland'},
#  {'alem', 'alme', 'lame', 'leam', 'male', 'meal', 'mela'},
#  {'alert', 'alter', 'artel', 'later', 'ratel', 'taler', 'telar'},
#  {'alien', 'aline', 'anile', 'elain', 'elian', 'laine', 'linea'},
#  {'argel', 'ergal', 'garle', 'glare', 'lager', 'large', 'regal'},
#  {'aril', 'lair', 'lari', 'liar', 'lira', 'rail', 'rial'},
#  {'arpent', 'enrapt', 'entrap', 'panter', 'parent', 'pretan', 'trepan'},
#  {'atle', 'laet', 'late', 'leat', 'tael', 'tale', 'teal'},
#  {'canter', 'creant', 'cretan', 'nectar', 'recant', 'tanrec', 'trance'},
#  {'darter', 'dartre', 'redart', 'retard', 'retrad', 'tarred', 'trader'},
#  {'dater', 'derat', 'detar', 'drate', 'rated', 'trade', 'tread'},
#  {'easting', 'gainset', 'genista', 'ingesta', 'seating', 'signate', 'teasing'},
#  {'emir', 'imer', 'mire', 'reim', 'remi', 'riem', 'rime'},
#  {'entrail', 'latiner', 'latrine', 'ratline', 'reliant', 'retinal', 'trenail'},
#  {'least', 'setal', 'slate', 'stale', 'steal', 'stela', 'tales'},
#  {'lepra', 'paler', 'parel', 'parle', 'pearl', 'perla', 'relap'},
#  {'abord', 'bardo', 'board', 'broad', 'dobra', 'dorab'},
#  {'acher', 'arche', 'chare', 'chera', 'rache', 'reach'},
#  {'acrid', 'caird', 'carid', 'darci', 'daric', 'dirca'},
#  {'actor', 'corta', 'croat', 'rocta', 'taroc', 'troca'},
#  {'adin', 'andi', 'dain', 'dani', 'dian', 'naid'},
#  {'agroan', 'angora', 'anogra', 'arango', 'argoan', 'onagra'},
#  {'aitch', 'chait', 'chati', 'chita', 'taich', 'tchai'},
#  {'alban', 'balan', 'banal', 'laban', 'nabal', 'nabla'},
#  {'alcor', 'calor', 'carlo', 'carol', 'claro', 'coral'},
#  {'aldine', 'daniel', 'delian', 'denial', 'enalid', 'leadin'},
#  {'alen', 'lane', 'lean', 'lena', 'nael', 'neal'},
#  {'alerse', 'leaser', 'reales', 'resale', 'reseal', 'sealer'},
#  {'alevin', 'alvine', 'valine', 'veinal', 'venial', 'vineal'},
#  {'altair', 'atrail', 'atrial', 'lariat', 'latria', 'talari'},
#  {'amen', 'enam', 'mane', 'mean', 'name', 'nema'},
#  {'amil', 'amli', 'lima', 'mail', 'mali', 'mila'},
#  {'amin', 'main', 'mani', 'mian', 'mina', 'naim'},
#  {'amir', 'irma', 'mari', 'mira', 'rami', 'rima'},
#  {'angler', 'arleng', 'garnel', 'largen', 'rangle', 'regnal'},
#  {'angrite', 'granite', 'ingrate', 'tangier', 'tearing', 'tigrean'},
#  {'anis', 'nais', 'nasi', 'nias', 'sain', 'sina'},
#  {'antu', 'aunt', 'naut', 'taun', 'tuan', 'tuna'},
#  {'apert', 'pater', 'peart', 'prate', 'taper', 'terap'},
#  {'aspen', 'panse', 'snape', 'sneap', 'spane', 'spean'},
#  {'asper', 'parse', 'prase', 'spaer', 'spare', 'spear'},
#  {'aster', 'serta', 'stare', 'strae', 'tarse', 'teras'},
#  {'asterin', 'eranist', 'restain', 'stainer', 'starnie', 'stearin'},
#  {'ates', 'east', 'eats', 'sate', 'seat', 'seta'},
#  {'balder', 'bardel', 'bedlar', 'bedral', 'belard', 'blader'},
#  {'beround', 'bounder', 'rebound', 'unbored', 'unorbed', 'unrobed'},
#  {'caliver', 'caviler', 'claiver', 'clavier', 'valeric', 'velaric'},
#  {'casper', 'escarp', 'parsec', 'scrape', 'secpar', 'spacer'},
#  {'cerotin', 'cointer', 'cotrine', 'cretion', 'noticer', 'rection'},
#  {'clethra', 'latcher', 'ratchel', 'relatch', 'talcher', 'trachle'},
#  {'corset', 'cortes', 'coster', 'escort', 'scoter', 'sector'},
#  {'danuri', 'diurna', 'dunair', 'durain', 'durani', 'durian'},
#  {'darin', 'dinar', 'drain', 'indra', 'nadir', 'ranid'},
#  {'degrain', 'deraign', 'deringa', 'gradine', 'grained', 'reading'},
#  {'derange', 'enraged', 'gardeen', 'gerenda', 'grandee', 'grenade'},
#  {'earthen', 'enheart', 'hearten', 'naether', 'teheran', 'traheen'},
#  {'elon', 'enol', 'leno', 'leon', 'lone', 'noel'},
#  {'esker', 'keres', 'reesk', 'seker', 'skeer', 'skere'},
#  {'evil', 'levi', 'live', 'veil', 'vile', 'vlei'},
#  {'gater', 'grate', 'great', 'greta', 'retag', 'targe'},
#  {'grein', 'inger', 'nigre', 'regin', 'reign', 'ringe'},
#  {'halse', 'leash', 'selah', 'shale', 'sheal', 'shela'},
#  {'inset', 'neist', 'snite', 'stein', 'stine', 'tsine'},
#  {'israel', 'relais', 'resail', 'sailer', 'serail', 'serial'},
#  {'iter', 'reit', 'rite', 'teri', 'tier', 'tire'},
#  {'mano', 'moan', 'mona', 'noam', 'noma', 'oman'},
#  {'mate', 'meat', 'meta', 'tame', 'team', 'tema'},
#  {'owser', 'resow', 'serow', 'sower', 'swore', 'worse'},
#  {'palster', 'persalt', 'plaster', 'psalter', 'spartle', 'stapler'},
#  {'pearlet', 'pleater', 'prelate', 'ptereal', 'replate', 'repleat'},
#  {'petrous', 'posture', 'proetus', 'proteus', 'septuor', 'spouter'},
#  {'poter', 'prote', 'repot', 'tepor', 'toper', 'trope'},
#  {'reins', 'resin', 'rinse', 'risen', 'serin', 'siren'},
#  {'resaw', 'sawer', 'seraw', 'sware', 'swear', 'warse'},
#  {'roset', 'rotse', 'soter', 'stero', 'store', 'torse'},
#  {'sawt', 'staw', 'swat', 'taws', 'twas', 'wast'},
#  {'abler', 'baler', 'belar', 'blare', 'blear'},
#  {'abrin', 'bairn', 'brain', 'brian', 'rabin'},
#  {'acer', 'acre', 'care', 'crea', 'race'},
#  {'acetoin', 'aconite', 'anoetic', 'antoeci', 'cetonia'},
#  {'achor', 'chora', 'corah', 'orach', 'roach'},
#  {'acrite', 'arcite', 'tercia', 'triace', 'tricae'},
#  {'actioner', 'anerotic', 'ceration', 'creation', 'reaction'},
#  {'adet', 'date', 'tade', 'tead', 'teda'},
#  {'adlet', 'dealt', 'delta', 'lated', 'taled'},
#  {'admire', 'armied', 'damier', 'dimera', 'merida'},
#  {'adrian', 'andira', 'andria', 'radian', 'randia'},
#  {'aer', 'are', 'ear', 'era', 'rea'},
#  {'agen', 'gaen', 'gane', 'gean', 'gena'},
#  {'ager', 'agre', 'gare', 'gear', 'rage'},
#  {'agon', 'ango', 'gaon', 'goan', 'gona'},
#  {'ahet', 'haet', 'hate', 'heat', 'thea'},
#  {'airman', 'amarin', 'marian', 'marina', 'mirana'},
#  {'alarm', 'malar', 'maral', 'marla', 'ramal'},
#  {'aletris', 'alister', 'listera', 'realist', 'saltier'},
#  {'algin', 'align', 'langi', 'liang', 'linga'},
#  {'algum', 'almug', 'glaum', 'gluma', 'mulga'},
#  {'alin', 'anil', 'lain', 'lina', 'nail'},
#  {'along', 'gonal', 'lango', 'longa', 'nogal'},
#  {'alpen', 'nepal', 'panel', 'penal', 'plane'},
#  {'alsine', 'neslia', 'saline', 'selina', 'silane'},
#  {'altern', 'antler', 'learnt', 'rental', 'ternal'},
#  {'alterne', 'enteral', 'eternal', 'teleran', 'teneral'},
#  {'alur', 'laur', 'lura', 'raul', 'ural'},
#  {'amain', 'amani', 'amnia', 'anima', 'mania'},
#  {'amber', 'bearm', 'bemar', 'bream', 'embar'},
#  {'ambler', 'blamer', 'lamber', 'marble', 'ramble'},
#  {'amiles', 'asmile', 'mesail', 'mesial', 'samiel'},
#  {'amino', 'inoma', 'naomi', 'omani', 'omina'},
#  {'amor', 'maro', 'mora', 'omar', 'roam'},
#  {'anadrom', 'madrona', 'mandora', 'monarda', 'roadman'},
#  {'androl', 'arnold', 'lardon', 'roland', 'ronald'},
#  {'aneretic', 'centiare', 'creatine', 'increate', 'iterance'},
#  {'anergic', 'garnice', 'garniec', 'geranic', 'grecian'},
#  {'anesis', 'anseis', 'sanies', 'sansei', 'sasine'},
#  {'anglist', 'lasting', 'salting', 'slating', 'staling'},
#  {'anisometric', 'creationism', 'miscreation', 'ramisection', 'reactionism'},
#  {'antimeter', 'attermine', 'interteam', 'terminate', 'tetramine'},
#  {'aper', 'pare', 'pear', 'rape', 'reap'},
#  {'apertly', 'peartly', 'platery', 'pteryla', 'taperly'},
#  {'aphis', 'apish', 'hispa', 'saiph', 'spahi'},
#  {'arati', 'atria', 'riata', 'tarai', 'tiara'},
#  {'arches', 'chaser', 'eschar', 'recash', 'search'},
#  {'arculite', 'cutleria', 'lucretia', 'reticula', 'treculia'},
#  {'ared', 'daer', 'dare', 'dear', 'read'},
#  {'arenig', 'earing', 'gainer', 'reagin', 'regain'},
#  {'arite', 'artie', 'irate', 'retia', 'tarie'},
#  {'arles', 'arsle', 'laser', 'seral', 'slare'},
#  {'arline', 'larine', 'linear', 'nailer', 'renail'},
#  {'armenic', 'carmine', 'ceriman', 'crimean', 'mercian'},
#  {'arni', 'iran', 'nair', 'rain', 'rani'},
#  {'arrect', 'carter', 'crater', 'recart', 'tracer'},
#  {'arse', 'rase', 'sare', 'sear', 'sera'},
#  {'arsonite', 'asterion', 'oestrian', 'rosinate', 'serotina'},
#  {'artesian', 'asterina', 'asternia', 'erastian', 'seatrain'},
#  {'artlet', 'latter', 'rattle', 'tartle', 'tatler'},
#  {'arvel', 'larve', 'laver', 'ravel', 'velar'},
#  {'ascot', 'coast', 'costa', 'tacso', 'tasco'},
#  {'ascula', 'calusa', 'casual', 'casula', 'causal'},
#  {'aspire', 'paries', 'praise', 'sirpea', 'spirea'},
#  {'astride', 'diaster', 'disrate', 'restiad', 'staired'},
#  {'ate', 'eat', 'eta', 'tae', 'tea'},
#  {'ateles', 'saltee', 'sealet', 'stelae', 'teasel'},
#  {'atingle', 'gelatin', 'genital', 'langite', 'telinga'},
#  {'atomics', 'catoism', 'cosmati', 'osmatic', 'somatic'},
#  {'atroscine', 'certosina', 'ostracine', 'tinoceras', 'tricosane'},
#  {'atter', 'tater', 'teart', 'tetra', 'treat'},
#  {'auncel', 'cuneal', 'lacune', 'launce', 'unlace'},
#  {'balor', 'bolar', 'boral', 'labor', 'lobar'},
#  {'beater', 'berate', 'betear', 'rebate', 'rebeat'},
#  {'calepin', 'capelin', 'panicle', 'pelican', 'pinacle'},
#  {'calker', 'lacker', 'rackle', 'recalk', 'reckla'},
#  {'calmer', 'carmel', 'clamer', 'marcel', 'mercal'},
#  {'cameral', 'caramel', 'carmela', 'ceramal', 'reclama'},
#  {'caner', 'crane', 'crena', 'nacre', 'rance'},
#  {'caper', 'crape', 'pacer', 'perca', 'recap'},
#  {'carlet', 'cartel', 'claret', 'rectal', 'talcer'},
#  {'carole', 'coaler', 'coelar', 'oracle', 'recoal'},
#  {'carse', 'caser', 'ceras', 'scare', 'scrae'},
#  {'centiar', 'certain', 'citrean', 'nacrite', 'nectria'},
#  {'cereus', 'ceruse', 'recuse', 'rescue', 'secure'},
#  {'cerion', 'coiner', 'neroic', 'orcein', 'recoin'},
#  {'cheater', 'hectare', 'recheat', 'reteach', 'teacher'},
#  {'citadel', 'deltaic', 'dialect', 'edictal', 'lactide'},
#  {'cleat', 'eclat', 'ectal', 'lacet', 'tecla'},
#  {'connarite', 'container', 'cotarnine', 'crenation', 'narcotine'},
#  {'crepis', 'cripes', 'persic', 'precis', 'spicer'},
#  {'dail', 'dali', 'dial', 'laid', 'lida'},
#  {'daimen', 'damine', 'maiden', 'median', 'medina'},
#  {'dais', 'dasi', 'disa', 'said', 'sida'},
#  {'dale', 'deal', 'lade', 'lead', 'leda'},
#  {'darger', 'gerard', 'grader', 'redrag', 'regard'},
#  {'darner', 'darren', 'errand', 'rander', 'redarn'},
#  {'dealer', 'leader', 'redeal', 'relade', 'relead'},
#  {'deary', 'deray', 'rayed', 'ready', 'yeard'},
#  {'deer', 'dere', 'dree', 'rede', 'reed'},
#  {'detail', 'dietal', 'dilate', 'edital', 'tailed'},
#  {'diet', 'dite', 'edit', 'tide', 'tied'},
#  {'dilo', 'diol', 'doli', 'idol', 'olid'},
#  {'diopter', 'peridot', 'proetid', 'protide', 'pteroid'},
#  {'doline', 'indole', 'leonid', 'loined', 'olenid'},
#  {'drupe', 'duper', 'perdu', 'prude', 'pured'},
#  {'dungaree', 'guardeen', 'unagreed', 'underage', 'ungeared'},
#  {'dwine', 'edwin', 'wendi', 'widen', 'wined'},
#  {'earth', 'hater', 'heart', 'herat', 'rathe'},
#  {'egeran', 'enrage', 'ergane', 'genear', 'genera'},
#  {'egol', 'goel', 'loge', 'ogle', 'oleg'},
#  {'else', 'lees', 'seel', 'sele', 'slee'},
#  {'elsin', 'lenis', 'niels', 'silen', 'sline'},
#  {'enhat', 'ethan', 'nathe', 'neath', 'thane'},
#  {'ensate', 'enseat', 'santee', 'sateen', 'senate'},
#  {'ense', 'esne', 'nese', 'seen', 'snee'},
#  {'enter', 'neter', 'renet', 'terne', 'treen'},
#  {'entreat', 'ratteen', 'tarente', 'ternate', 'tetrane'},
#  {'erethic', 'etheric', 'heretic', 'heteric', 'teicher'},
#  {'ergotin', 'genitor', 'negrito', 'ogtiern', 'trigone'},
#  {'errite', 'reiter', 'retier', 'retire', 'tierer'},
#  {'estrin', 'insert', 'sinter', 'sterin', 'triens'},
#  {'ether', 'rethe', 'theer', 'there', 'three'},
#  {'evilness', 'liveness', 'veinless', 'vileness', 'vineless'},
#  {'feering', 'feigner', 'freeing', 'reefing', 'refeign'},
#  {'feil', 'file', 'leif', 'lief', 'life'},
#  {'fertil', 'filter', 'lifter', 'relift', 'trifle'},
#  {'gilder', 'girdle', 'glider', 'regild', 'ridgel'},
#  {'hart', 'rath', 'tahr', 'thar', 'trah'},
#  {'haunter', 'nauther', 'unearth', 'unheart', 'urethan'},
#  {'imperant', 'pairment', 'partimen', 'premiant', 'tripeman'},
#  {'inert', 'inter', 'niter', 'retin', 'trine'},
#  {'inseer', 'nereis', 'seiner', 'serine', 'sirene'},
#  {'lament', 'manlet', 'mantel', 'mantle', 'mental'},
#  {'lasi', 'lias', 'lisa', 'sail', 'sial'},
#  {'latent', 'latten', 'nattle', 'talent', 'tantle'},
#  {'leap', 'lepa', 'pale', 'peal', 'plea'},
#  {'levier', 'relive', 'reveil', 'revile', 'veiler'},
#  {'loam', 'loma', 'malo', 'mola', 'olam'},
#  {'lois', 'silo', 'siol', 'soil', 'soli'},
#  {'lotase', 'osteal', 'solate', 'stolae', 'talose'},
#  {'luster', 'result', 'rustle', 'sutler', 'ulster'},
#  {'manes', 'manse', 'mensa', 'samen', 'senam'},
#  {'manor', 'moran', 'norma', 'ramon', 'roman'},
#  {'maronite', 'martinoe', 'minorate', 'morenita', 'romanite'},
#  {'maund', 'munda', 'numda', 'undam', 'unmad'},
#  {'merit', 'miter', 'mitre', 'remit', 'timer'},
#  {'meros', 'mores', 'morse', 'sermo', 'smore'},
#  {'muran', 'ruman', 'unarm', 'unram', 'urman'},
#  {'nape', 'neap', 'nepa', 'pane', 'pean'},
#  {'nerita', 'ratine', 'retain', 'retina', 'tanier'},
#  {'nestor', 'sterno', 'stoner', 'strone', 'tensor'},
#  {'neuter', 'retune', 'runtee', 'tenure', 'tureen'},
#  {'nipa', 'pain', 'pani', 'pian', 'pina'},
#  {'noreast', 'rosetan', 'seatron', 'senator', 'treason'},
#  {'notal', 'ontal', 'talon', 'tolan', 'tonal'},
#  {'overt', 'rovet', 'torve', 'trove', 'voter'},
#  {'part', 'prat', 'rapt', 'tarp', 'trap'},
#  {'piaster', 'piastre', 'raspite', 'spirate', 'traipse'},
#  {'piles', 'plies', 'slipe', 'spiel', 'spile'},
#  {'pointer', 'protein', 'pterion', 'repoint', 'tropine'},
#  {'poster', 'presto', 'repost', 'respot', 'stoper'},
#  {'posterish', 'prothesis', 'sophister', 'storeship', 'tephrosis'},
#  {'rakish', 'riksha', 'shikar', 'shikra', 'sikhra'},
#  {'ravi', 'riva', 'vair', 'vari', 'vira'},
#  {'realest', 'reslate', 'resteal', 'stealer', 'teasler'},
#  {'reis', 'rise', 'seri', 'sier', 'sire'},
#  {'relost', 'reslot', 'rostel', 'sterol', 'torsel'},
#  {'revest', 'servet', 'sterve', 'verset', 'vester'},
#  {'roust', 'rusot', 'stour', 'sutor', 'torus'},
#  {'royt', 'ryot', 'tory', 'troy', 'tyro'},
#  {'rusa', 'saur', 'sura', 'ursa', 'usar'},
#  {'sart', 'star', 'stra', 'tars', 'tsar'},
#  {'skater', 'staker', 'strake', 'streak', 'tasker'},
#  {'starve', 'staver', 'strave', 'tavers', 'versta'},
#  {'undersap', 'unparsed', 'unrasped', 'unspared', 'unspread'},
#  {'underserve', 'underverse', 'undeserver', 'unreserved', 'unreversed'},
#  {'abate', 'ateba', 'batea', 'beata'},
#  {'abater', 'artabe', 'eartab', 'trabea'},
#  {'abet', 'bate', 'beat', 'beta'},
#  {'abiuret', 'aubrite', 'biurate', 'rubiate'},
#  {'abrotine', 'baritone', 'obtainer', 'reobtain'},
#  {'absi', 'bais', 'bias', 'isba'},
#  {'achen', 'chane', 'chena', 'hance'},
#  {'achete', 'hecate', 'teache', 'thecae'},
#  {'achtel', 'chalet', 'thecal', 'thecla'},
#  {'acier', 'aeric', 'ceria', 'erica'},
#  {'acker', 'caker', 'crake', 'creak'},
#  {'acor', 'caro', 'cora', 'orca'},
#  {'acred', 'cader', 'cadre', 'cedar'},
#  {'actinal', 'alantic', 'alicant', 'antical'},
#  {'adar', 'arad', 'raad', 'rada'},
#  {'addu', 'dadu', 'daud', 'duad'},
#  {'adhere', 'header', 'hedera', 'rehead'},
#  {'adherent', 'headrent', 'neatherd', 'threaden'},
#  {'adion', 'danio', 'doina', 'donia'},
#  {'admi', 'amid', 'madi', 'maid'},
#  {'adorn', 'donar', 'drona', 'radon'},
#  {'aeromantic', 'cameration', 'maceration', 'racemation'},
#  {'aery', 'eyra', 'yare', 'year'},
#  {'afteract', 'artefact', 'farcetta', 'farctate'},
#  {'agal', 'agla', 'alga', 'gala'},
#  {'agar', 'agra', 'gara', 'raga'},
#  {'aglare', 'alegar', 'galera', 'laager'},
#  {'agonic', 'angico', 'gaonic', 'goniac'},
#  {'ahorse', 'ashore', 'hoarse', 'shorea'},
#  {'ahunt', 'haunt', 'thuan', 'unhat'},
#  {'aidenn', 'andine', 'dannie', 'indane'},
#  {'aider', 'deair', 'irade', 'redia'},
#  {'aiglet', 'ligate', 'taigle', 'tailge'},
#  {'ailanto', 'alation', 'laotian', 'notalia'},
#  {'aimer', 'maire', 'marie', 'ramie'},
#  {'aint', 'anti', 'tain', 'tina'},
#  {'airt', 'rita', 'tari', 'tiar'},
#  {'aisled', 'deasil', 'ladies', 'sailed'},
#  {'ait', 'ati', 'ita', 'tai'},
#  {'ako', 'koa', 'oak', 'oka'},
#  {'alangin', 'anginal', 'anglian', 'nagnail'},
#  {'albert', 'balter', 'labret', 'tabler'},
#  {'albino', 'albion', 'alboin', 'oliban'},
#  {'alcamine', 'analcime', 'calamine', 'camelina'},
#  {'alco', 'coal', 'cola', 'loca'},
#  {'alecost', 'lactose', 'scotale', 'talcose'},
#  {'alectoris', 'sarcolite', 'sclerotia', 'sectorial'},
#  {'alectrion', 'clarionet', 'crotaline', 'locarnite'},
#  {'alef', 'feal', 'flea', 'leaf'},
#  {'aleft', 'alfet', 'fetal', 'fleta'},
#  {'aleutic', 'auletic', 'caulite', 'lutecia'},
#  {'algenib', 'bealing', 'belgian', 'bengali'},
#  {'algor', 'argol', 'goral', 'largo'},
#  {'alible', 'belial', 'labile', 'liable'},
#  {'aligner', 'engrail', 'realign', 'reginal'},
#  {'alimentic', 'antilemic', 'melanitic', 'metanilic'},
#  {'alist', 'litas', 'slait', 'talis'},
#  {'alkine', 'ilkane', 'inlake', 'inleak'},
#  {'allergy', 'gallery', 'largely', 'regally'},
#  {'alma', 'amla', 'lama', 'mala'},
#  {'almain', 'animal', 'lamina', 'manila'},
#  {'alnage', 'angela', 'galena', 'lagena'},
#  {'alod', 'dola', 'load', 'odal'},
#  {'alopecist', 'altiscope', 'epicostal', 'scapolite'},
#  {'alpestrine', 'episternal', 'interlapse', 'presential'},
#  {'alpine', 'nepali', 'penial', 'pineal'},
#  {'altar', 'artal', 'ratal', 'talar'},
#  {'altruism', 'muralist', 'traulism', 'ultraism'},
#  {'alvin', 'anvil', 'nival', 'vinal'},
#  {'alytes', 'astely', 'lysate', 'stealy'},
#  {'amacrine', 'american', 'camerina', 'cinerama'},
#  {'amadi', 'damia', 'madia', 'maida'},
#  {'amar', 'amra', 'mara', 'rama'},
#  {'amass', 'assam', 'massa', 'samas'},
#  {'amble', 'belam', 'blame', 'mabel'},
#  {'amende', 'demean', 'meaned', 'nadeem'},
#  {'amender', 'meander', 'reamend', 'reedman'},
#  {'amentia', 'aminate', 'anamite', 'animate'},
#  {'ametria', 'artemia', 'meratia', 'ramaite'},
#  {'amgarn', 'mangar', 'marang', 'ragman'},
#  {'amicron', 'marconi', 'minorca', 'romanic'},
#  {'amine', 'anime', 'maine', 'manei'},
#  {'ammi', 'imam', 'maim', 'mima'},
#  {'amsel', 'melas', 'mesal', 'samel'},
#  {'amy', 'may', 'mya', 'yam'},
#  {'anam', 'mana', 'naam', 'nama'},
#  {'anarcotin', 'cantorian', 'carnation', 'narcotina'},
#  {'anaretic', 'arcanite', 'carinate', 'craniate'},
#  {'anchor', 'archon', 'charon', 'rancho'},
#  {'anchorite', 'antechoir', 'heatronic', 'hectorian'},
#  {'anchoritism', 'chiromantis', 'chrismation', 'harmonistic'},
#  {'ande', 'dane', 'dean', 'edna'},
#  {'andorite', 'nadorite', 'ordinate', 'rodentia'},
#  {'andre', 'arend', 'daren', 'redan'},
#  {'andrew', 'redawn', 'wander', 'warden'},
#  {'anger', 'areng', 'grane', 'range'},
#  {'angled', 'dangle', 'englad', 'lagend'},
#  {'angster', 'garnets', 'nagster', 'strange'},
#  {'anicut', 'nautic', 'ticuna', 'tunica'},
#  {'anilid', 'dialin', 'dianil', 'inlaid'},
#  {'animus', 'anisum', 'anusim', 'manius'},
#  {'anisal', 'nasial', 'salian', 'salina'},
#  {'anise', 'insea', 'siena', 'sinae'},
#  {'anointer', 'inornate', 'nonirate', 'reanoint'},
#  {'anser', 'nares', 'rasen', 'snare'},
#  {'antacrid', 'cardiant', 'radicant', 'tridacna'},
#  {'antes', 'nates', 'stane', 'stean'},
#  {'anther', 'nather', 'tharen', 'thenar'},
#  {'anticor', 'carotin', 'cortina', 'ontaric'},
#  {'antimeric', 'carminite', 'criminate', 'metrician'},
#  {'antired', 'detrain', 'randite', 'trained'},
#  {'antisun', 'unsaint', 'unsatin', 'unstain'},
#  {'antre', 'arent', 'retan', 'terna'},
#  {'anuretic', 'centauri', 'centuria', 'teucrian'},
#  {'aperch', 'eparch', 'percha', 'preach'},
#  {'aphetism', 'mateship', 'shipmate', 'spithame'},
#  {'apis', 'pais', 'pasi', 'saip'},
#  {'apricot', 'atropic', 'parotic', 'patrico'},
#  {'aptly', 'patly', 'platy', 'typal'},
#  {'aptote', 'optate', 'potate', 'teapot'},
#  {'arab', 'arba', 'baar', 'bara'},
#  {'arabinic', 'cabirian', 'carabini', 'cibarian'},
#  {'arcos', 'crosa', 'oscar', 'sacro'},
#  {'arctoidean', 'carotidean', 'cordaitean', 'dinocerata'},
#  {'arctos', 'castor', 'costar', 'scrota'},
#  {'ardeb', 'beard', 'bread', 'debar'},
#  {'argent', 'garnet', 'garten', 'tanger'},
#  {'argot', 'gator', 'gotra', 'groat'},
#  {'argute', 'guetar', 'rugate', 'tuareg'},
#  {'aries', 'arise', 'raise', 'serai'},
#  {'arisen', 'arsine', 'resina', 'serian'},
#  {'aristol', 'oralist', 'ortalis', 'striola'},
#  {'armed', 'derma', 'dream', 'ramed'},
#  {'army', 'mary', 'myra', 'yarm'},
#  {'arrent', 'errant', 'ranter', 'ternar'},
#  {'arrest', 'astrer', 'raster', 'starer'},
#  {'arretine', 'eretrian', 'eritrean', 'retainer'},
#  {'arrish', 'harris', 'rarish', 'sirrah'},
#  {'arsedine', 'arsenide', 'sedanier', 'siderean'},
#  {'arsenite', 'resinate', 'teresian', 'teresina'},
#  {'arshine', 'nearish', 'rhesian', 'sherani'},
#  {'art', 'rat', 'tar', 'tra'},
#  {'arterin', 'retrain', 'terrain', 'trainer'},
#  {'arthel', 'halter', 'lather', 'thaler'},
#  {'artisan', 'astrain', 'sartain', 'tsarina'},
#  {'arustle', 'estrual', 'saluter', 'saulter'},
#  {'aryl', 'lyra', 'ryal', 'yarl'},
#  {'asarite', 'asteria', 'atresia', 'setaria'},
#  {'ascertain', 'cartesian', 'cartisane', 'sectarian'},
#  {'ascian', 'sacian', 'scania', 'sicana'},
#  {'asem', 'mesa', 'same', 'seam'},
#  {'ashanti', 'sanhita', 'shaitan', 'thasian'},
#  {'ashen', 'hanse', 'shane', 'shean'},
#  {'asker', 'reask', 'saker', 'sekar'},
#  {'aslant', 'lansat', 'natals', 'santal'},
#  {'asor', 'rosa', 'soar', 'sora'},
#  {'assertor', 'assorter', 'oratress', 'reassort'},
#  {'astern', 'enstar', 'stenar', 'sterna'},
#  {'astilbe', 'bestial', 'blastie', 'stabile'},
#  {'atenism', 'inmeats', 'insteam', 'samnite'},
#  {'atenist', 'instate', 'satient', 'steatin'},
#  {'athens', 'hasten', 'snathe', 'sneath'},
#  {'atmo', 'atom', 'moat', 'toma'},
#  {'atresy', 'estray', 'reasty', 'stayer'},
#  {'attern', 'natter', 'ratten', 'tarten'},
#  {'auld', 'dual', 'laud', 'udal'},
#  {'aver', 'rave', 'vare', 'vera'},
#  {'avert', 'tarve', 'taver', 'trave'},
#  {'awest', 'sweat', 'tawse', 'waste'},
#  {'bagel', 'belga', 'gable', 'gleba'},
#  {'bagre', 'barge', 'begar', 'rebag'},
#  {'baiter', 'barite', 'rebait', 'terbia'},
#  {'balas', 'balsa', 'basal', 'sabal'},
#  {'balu', 'baul', 'bual', 'luba'},
#  {'barbe', 'bebar', 'breba', 'rebab'},
#  {'barid', 'bidar', 'braid', 'rabid'},
#  {'barie', 'beira', 'erbia', 'rebia'},
#  {'barotse', 'boaster', 'reboast', 'sorbate'},
#  {'barse', 'besra', 'saber', 'serab'},
#  {'base', 'besa', 'sabe', 'seba'},
#  {'batel', 'blate', 'bleat', 'table'},
#  {'batter', 'bertat', 'tabret', 'tarbet'},
#  {'baun', 'buna', 'nabu', 'nuba'},
#  {'bawler', 'brelaw', 'rebawl', 'warble'},
#  {'bearing', 'begrain', 'brainge', 'rigbane'},
#  {'bearlet', 'bleater', 'elberta', 'retable'},
#  {'beid', 'bide', 'debi', 'dieb'},
#  {'beni', 'bien', 'bine', 'inbe'},
#  {'beri', 'bier', 'brei', 'ribe'},
#  {'besour', 'boreus', 'bourse', 'bouser'},
#  {'betrail', 'librate', 'triable', 'trilabe'},
#  {'betrayer', 'eatberry', 'rebetray', 'teaberry'},
#  {'bider', 'bredi', 'bride', 'rebid'},
#  {'blower', 'bowler', 'reblow', 'worble'},
#  {'bluer', 'brule', 'burel', 'ruble'},
#  {'bolo', 'bool', 'lobo', 'obol'},
#  {'bolter', 'orblet', 'reblot', 'rebolt'},
#  {'boreen', 'enrobe', 'neebor', 'rebone'},
#  {'brumal', 'labrum', 'lumbar', 'umbral'},
#  {'brut', 'burt', 'trub', 'turb'},
#  {'brute', 'buret', 'rebut', 'tuber'},
#  {'bunder', 'burden', 'burned', 'unbred'},
#  {'camel', 'clame', 'cleam', 'macle'},
#  {'camelid', 'decimal', 'declaim', 'medical'},
#  {'camion', 'conima', 'manioc', 'monica'},
#  {'camus', 'musca', 'scaum', 'sumac'},
#  {'canel', 'clean', 'lance', 'lenca'},
#  {'canister', 'cestrian', 'cisterna', 'irascent'},
#  {'cannot', 'canton', 'conant', 'nonact'},
#  {'canroy', 'crayon', 'cyrano', 'nyroca'},
#  {'canterer', 'recanter', 'recreant', 'terrance'},
#  {'cantle', 'cental', 'lancet', 'tancel'},
#  {'capitol', 'coalpit', 'optical', 'topical'},
#  {'capsian', 'caspian', 'nascapi', 'panisca'},
#  {'carbo', 'carob', 'coarb', 'cobra'},
#  {'carinal', 'carlina', 'clarain', 'cranial'},
#  {'carlie', 'claire', 'eclair', 'erical'},
#  {'carnalite', 'claretian', 'lacertian', 'nectarial'},
#  {'carolin', 'clarion', 'colarin', 'locrian'},
#  {'carom', 'coram', 'macro', 'marco'},
#  {'caterer', 'recrate', 'retrace', 'terrace'},
#  {'ceder', 'cedre', 'cered', 'creed'},
#  {'cedriret', 'directer', 'recredit', 'redirect'},
#  {'celloid', 'codille', 'collide', 'collied'},
#  {'celsian', 'escalin', 'sanicle', 'secalin'},
#  {'censer', 'scerne', 'screen', 'secern'},
#  {'centered', 'decenter', 'decentre', 'recedent'},
#  {'centerer', 'recenter', 'recentre', 'terrence'},
#  {'ceral', 'clare', 'clear', 'lacer'},
#  {'cerci', 'ceric', 'cicer', 'circe'},
#  {'cerite', 'certie', 'recite', 'tierce'},
#  {'cerous', 'course', 'crouse', 'source'},
#  {'cesare', 'crease', 'recase', 'searce'},
#  {'chaste', 'sachet', 'scathe', 'scheat'},
#  {'cheat', 'tache', 'teach', 'theca'},
#  {'chet', 'etch', 'tche', 'tech'},
#  {'chorti', 'orthic', 'thoric', 'trochi'},
#  {'cider', 'cried', 'deric', 'dicer'},
#  {'citer', 'recti', 'ticer', 'trice'},
#  {'citrene', 'enteric', 'enticer', 'tercine'},
#  {'citrine', 'crinite', 'inciter', 'neritic'},
#  {'citrus', 'curtis', 'rictus', 'rustic'},
#  {'clio', 'coil', 'coli', 'loci'},
#  {'clione', 'coelin', 'encoil', 'enolic'},
#  {'codamine', 'comedian', 'daemonic', 'demoniac'},
#  {'colleter', 'coteller', 'coterell', 'recollet'},
#  {'comedist', 'demotics', 'docetism', 'domestic'},
#  {'conter', 'cornet', 'cronet', 'roncet'},
#  {'contour', 'cornuto', 'countor', 'crouton'},
#  {'copist', 'coptis', 'optics', 'postic'},
#  {'copular', 'croupal', 'cupolar', 'porcula'},
#  {'cor', 'cro', 'orc', 'roc'},
#  {'cornuate', 'courante', 'cuneator', 'outrance'},
#  {'cornute', 'counter', 'recount', 'trounce'},
#  {'couper', 'croupe', 'poucer', 'recoup'},
#  {'craniota', 'croatian', 'narcotia', 'raincoat'},
#  {'creational', 'crotalinae', 'laceration', 'reactional'},
#  {'creedist', 'desertic', 'discreet', 'discrete'},
#  {'crenula', 'lucarne', 'nuclear', 'unclear'},
#  {'cruet', 'eruct', 'recut', 'truce'},
#  {'cunila', 'lucian', 'lucina', 'uncial'},
#  {'curial', 'lauric', 'uracil', 'uralic'},
#  {'daker', 'drake', 'kedar', 'radek'},
#  {'damner', 'manred', 'randem', 'remand'},
#  {'danakil', 'dankali', 'kaldani', 'ladakin'},
#  {'danger', 'gander', 'garden', 'ranged'},
#  {'danli', 'ladin', 'linda', 'nidal'},
#  {'datil', 'dital', 'tidal', 'tilda'},
#  {'daunter', 'unarted', 'unrated', 'untread'},
#  {'dave', 'deva', 'vade', 'veda'},
#  {'dearth', 'hatred', 'rathed', 'thread'},
#  {'deash', 'hades', 'sadhe', 'shade'},
#  {'deciatine', 'diacetine', 'taenicide', 'teniacide'},
#  {'deem', 'deme', 'mede', 'meed'},
#  {'deemer', 'meered', 'redeem', 'remede'},
#  {'dehors', 'rhodes', 'shoder', 'shored'},
#  {'deinos', 'donsie', 'inodes', 'onside'},
#  {'deirdre', 'derider', 'derride', 'ridered'},
#  {'demerit', 'dimeter', 'merited', 'mitered'},
#  {'demetrian', 'dermatine', 'meandrite', 'minareted'},
#  {'demi', 'diem', 'dime', 'mide'},
#  {'demirep', 'epiderm', 'impeder', 'remiped'},
#  {'dentin', 'indent', 'intend', 'tinned'},
#  {'depaint', 'inadept', 'painted', 'patined'},
#  {'derater', 'retrade', 'retread', 'treader'},
#  {'derision', 'ironside', 'resinoid', 'sirenoid'},
#  {'derries', 'desirer', 'resider', 'serried'},
#  {'desi', 'ides', 'seid', 'side'},
#  {'destain', 'instead', 'sainted', 'satined'},
#  {'diastole', 'isolated', 'sodalite', 'solidate'},
#  {'dier', 'dire', 'reid', 'ride'},
#  {'dimetria', 'mitridae', 'tiremaid', 'triamide'},
#  {'dine', 'enid', 'inde', 'nide'},
#  {'dingle', 'elding', 'engild', 'gilden'},
#  {'dingo', 'doing', 'gondi', 'gonid'},
#  {'diphaser', 'parished', 'raphides', 'sephardi'},
#  {'dirge', 'gride', 'redig', 'ridge'},
#  {'diurne', 'inured', 'ruined', 'unride'},
#  {'doer', 'redo', 'rode', 'roed'},
#  {'dole', 'elod', 'lode', 'odel'},
#  {'domine', 'domnei', 'emodin', 'medino'},
#  {'doomer', 'mooder', 'redoom', 'roomed'},
#  {'door', 'odor', 'oord', 'rood'},
#  {'doubter', 'obtrude', 'outbred', 'redoubt'},
#  {'dour', 'duro', 'ordu', 'roud'},
#  {'drail', 'laird', 'larid', 'liard'},
#  {'drawer', 'redraw', 'reward', 'warder'},
#  {'duer', 'dure', 'rude', 'urde'},
#  {'dulcian', 'incudal', 'lucanid', 'lucinda'},
#  {'dunal', 'laund', 'lunda', 'ulnad'},
#  {'dunger', 'gerund', 'greund', 'nudger'},
#  {'eaglet', 'legate', 'teagle', 'telega'},
#  {'earl', 'eral', 'lear', 'real'},
#  {'earthly', 'heartly', 'lathery', 'rathely'},
#  {'eburna', 'unbare', 'unbear', 'urbane'},
#  {'eciton', 'noetic', 'notice', 'octine'},
#  {'edition', 'odinite', 'otidine', 'tineoid'},
#  {'elastin', 'salient', 'saltine', 'slainte'},
#  {'elinor', 'lienor', 'lorien', 'noiler'},
#  {'elinvar', 'ravelin', 'reanvil', 'valerin'},
#  {'elsa', 'sale', 'seal', 'slae'},
#  {'emit', 'item', 'mite', 'time'},
#  {'emprise', 'imprese', 'premise', 'spireme'},
#  {'enamor', 'monera', 'oreman', 'romane'},
#  {'enapt', 'paten', 'penta', 'tapen'},
#  {'encist', 'incest', 'insect', 'scient'},
#  {'endura', 'neurad', 'undear', 'unread'},
#  {'enfile', 'enlief', 'enlife', 'feline'},
#  {'enherit', 'etherin', 'neither', 'therein'},
#  {'enif', 'fine', 'neif', 'nife'},
#  {'enisle', 'ensile', 'senile', 'silene'},
#  {'enlist', 'listen', 'silent', 'tinsel'},
#  {'enlister', 'esterlin', 'listener', 'relisten'},
#  {'enrive', 'envier', 'veiner', 'verine'},
#  {'enstore', 'estrone', 'storeen', 'tornese'},
#  {'entia', 'teian', 'tenai', 'tinea'},
#  {'entoplastic', 'spinotectal', 'tectospinal', 'tenoplastic'},
#  {'eonism', 'mesion', 'oneism', 'simeon'},
#  {'epistlar', 'pilaster', 'plaister', 'priestal'},
#  {'epistoler', 'peristole', 'perseitol', 'pistoleer'},
#  {'epos', 'peso', 'pose', 'sope'},
#  {'erection', 'neoteric', 'nocerite', 'renotice'},
#  {'ergon', 'genro', 'goner', 'negro'},
#  {'erma', 'mare', 'rame', 'ream'},
#  {'ernest', 'nester', 'resent', 'streen'},
#  {'eros', 'rose', 'sero', 'sore'},
#  {'eroticism', 'isometric', 'meroistic', 'trioecism'},
#  {'erse', 'rees', 'seer', 'sere'},
#  {'erthen', 'henter', 'nether', 'threne'},
#  {'estrange', 'segreant', 'sergeant', 'sternage'},
#  {'estrous', 'oestrus', 'sestuor', 'tussore'},
#  {'etamin', 'inmate', 'taimen', 'tamein'},
#  {'ethnal', 'hantle', 'lathen', 'thenal'},
#  {'fakir', 'fraik', 'kafir', 'rafik'},
#  {'fare', 'fear', 'frae', 'rafe'},
#  {'ferri', 'firer', 'freir', 'frier'},
#  {'fetial', 'filate', 'lafite', 'leafit'},
#  {'filer', 'flier', 'lifer', 'rifle'},
#  {'finder', 'friend', 'redfin', 'refind'},
#  {'fister', 'resift', 'sifter', 'strife'},
#  {'floret', 'forlet', 'lofter', 'torfel'},
#  {'flower', 'fowler', 'reflow', 'wolfer'},
#  {'fluent', 'netful', 'unfelt', 'unleft'},
#  {'forrue', 'fourer', 'fourre', 'furore'},
#  {'gaet', 'gate', 'geat', 'geta'},
#  {'gail', 'gali', 'gila', 'glia'},
#  {'gain', 'inga', 'naig', 'ngai'},
#  {'gaol', 'goal', 'gola', 'olga'},
#  {'gape', 'page', 'peag', 'pega'},
#  {'gaper', 'grape', 'pager', 'parge'},
#  {'gargle', 'gregal', 'lagger', 'raggle'},
#  {'garnett', 'gnatter', 'gratten', 'tergant'},
#  {'garret', 'garter', 'grater', 'targer'},
#  {'gateman', 'magenta', 'magnate', 'magneta'},
#  {'gaun', 'guan', 'guna', 'uang'},
#  {'genre', 'green', 'neger', 'reneg'},
#  {'geomant', 'magneto', 'megaton', 'montage'},
#  {'germanite', 'germinate', 'gramenite', 'mangerite'},
#  {'girsle', 'gisler', 'glires', 'grilse'},
#  {'gobelin', 'gobline', 'ignoble', 'inglobe'},
#  {'gramophonic', 'monographic', 'nomographic', 'phonogramic'},
#  {'gramophonically', 'monographically', 'nomographically', 'phonogramically'},
#  {'grantee', 'greaten', 'reagent', 'rentage'},
#  {'grateman', 'mangrate', 'mentagra', 'targeman'},
#  {'guerdoner', 'reundergo', 'undergoer', 'undergore'},
#  {'hasp', 'pash', 'psha', 'shap'},
#  {'haw', 'hwa', 'wah', 'wha'},
#  {'heaps', 'pesah', 'phase', 'shape'},
#  {'hector', 'rochet', 'tocher', 'troche'},
#  {'herpetism', 'metership', 'metreship', 'temperish'},
#  {'herse', 'sereh', 'sheer', 'shree'},
#  {'hist', 'sith', 'this', 'tshi'},
#  {'homerist', 'isotherm', 'otherism', 'theorism'},
#  {'hornet', 'nother', 'theron', 'throne'},
#  {'host', 'shot', 'thos', 'tosh'},
#  {'hypnotic', 'phytonic', 'pythonic', 'typhonic'},
#  {'idlety', 'lydite', 'tidely', 'tidley'},
#  {'imager', 'maigre', 'margie', 'mirage'},
#  {'imaret', 'metria', 'mirate', 'rimate'},
#  {'impaler', 'impearl', 'lempira', 'premial'},
#  {'indorse', 'ordines', 'siredon', 'sordine'},
#  {'ingle', 'ligne', 'linge', 'nigel'},
#  {'inkra', 'krina', 'nakir', 'rinka'},
#  {'innest', 'sennit', 'sinnet', 'tennis'},
#  {'inro', 'iron', 'noir', 'nori'},
#  {'insetter', 'interest', 'interset', 'sternite'},
#  {'insister', 'reinsist', 'sinister', 'sisterin'},
#  {'insole', 'leonis', 'lesion', 'selion'},
#  {'insoul', 'linous', 'nilous', 'unsoil'},
#  {'insult', 'sunlit', 'unlist', 'unslit'},
#  {'intercale', 'interlace', 'lacertine', 'reclinate'},
#  {'interlope', 'interpole', 'repletion', 'terpineol'},
#  {'interpone', 'peritenon', 'pinnotere', 'preintone'},
#  {'into', 'nito', 'oint', 'tino'},
#  {'intreat', 'iterant', 'nitrate', 'tertian'},
#  {'intrude', 'turdine', 'untired', 'untried'},
#  {'inventer', 'reinvent', 'ventrine', 'vintener'},
#  {'irenics', 'resinic', 'sericin', 'sirenic'},
#  {'islet', 'istle', 'slite', 'stile'},
#  {'isleta', 'litsea', 'salite', 'stelai'},
#  {'iten', 'neti', 'tien', 'tine'},
#  {'itmo', 'moit', 'omit', 'timo'},
#  {'janos', 'jason', 'jonas', 'sonja'},
#  {'karo', 'kora', 'okra', 'roka'},
#  {'kasha', 'khasa', 'sakha', 'shaka'},
#  {'kate', 'keta', 'take', 'teak'},
#  {'keest', 'skeet', 'skete', 'steek'},
#  {'kitar', 'krait', 'rakit', 'traik'},
#  {'knar', 'kran', 'nark', 'rank'},
#  {'lairman', 'laminar', 'malarin', 'railman'},
#  {'lameness', 'maleness', 'maneless', 'nameless'},
#  {'lamus', 'malus', 'musal', 'slaum'},
#  {'lascar', 'rascal', 'sacral', 'scalar'},
#  {'latite', 'tailet', 'tailte', 'talite'},
#  {'laun', 'luna', 'ulna', 'unal'},
#  {'lave', 'vale', 'veal', 'vela'},
#  {'laveer', 'leaver', 'reveal', 'vealer'},
#  {'leaper', 'releap', 'repale', 'repeal'},
#  {'leet', 'lete', 'teel', 'tele'},
#  {'lenora', 'loaner', 'orlean', 'reloan'},
#  {'lepanto', 'nepotal', 'petalon', 'polenta'},
#  {'leproma', 'palermo', 'pleroma', 'polearm'},
#  {'levir', 'liver', 'livre', 'rivel'},
#  {'levo', 'love', 'velo', 'vole'},
#  {'lien', 'line', 'neil', 'nile'},
#  {'limean', 'maline', 'melian', 'menial'},
#  {'limes', 'miles', 'slime', 'smile'},
#  {'lino', 'lion', 'loin', 'noil'},
#  {'lipa', 'pail', 'pali', 'pial'},
#  {'lirate', 'retail', 'retial', 'tailer'},
#  {'lisper', 'pliers', 'sirple', 'spiler'},
#  {'lite', 'teil', 'teli', 'tile'},
#  {'litster', 'slitter', 'stilter', 'testril'},
#  {'looter', 'retool', 'rootle', 'tooler'},
#  {'loro', 'olor', 'orlo', 'rool'},
#  {'loser', 'orsel', 'rosel', 'soler'},
#  {'lowery', 'owlery', 'rowley', 'yowler'},
#  {'lumper', 'plumer', 'replum', 'rumple'},
#  {'lunare', 'neural', 'ulnare', 'unreal'},
#  {'lupe', 'pelu', 'peul', 'pule'},
#  {'lutrinae', 'retinula', 'rutelian', 'tenurial'},
#  {'lyrate', 'raylet', 'realty', 'telary'},
#  {'mainpast', 'mantispa', 'panamist', 'stampian'},
#  {'maintop', 'ptomain', 'tampion', 'timpano'},
#  {'malines', 'salmine', 'selamin', 'seminal'},
#  {'malison', 'manolis', 'osmanli', 'somnial'},
#  {'manist', 'mantis', 'matins', 'stamin'},
#  {'maris', 'marsi', 'samir', 'simar'},
#  {'martes', 'master', 'remast', 'stream'},
#  {'mateless', 'meatless', 'tameless', 'teamless'},
#  {'melanite', 'meletian', 'metaline', 'nemalite'},
#  {'mentor', 'merton', 'termon', 'tormen'},
#  {'mero', 'more', 'omer', 'rome'},
#  {'merop', 'moper', 'proem', 'remop'},
#  {'mese', 'seem', 'seme', 'smee'},
#  {'mester', 'restem', 'temser', 'termes'},
#  {'metis', 'smite', 'stime', 'times'},
#  {'mias', 'saim', 'siam', 'sima'},
#  {'mitra', 'tarmi', 'timar', 'tirma'},
#  {'monaster', 'monstera', 'nearmost', 'storeman'},
#  {'moorwort', 'rootworm', 'tomorrow', 'wormroot'},
#  {'mundane', 'unamend', 'unmaned', 'unnamed'},
#  {'musar', 'ramus', 'rusma', 'surma'},
#  {'nailrod', 'ordinal', 'rinaldo', 'rodinal'},
#  {'natr', 'rant', 'tarn', 'tran'},
#  {'neiper', 'perine', 'pirene', 'repine'},
#  {'neoplasm', 'pleonasm', 'polesman', 'splenoma'},
#  {'neurite', 'retinue', 'reunite', 'uterine'},
#  {'nope', 'open', 'peon', 'pone'},
#  {'norse', 'noser', 'seron', 'snore'},
#  {'noter', 'tenor', 'toner', 'trone'},
#  {'notus', 'snout', 'stoun', 'tonus'},
#  {'onset', 'seton', 'steno', 'stone'},
#  {'orangist', 'organist', 'roasting', 'signator'},
#  {'orant', 'rotan', 'toran', 'trona'},
#  {'orthose', 'reshoot', 'shooter', 'soother'},
#  {'other', 'thore', 'throe', 'toher'},
#  {'ottar', 'tarot', 'torta', 'troat'},
#  {'ouster', 'souter', 'touser', 'trouse'},
#  {'outgrin', 'outring', 'routing', 'touring'},
#  {'padle', 'paled', 'pedal', 'plead'},
#  {'painter', 'pertain', 'pterian', 'repaint'},
#  {'pair', 'pari', 'pria', 'ripa'},
#  {'paly', 'play', 'pyal', 'pyla'},
#  {'panelist', 'pantelis', 'penalist', 'plastein'},
#  {'panisic', 'piscian', 'piscina', 'sinapic'},
#  {'pannus', 'sannup', 'unsnap', 'unspan'},
#  {'pantile', 'pentail', 'platine', 'talpine'},
#  {'paperer', 'perpera', 'prepare', 'repaper'},
#  {'parley', 'pearly', 'player', 'replay'},
#  {'parol', 'polar', 'poral', 'proal'},
#  {'parsee', 'persae', 'persea', 'serape'},
#  {'parsley', 'pyrales', 'sparely', 'splayer'},
#  {'paschite', 'pastiche', 'pistache', 'scaphite'},
#  {'past', 'spat', 'stap', 'taps'},
#  {'pate', 'peat', 'tape', 'teap'},
#  {'patener', 'pearten', 'petrean', 'terpane'},
#  {'pearled', 'pedaler', 'pleader', 'replead'},
#  {'penster', 'present', 'serpent', 'strepen'},
#  {'peres', 'perse', 'speer', 'spree'},
#  {'periost', 'porites', 'reposit', 'riposte'},
#  {'pest', 'sept', 'spet', 'step'},
#  {'pester', 'preset', 'restep', 'streep'},
#  {'peto', 'poet', 'pote', 'tope'},
#  {'phos', 'posh', 'shop', 'soph'},
#  {'phrase', 'seraph', 'shaper', 'sherpa'},
#  {'phytic', 'pitchy', 'pythic', 'typhic'},
#  {'piner', 'prine', 'repin', 'ripen'},
#  {'planate', 'planeta', 'plantae', 'platane'},
#  {'poros', 'proso', 'sopor', 'spoor'},
#  {'porret', 'porter', 'report', 'troper'},
#  {'poser', 'prose', 'ropes', 'spore'},
#  {'poseur', 'pouser', 'souper', 'uprose'},
#  {'post', 'spot', 'stop', 'tops'},
#  {'priest', 'pteris', 'sprite', 'stripe'},
#  {'purist', 'spruit', 'uprist', 'upstir'},
#  {'purse', 'resup', 'sprue', 'super'},
#  {'rate', 'tare', 'tear', 'tera'},
#  {'rateless', 'tasseler', 'tearless', 'tesseral'},
#  {'rattles', 'slatter', 'starlet', 'startle'},
#  {'reasy', 'resay', 'sayer', 'seary'},
#  {'reserve', 'resever', 'reverse', 'severer'},
#  {'reshut', 'suther', 'thurse', 'tusher'},
#  {'resign', 'resing', 'signer', 'singer'},
#  {'resort', 'roster', 'sorter', 'storer'},
#  {'restio', 'sorite', 'sortie', 'triose'},
#  {'restow', 'stower', 'towser', 'worset'},
#  {'restraint', 'retransit', 'trainster', 'transiter'},
#  {'retest', 'setter', 'street', 'tester'},
#  {'retoast', 'rosetta', 'stoater', 'toaster'},
#  {'riant', 'tairn', 'tarin', 'train'},
#  {'rive', 'veri', 'vier', 'vire'},
#  {'ruinate', 'taurine', 'uranite', 'urinate'},
#  {'runite', 'triune', 'uniter', 'untire'},
#  {'ruse', 'suer', 'sure', 'user'},
#  {'saintless', 'saltiness', 'slatiness', 'stainless'},
#  {'salve', 'selva', 'slave', 'valse'},
#  {'salver', 'serval', 'slaver', 'versal'},
#  {'samite', 'semita', 'tamise', 'teaism'},
#  {'satyr', 'stary', 'stray', 'trasy'},
#  {'sederunt', 'underset', 'undesert', 'unrested'},
#  {'serut', 'strue', 'turse', 'uster'},
#  {'shoot', 'sooth', 'sotho', 'toosh'},
#  {'sleet', 'slete', 'steel', 'stele'},
#  {'sowt', 'stow', 'swot', 'wots'},
#  {'spart', 'sprat', 'strap', 'traps'},
#  {'spirt', 'sprit', 'stirp', 'strip'},
#  {'state', 'taste', 'tates', 'testa'},
#  {'swith', 'whist', 'whits', 'wisht'},
#  {'taint', 'tanti', 'tinta', 'titan'},
#  {'thraw', 'warth', 'whart', 'wrath'},
#  {'throw', 'whort', 'worth', 'wroth'},
#  {'uncarted', 'uncrated', 'underact', 'untraced'},
#  {'vail', 'vali', 'vial', 'vila'},
#  {'weird', 'wired', 'wride', 'wried'},
#  {'aaronic', 'nicarao', 'ocarina'},
#  {'abe', 'bae', 'bea'},
#  {'abed', 'bade', 'bead'},
#  {'aberia', 'baeria', 'baiera'},
#  {'abir', 'bari', 'rabi'},
#  {'ablare', 'arable', 'arbela'},
#  {'ableness', 'blaeness', 'sensable'},
#  {'ablest', 'stable', 'tables'},
#  {'ablow', 'balow', 'bowla'},
#  {'ably', 'blay', 'yalb'},
#  {'abner', 'arneb', 'reban'},
#  {'aboard', 'aborad', 'abroad'},
#  {'abreact', 'bractea', 'cabaret'},
#  {'abret', 'bater', 'berat'},
#  {'abrus', 'bursa', 'subra'},
#  {'abut', 'tabu', 'tuba'},
#  {'acadie', 'acedia', 'adicea'},
#  {'acamar', 'camara', 'maraca'},
#  {'acanth', 'anchat', 'tanach'},
#  {'acardia', 'acarida', 'arcadia'},
#  {'acarian', 'acarina', 'acrania'},
#  {'acarid', 'cardia', 'carida'},
#  {'acarine', 'acraein', 'arecain'},
#  {'accretion', 'anorectic', 'neoarctic'},
#  {'acentric', 'encratic', 'nearctic'},
#  {'acentrous', 'courtesan', 'nectarous'},
#  {'acerb', 'brace', 'caber'},
#  {'acerous', 'carouse', 'euscaro'},
#  {'acetanilid', 'laciniated', 'teniacidal'},
#  {'acetin', 'actine', 'enatic'},
#  {'acetol', 'colate', 'locate'},
#  {'ache', 'each', 'haec'},
#  {'achill', 'cahill', 'chilla'},
#  {'achondrite', 'ditrochean', 'ordanchite'},
#  {'achromatin', 'chariotman', 'machinator'},
#  {'acid', 'cadi', 'caid'},
#  {'acidometry', 'medicatory', 'radiectomy'},
#  {'acis', 'asci', 'saic'},
#  {'acle', 'alec', 'lace'},
#  {'acme', 'came', 'mace'},
#  {'acne', 'cane', 'nace'},
#  {'acnida', 'anacid', 'dacian'},
#  {'acnodal', 'canadol', 'locanda'},
#  {'acone', 'canoe', 'ocean'},
#  {'aconital', 'actional', 'anatolic'},
#  {'aconitic', 'cationic', 'itaconic'},
#  {'aconitin', 'inaction', 'nicotian'},
#  {'acorn', 'acron', 'racon'},
#  {'acosmist', 'massicot', 'somatics'},
#  {'acream', 'camera', 'mareca'},
#  {'acrididae', 'cardiidae', 'cidaridae'},
#  {'acrostic', 'sarcotic', 'socratic'},
#  {'acryl', 'caryl', 'clary'},
#  {'actian', 'natica', 'tanica'},
#  {'actinoid', 'diatonic', 'naticoid'},
#  {'actinon', 'cantion', 'contain'},
#  {'actinopteri', 'crepitation', 'precitation'},
#  {'action', 'atonic', 'cation'},
#  {'acton', 'canto', 'octan'},
#  {'acts', 'cast', 'scat'},
#  {'acture', 'cauter', 'curate'},
#  {'acyl', 'clay', 'lacy'},
#  {'adad', 'adda', 'dada'},
#  {'adapter', 'predata', 'readapt'},
#  {'adder', 'dread', 'readd'},
#  {'adeem', 'ameed', 'edema'},
#  {'adeline', 'daniele', 'delaine'},
#  {'adeling', 'dealing', 'leading'},
#  {'ademonist', 'demoniast', 'staminode'},
#  {'adermin', 'amerind', 'dimeran'},
#  {'adiel', 'delia', 'ideal'},
#  {'adipocele', 'cepolidae', 'ploceidae'},
#  {'adman', 'daman', 'namda'},
#  {'admirer', 'madrier', 'married'},
#  {'ado', 'dao', 'oda'},
#  {'adonin', 'nanoid', 'nonaid'},
#  {'adopter', 'protead', 'readopt'},
#  {'adore', 'oared', 'oread'},
#  {'adroitly', 'dilatory', 'idolatry'},
#  {'adry', 'dray', 'yard'},
#  {'adular', 'aludra', 'radula'},
#  {'ady', 'day', 'yad'},
#  {'aegle', 'eagle', 'galee'},
#  {'aeolian', 'aeolina', 'aeonial'},
#  {'aeonist', 'asiento', 'satieno'},
#  {'aes', 'ase', 'sea'},
#  {'aetian', 'antiae', 'taenia'},
#  {'afebrile', 'balefire', 'fireable'},
#  {'afresh', 'fasher', 'ferash'},
#  {'agalite', 'tailage', 'taliage'},
#  {'aged', 'egad', 'gade'},
#  {'agger', 'gager', 'regga'},
#  {'agib', 'biga', 'gabi'},
#  {'agiel', 'agile', 'galei'},
#  {'agistor', 'agrotis', 'orgiast'},
#  {'agnus', 'angus', 'sugan'},
#  {'agoniadin', 'anangioid', 'ganoidian'},
#  {'agonizer', 'orangize', 'organize'},
#  {'agrania', 'angaria', 'niagara'},
#  {'agree', 'eager', 'eagre'},
#  {'agrestian', 'gerastian', 'stangeria'},
#  {'agrufe', 'gaufer', 'gaufre'},
#  {'ahem', 'haem', 'hame'},
#  {'ahey', 'eyah', 'yeah'},
#  {'ahint', 'hiant', 'tahin'},
#  {'ahsan', 'hansa', 'hasan'},
#  {'aht', 'hat', 'tha'},
#  {'ahtena', 'aneath', 'athena'},
#  {'ahu', 'auh', 'hau'},
#  {'aides', 'aside', 'sadie'},
#  {'aiel', 'aile', 'elia'},
#  {'ail', 'ila', 'lai'},
#  {'ailing', 'angili', 'nilgai'},
#  {'aim', 'ami', 'ima'},
#  {'aimless', 'melissa', 'seismal'},
#  {'air', 'ira', 'ria'},
#  {'aira', 'aria', 'raia'},
#  {'airan', 'arain', 'arian'},
#  {'ajar', 'jara', 'raja'},
#  {'akin', 'kina', 'naik'},
#  {'aknee', 'ankee', 'keena'},
#  {'aku', 'auk', 'kua'},
#  {'alacritous', 'lactarious', 'lactosuria'},
#  {'alain', 'alani', 'liana'},
#  {'alan', 'anal', 'lana'},
#  {'alangine', 'angelina', 'galenian'},
#  {'alans', 'lanas', 'nasal'},
#  {'alb', 'bal', 'lab'},
#  {'alba', 'baal', 'bala'},
#  {'albanite', 'balanite', 'nabalite'},
#  {'albata', 'atabal', 'balata'},
#  {'alberta', 'latebra', 'ratable'},
#  {'alberto', 'bloater', 'latrobe'},
#  {'albi', 'bail', 'bali'},
#  {'albin', 'binal', 'blain'},
#  {'alces', 'casel', 'scale'},
#  {'alcidine', 'danielic', 'lecaniid'},
#  {'alcoran', 'ancoral', 'carolan'},
#  {'alcove', 'coeval', 'volcae'},
#  {'alder', 'daler', 'lader'},
#  {'aldime', 'mailed', 'medial'},
#  {'alerce', 'cereal', 'relace'},
#  {'aletap', 'palate', 'platea'},
#  {'alex', 'axel', 'axle'},
#  {'algerian', 'geranial', 'regalian'},
#  {'algine', 'genial', 'linage'},
#  {'alice', 'celia', 'ileac'},
#  {'alichel', 'challie', 'helical'},
#  {'aliptes', 'pastile', 'talipes'},
#  {'alit', 'tail', 'tali'},
#  {'alkes', 'sakel', 'slake'},
#  {'allagite', 'alligate', 'talliage'},
#  {'alle', 'ella', 'leal'},
#  {'allie', 'leila', 'lelia'},
#  {'allium', 'alulim', 'muilla'},
#  {'alman', 'lamna', 'manal'},
#  {'almoner', 'moneral', 'nemoral'},
#  ...]

# %%
for sig in sorted(anagramBySignature.keys(), key=len, reverse=True):
    print(anagramBySignature[sig])
# Out:
# {'cholecystoduodenostomy', 'duodenocholecystostomy'}
# {'hydropneumopericardium', 'pneumohydropericardium'}
# {'pathologicoanatomical', 'anatomicopathological'}
# {'photochromolithograph', 'chromophotolithograph'}
# {'pancreatoduodenectomy', 'duodenopancreatectomy'}
# {'labioglossopharyngeal', 'glossolabiopharyngeal'}
# {'anatomicophysiologic', 'physiologicoanatomic'}
# {'meningoencephalocele', 'encephalomeningocele'}
# {'glossolabiolaryngeal', 'labioglossolaryngeal'}
# {'pathologicoanatomic', 'anatomicopathologic'}
# {'clinicopathological', 'pathologicoclinical'}
# {'meningoencephalitis', 'encephalomeningitis'}
# {'gastroesophagostomy', 'esophagogastrostomy'}
# {'incontrovertibility', 'introconvertibility'}
# {'pericardiacophrenic', 'phrenicopericardiac'}
# {'physiopsychological', 'psychophysiological'}
# {'chondromyxosarcoma', 'myxochondrosarcoma'}
# {'chorioidoretinitis', 'retinochorioiditis'}
# {'chronophotographic', 'photochronographic'}
# {'electrothermometer', 'thermoelectrometer'}
# {'vasoepididymostomy', 'epididymovasostomy'}
# {'thermogalvanometer', 'galvanothermometer'}
# {'hexakistetrahedron', 'tetrakishexahedron'}
# {'pharyngolaryngitis', 'laryngopharyngitis'}
# {'tracheolaryngotomy', 'laryngotracheotomy'}
# {'psychoneurological', 'neuropsychological'}
# {'methylacetanilide', 'acetmethylanilide'}
# {'marsipobranchiata', 'basiparachromatin'}
# {'siliceocalcareous', 'calcareosiliceous'}
# {'meningocephalitis', 'cephalomeningitis'}
# {'cerebromeningitis', 'meningocerebritis'}
# {'chemicomechanical', 'mechanicochemical'}
# {'chromolithography', 'lithochromography'}
# {'chromophotography', 'photochromography'}
# {'chronophotography', 'photochronography'}
# {'constitutionalism', 'misconstitutional'}
# {'polygamodioecious', 'dioeciopolygamous'}
# {'electromagnetical', 'magnetoelectrical'}
# {'encephalomyelitis', 'myeloencephalitis'}
# {'hexakisoctahedron', 'octakishexahedron'}
# {'hydropneumothorax', 'pneumohydrothorax'}
# {'hysterolaparotomy', 'laparohysterotomy'}
# {'myomohysterectomy', 'hysteromyomectomy'}
# {'laryngopharyngeal', 'pharyngolaryngeal'}
# {'photomicrographic', 'microphotographic'}
# {'microspectroscope', 'spectromicroscope'}
# {'representationism', 'misrepresentation'}
# {'pericardiopleural', 'pleuropericardial'}
# {'benzantialdoxime', 'antibenzaldoxime'}
# {'arthrochondritis', 'chondroarthritis'}
# {'autoradiographic', 'radioautographic'}
# {'psychobiological', 'biopsychological'}
# {'corneocalcareous', 'calcareocorneous'}
# {'chronophotograph', 'photochronograph'}
# {'configurationism', 'misconfiguration'}
# {'electrodynamical', 'dynamoelectrical'}
# {'hydroferricyanic', 'ferrihydrocyanic'}
# {'hydroferrocyanic', 'ferrohydrocyanic'}
# {'myxofibrosarcoma', 'fibromyxosarcoma'}
# {'phosphoglycerate', 'glycerophosphate'}
# {'photoheliography', 'heliophotography'}
# {'hemopneumothorax', 'pneumohemothorax'}
# {'introconvertible', 'incontrovertible'}
# {'vesicointestinal', 'intestinovesical'}
# {'splenolaparotomy', 'laparosplenotomy'}
# {'photolithography', 'lithophotography'}
# {'meningomyelocele', 'myelomeningocele'}
# {'microphotography', 'photomicrography'}
# {'permonosulphuric', 'monopersulphuric'}
# {'temporooccipital', 'occipitotemporal'}
# {'parietosquamosal', 'squamosoparietal'}
# {'pectinatopinnate', 'pinnatopectinate'}
# {'pterylographical', 'petrographically'}
# {'rhinopharyngitis', 'pharyngorhinitis'}
# {'photostereograph', 'stereophotograph'}
# {'phototelegraphic', 'telephotographic'}
# {'physiopsychology', 'psychophysiology'}
# {'psychotechnology', 'technopsychology'}
# {'ureteropyelogram', 'pyeloureterogram'}
# {'sacculoutricular', 'utriculosaccular'}
# {'somatosplanchnic', 'splanchnosomatic'}
# {'telespectroscope', 'spectrotelescope'}
# {'streptothricosis', 'streptotrichosis'}
# {'vaginoabdominal', 'abdominovaginal'}
# {'vesicoabdominal', 'abdominovesical'}
# {'aluminosilicate', 'silicoaluminate'}
# {'radioautography', 'autoradiography'}
# {'thermobarograph', 'barothermograph'}
# {'sociobiological', 'biosociological'}
# {'physicochemical', 'chemicophysical'}
# {'megachiropteran', 'cinematographer'}
# {'columbotitanate', 'titanocolumbate'}
# {'conservationist', 'conversationist'}
# {'misconstruction', 'constructionism'}
# {'cystourethritis', 'urethrocystitis'}
# {'dactylopteridae', 'pterodactylidae'}
# {'dermatoneurosis', 'neurodermatosis'}
# {'sinistrodextral', 'dextrosinistral'}
# {'misecclesiastic', 'ecclesiasticism'}
# {'magnetoelectric', 'electromagnetic'}
# {'enterogastritis', 'gastroenteritis'}
# {'sphenoethmoidal', 'ethmosphenoidal'}
# {'frontooccipital', 'occipitofrontal'}
# {'remagnification', 'germanification'}
# {'nomographically', 'monographically', 'phonogramically', 'gramophonically'}
# {'tetrahexahedron', 'hexatetrahedron'}
# {'imprescriptible', 'imperscriptible'}
# {'impressibleness', 'permissibleness'}
# {'inferoposterior', 'posteroinferior'}
# {'nephrolithotomy', 'lithonephrotomy'}
# {'macrophotograph', 'photomacrograph'}
# {'meningomyelitis', 'myelomeningitis'}
# {'microphotograph', 'photomicrograph'}
# {'photomicroscope', 'microphotoscope'}
# {'microradiometer', 'radiomicrometer'}
# {'remisunderstand', 'misunderstander'}
# {'temporoparietal', 'parietotemporal'}
# {'visceroparietal', 'parietovisceral'}
# {'telephotography', 'phototelegraphy'}
# {'phytotopography', 'phototypography'}
# {'pneumopyothorax', 'pyopneumothorax'}
# {'posterosuperior', 'superoposterior'}
# {'transimpression', 'pretransmission'}
# {'tungstosilicate', 'silicotungstate'}
# {'stereotelescope', 'telestereoscope'}
# {'sternovertebral', 'vertebrosternal'}
# {'untraceableness', 'uncreatableness'}
# {'adenochondroma', 'chondroadenoma'}
# {'altitudinarian', 'latitudinarian'}
# {'angiochondroma', 'chondroangioma'}
# {'charlatanistic', 'antarchistical'}
# {'anteroinferior', 'inferoanterior'}
# {'anterosuperior', 'superoanterior'}
# {'associationism', 'misassociation'}
# {'radioautograph', 'autoradiograph'}
# {'blastomycetous', 'cytoblastemous'}
# {'borofluohydric', 'hydrofluoboric'}
# {'carcinosarcoma', 'sarcocarcinoma'}
# {'vesicocervical', 'cervicovesical'}
# {'platinochloric', 'chloroplatinic'}
# {'fibrochondroma', 'chondrofibroma'}
# {'conservational', 'conversational'}
# {'constitutioner', 'reconstitution'}
# {'vertebrocostal', 'costovertebral'}
# {'cystonephrosis', 'nephrocystosis'}
# {'dentatoserrate', 'serratodentate'}
# {'sinuatodentate', 'dentatosinuate'}
# {'dipterological', 'pteridological'}
# {'dorsoventrally', 'ventrodorsally'}
# {'jejunoduodenal', 'duodenojejunal'}
# {'electrodynamic', 'dynamoelectric'}
# {'thermoelectric', 'electrothermic'}
# {'phylloerythrin', 'erythrophyllin'}
# {'extirpationist', 'sextipartition'}
# {'parietofrontal', 'frontoparietal'}
# {'temporofrontal', 'frontotemporal'}
# {'galvanopsychic', 'psychogalvanic'}
# {'spermiogenesis', 'geissospermine'}
# {'holohemihedral', 'hemiholohedral'}
# {'herpetological', 'pretheological'}
# {'nephrohydrosis', 'hydronephrosis'}
# {'permissibility', 'impressibility'}
# {'permissiveness', 'impressiveness'}
# {'nongeometrical', 'inconglomerate'}
# {'interpollinate', 'interpellation'}
# {'intersectional', 'intraselection'}
# {'repristination', 'interspiration'}
# {'serioludicrous', 'ludicroserious'}
# {'physicomedical', 'medicophysical'}
# {'metrophlebitis', 'phlebometritis'}
# {'remisrepresent', 'misrepresenter'}
# {'unartistically', 'naturistically'}
# {'nephropyelitis', 'pyelonephritis'}
# {'neuropsychosis', 'psychoneurosis'}
# {'nondesecration', 'recondensation'}
# {'paradisiacally', 'paradisaically'}
# {'vaginoperineal', 'perineovaginal'}
# {'perturbational', 'protuberantial'}
# {'petrographical', 'pterographical'}
# {'pterylological', 'petrologically'}
# {'petrosquamosal', 'squamopetrosal'}
# {'phototelegraph', 'telephotograph'}
# {'visceropleural', 'pleurovisceral'}
# {'proletarianize', 'prerealization'}
# {'pretensiveness', 'presentiveness'}
# {'spermatogonium', 'protomagnesium'}
# {'purpuroxanthin', 'xanthopurpurin'}
# {'radiotelephone', 'teleradiophone'}
# {'relativization', 'revitalization'}
# {'titanofluoride', 'rotundifoliate'}
# {'sacrovertebral', 'vertebrosacral'}
# {'soliterraneous', 'salinoterreous'}
# {'titanosilicate', 'silicotitanate'}
# {'silicotungstic', 'tungstosilicic'}
# {'thunderbearing', 'underbreathing'}
# {'transanimation', 'transamination'}
# {'unamenableness', 'unnameableness'}
# {'aeolharmonica', 'chloroanaemia'}
# {'areographical', 'aerographical'}
# {'maleficiation', 'amelification'}
# {'amplification', 'palmification'}
# {'angiocholitis', 'cholangioitis'}
# {'keratoangioma', 'angiokeratoma'}
# {'anticlinorium', 'inclinatorium'}
# {'sporification', 'antisoporific', 'prosification'}
# {'argentiferous', 'garnetiferous'}
# {'arthrosteitis', 'ostearthritis'}
# {'attentiveness', 'tentativeness'}
# {'autoheterosis', 'heteroousiast'}
# {'beardlessness', 'breadlessness'}
# {'benzofluorene', 'fluorobenzene'}
# {'biopsychology', 'psychobiology'}
# {'cytoblastemic', 'blastomycetic'}
# {'botanophilist', 'philobotanist'}
# {'brachiofacial', 'faciobrachial'}
# {'cervicobuccal', 'buccocervical'}
# {'petrochemical', 'cephalometric'}
# {'cephalopodous', 'podocephalous'}
# {'certification', 'cretification', 'rectification'}
# {'certificative', 'rectificative'}
# {'certificatory', 'rectificatory'}
# {'cervicodorsal', 'dorsocervical'}
# {'cervicofacial', 'faciocervical'}
# {'cervicolabial', 'labiocervical'}
# {'cheatableness', 'teachableness'}
# {'cholesteremia', 'heteroecismal'}
# {'costochondral', 'chondrocostal'}
# {'chondrolipoma', 'lipochondroma'}
# {'chondromyxoma', 'myxochondroma'}
# {'coloenteritis', 'enterocolitis'}
# {'proctocolitis', 'coloproctitis'}
# {'competitioner', 'recompetition'}
# {'procommission', 'compromission'}
# {'monodactylous', 'condylomatous'}
# {'considerative', 'devisceration'}
# {'countertrades', 'unstercorated'}
# {'crimelessness', 'mercilessness'}
# {'inguinocrural', 'cruroinguinal'}
# {'prostatectomy', 'cryptostomate'}
# {'cystopyelitis', 'pyelocystitis'}
# {'pterodactylus', 'dactylopterus'}
# {'palaeechinoid', 'deinocephalia'}
# {'predomination', 'demipronation', 'preadmonition'}
# {'dermosclerite', 'sclerodermite'}
# {'diageotropism', 'geodiatropism'}
# {'diplocephalus', 'pseudophallic'}
# {'pteridologist', 'dipterologist'}
# {'discriminator', 'doctrinairism'}
# {'redistinguish', 'distinguisher'}
# {'endoarteritis', 'sideronatrite'}
# {'sphenoethmoid', 'ethmosphenoid'}
# {'misexpression', 'expressionism'}
# {'orbitofrontal', 'frontoorbital'}
# {'neuroganglion', 'ganglioneuron'}
# {'hepatogastric', 'gastrohepatic'}
# {'nephrogastric', 'gastrophrenic', 'phrenogastric'}
# {'urinogenitary', 'genitourinary'}
# {'monographical', 'nomographical', 'gramophonical'}
# {'grandpaternal', 'grandparental'}
# {'logographical', 'graphological'}
# {'uranographist', 'guarantorship'}
# {'hemicatalepsy', 'mesaticephaly'}
# {'megalohepatia', 'hepatomegalia'}
# {'hepatonephric', 'phrenohepatic'}
# {'hydrosulphate', 'sulphohydrate'}
# {'intracoelomic', 'iconometrical'}
# {'impersonation', 'prosemination', 'semipronation'}
# {'misimpression', 'impressionism'}
# {'incudomalleal', 'malleoincudal'}
# {'nonvisitation', 'innovationist'}
# {'instructional', 'nonaltruistic'}
# {'intercalation', 'interactional'}
# {'intermorainic', 'recrimination'}
# {'interspecific', 'prescientific'}
# {'intervascular', 'vernacularist'}
# {'investigation', 'tenovaginitis'}
# {'nasolachrymal', 'lachrymonasal'}
# {'ventrolateral', 'lateroventral'}
# {'omphalogenous', 'megalophonous'}
# {'splenomegalia', 'megalosplenia'}
# {'promonarchist', 'micranthropos'}
# {'micropetalous', 'somatopleuric'}
# {'perceptionism', 'misperception'}
# {'suggestionism', 'missuggestion'}
# {'neuromyelitis', 'myeloneuritis'}
# {'nephrocardiac', 'phrenocardiac'}
# {'orthantimonic', 'ornithomantic'}
# {'osteometrical', 'stereotomical'}
# {'uterocervical', 'overcirculate'}
# {'veraciousness', 'oversauciness'}
# {'paraphrenitis', 'paranephritis'}
# {'parasyntheton', 'thysanopteran'}
# {'pedometrician', 'premedication'}
# {'preambulation', 'perambulation'}
# {'preambulatory', 'perambulatory'}
# {'periodicalist', 'proidealistic', 'peridiastolic'}
# {'personalistic', 'pictorialness'}
# {'splenophrenic', 'phrenosplenic', 'splenonephric'}
# {'pneumatophony', 'pneumonopathy'}
# {'stomatopodous', 'podostomatous'}
# {'redescription', 'prediscretion'}
# {'protoperlaria', 'propraetorial'}
# {'protosulphide', 'sulphoproteid'}
# {'somatopsychic', 'psychosomatic'}
# {'pyosepticemia', 'septicopyemia'}
# {'septicopyemic', 'pyosepticemic'}
# {'retrogradient', 'redintegrator'}
# {'superposition', 'resupposition'}
# {'sacrification', 'scarification'}
# {'subcortically', 'scorbutically'}
# {'superintender', 'unenterprised'}
# {'unamenability', 'unnameability'}
# {'unrectifiable', 'uncertifiable'}
# {'unconservable', 'unconversable'}
# {'unpermissible', 'unimpressible'}
# {'unspectrelike', 'unspecterlike'}
# {'unsuspectible', 'unsusceptible'}
# {'vesicovaginal', 'vaginovesical'}
# {'accomplisher', 'reaccomplish'}
# {'acherontical', 'anchoretical'}
# {'achromatinic', 'chromatician'}
# {'acidophilous', 'aphidicolous'}
# {'acrostically', 'socratically'}
# {'precantation', 'actinopteran'}
# {'acutenaculum', 'unaccumulate'}
# {'adenocystoma', 'cystoadenoma'}
# {'adenofibroma', 'fibroadenoma'}
# {'sarcoadenoma', 'adenosarcoma'}
# {'proadmission', 'adpromission'}
# {'incorporated', 'adrenotropic'}
# {'lancasterian', 'alcantarines'}
# {'ethnological', 'allothogenic'}
# {'bilaterality', 'relatability', 'alterability'}
# {'amphitropous', 'pastophorium'}
# {'anemographic', 'phanerogamic'}
# {'fibroangioma', 'angiofibroma'}
# {'unalimentary', 'anteluminary'}
# {'anticreative', 'antireactive'}
# {'antifriction', 'nitrifaction'}
# {'misquotation', 'antimosquito'}
# {'pentathionic', 'antiphonetic'}
# {'entoparasite', 'antiprotease'}
# {'antiroyalist', 'stationarily'}
# {'practitional', 'antitropical'}
# {'parochialism', 'aphorismical'}
# {'igneoaqueous', 'aqueoigneous'}
# {'arsenopyrite', 'pyroarsenite'}
# {'bicarpellary', 'prebacillary'}
# {'reproachable', 'blepharocera'}
# {'podobranchia', 'branchiopoda'}
# {'hydrobromate', 'bromohydrate'}
# {'cacodemoniac', 'cacodaemonic'}
# {'callisection', 'clinoclasite'}
# {'calotermitid', 'dilatometric'}
# {'capsulectomy', 'scapulectomy'}
# {'hydrocarbide', 'carbohydride'}
# {'sectarianism', 'cartesianism'}
# {'femorocaudal', 'caudofemoral'}
# {'laterocaudal', 'caudolateral'}
# {'centrodorsal', 'dorsocentral'}
# {'centrolineal', 'crenellation'}
# {'chloracetate', 'ceratothecal'}
# {'certificator', 'rectificator'}
# {'corycavidine', 'cervicodynia'}
# {'chapelmaster', 'spermathecal'}
# {'chaperonless', 'proseneschal'}
# {'cheiropodist', 'coeditorship'}
# {'chemicovital', 'vitochemical'}
# {'monarchistic', 'chiromancist'}
# {'opisthorchis', 'chirosophist'}
# {'chloroanemia', 'choleromania'}
# {'chloroiodide', 'iodochloride'}
# {'thoracectomy', 'chromatocyte'}
# {'chrysography', 'psychorrhagy'}
# {'tonicoclonic', 'clonicotonic'}
# {'solicitation', 'coalitionist'}
# {'collectioner', 'recollection'}
# {'colpeurynter', 'counterreply'}
# {'colporrhagia', 'orographical'}
# {'commentarial', 'manometrical'}
# {'commissioner', 'recommission'}
# {'contemperate', 'compenetrate'}
# {'comprehender', 'recomprehend'}
# {'concessioner', 'reconcession'}
# {'connoissance', 'nonaccession'}
# {'conservation', 'conversation'}
# {'conversative', 'conservative'}
# {'conturbation', 'obtruncation'}
# {'conventioner', 'reconvention'}
# {'topographics', 'coprophagist'}
# {'reoccupation', 'cornucopiate'}
# {'prosectorial', 'corporealist'}
# {'correctioner', 'recorrection'}
# {'sternocostal', 'costosternal'}
# {'countercarte', 'counteracter'}
# {'countermarch', 'countercharm'}
# {'counterguard', 'uncorrugated'}
# {'counterpaled', 'unpercolated', 'counterplead'}
# {'countershade', 'decantherous'}
# {'counterstand', 'uncontrasted'}
# {'courtiership', 'peritrichous'}
# {'reactiveness', 'creativeness'}
# {'directorship', 'creditorship'}
# {'crestmoreite', 'stereometric'}
# {'cricothyroid', 'thyrocricoid'}
# {'crurogenital', 'genitocrural'}
# {'fibrocystoma', 'cystofibroma'}
# {'decimestrial', 'sedimetrical'}
# {'delicatessen', 'delicateness'}
# {'delimitation', 'mniotiltidae'}
# {'imparalleled', 'demiparallel'}
# {'indulgential', 'dentilingual', 'linguidental'}
# {'dentolingual', 'linguodental'}
# {'depositional', 'despoliation'}
# {'predeication', 'depreciation'}
# {'derivational', 'revalidation'}
# {'herpetomonad', 'dermatophone'}
# {'epiceratodus', 'dipteraceous'}
# {'disadventure', 'unadvertised'}
# {'disastimeter', 'semistriated'}
# {'undiscretion', 'discontinuer'}
# {'discreteness', 'discreetness'}
# {'dorsolateral', 'laterodorsal'}
# {'ventrodorsad', 'dorsoventrad'}
# {'dorsoventral', 'ventrodorsal'}
# {'empathically', 'emphatically'}
# {'energeticist', 'energetistic'}
# {'erythrophage', 'heterography'}
# {'etherization', 'heterization'}
# {'exasperation', 'xenoparasite'}
# {'selfsameness', 'famelessness'}
# {'tibiofemoral', 'femorotibial'}
# {'neurofibroma', 'fibroneuroma'}
# {'fingerflower', 'fringeflower'}
# {'refoundation', 'foundationer'}
# {'gallotannate', 'tannogallate'}
# {'gastropathic', 'graphostatic'}
# {'hydrogeology', 'geohydrology'}
# {'glossolabial', 'labioglossal'}
# {'gonidiferous', 'indigoferous'}
# {'gramophonist', 'monographist'}
# {'phonographic', 'graphophonic'}
# {'haptophorous', 'pathophorous'}
# {'heretication', 'theoretician'}
# {'urethrascope', 'heterocarpus'}
# {'heterogynous', 'thyreogenous'}
# {'polymetochia', 'homeotypical'}
# {'radiohumeral', 'humeroradial'}
# {'humoralistic', 'humoristical'}
# {'hurtlessness', 'ruthlessness'}
# {'somatophytic', 'hypostomatic'}
# {'hysterophyta', 'hysteropathy'}
# {'iatraliptics', 'partialistic'}
# {'intemperable', 'impenetrable'}
# {'impenetrably', 'intemperably'}
# {'importunance', 'unimportance'}
# {'impressively', 'permissively'}
# {'inactivation', 'vaticination'}
# {'incomputable', 'uncompatible'}
# {'nonscientist', 'inconsistent'}
# {'indefinitude', 'unidentified'}
# {'indeprivable', 'predivinable'}
# {'indiscreetly', 'indiscretely', 'iridescently'}
# {'inobtainable', 'nonbilabiate'}
# {'precautional', 'inoperculata'}
# {'intercession', 'recensionist'}
# {'interimistic', 'trimesitinic'}
# {'reprotection', 'interoceptor'}
# {'interpellate', 'pantellerite'}
# {'prereduction', 'interproduce'}
# {'tenuistriate', 'intersituate'}
# {'interstation', 'strontianite'}
# {'intervention', 'introvenient'}
# {'nitrogelatin', 'intolerating'}
# {'irrationable', 'orbitelarian'}
# {'pretercanine', 'irrepentance'}
# {'ischiorectal', 'sciotherical'}
# {'isosaccharic', 'sacroischiac'}
# {'protectional', 'lactoprotein'}
# {'lepidosauria', 'pliosauridae'}
# {'sphacelation', 'lipsanotheca'}
# {'lithonephria', 'philotherian'}
# {'metrological', 'logometrical'}
# {'metaphysical', 'lymphectasia'}
# {'mastological', 'malacologist'}
# {'slaughterman', 'manslaughter'}
# {'matelessness', 'tamelessness'}
# {'ventromedial', 'medioventral'}
# {'pharmacolite', 'metaphorical'}
# {'metronomical', 'monometrical'}
# {'microcephaly', 'pyrochemical'}
# {'micropterous', 'prosectorium'}
# {'traditionism', 'mistradition'}
# {'monocystidae', 'monocystidea'}
# {'nomophyllous', 'monophyllous'}
# {'psychomonism', 'monopsychism'}
# {'protomorphic', 'morphotropic'}
# {'volunteerism', 'multinervose'}
# {'thermography', 'mythographer'}
# {'transoceanic', 'narcaciontes'}
# {'unartistical', 'naturalistic'}
# {'nematophyton', 'tenontophyma'}
# {'phonelescope', 'nepheloscope'}
# {'nephological', 'phenological'}
# {'nephrologist', 'phrenologist'}
# {'nephropathic', 'phrenopathic'}
# {'nephropsidae', 'praesphenoid'}
# {'nephroptosia', 'prosiphonate'}
# {'pyonephrosis', 'nephropyosis'}
# {'noncertified', 'nonrectified'}
# {'unconstraint', 'noncurantist'}
# {'prenominical', 'nonempirical'}
# {'nonpearlitic', 'pratincoline'}
# {'notelessness', 'tonelessness'}
# {'substraction', 'obscurantist'}
# {'octastrophic', 'postthoracic'}
# {'oligophrenia', 'oligonephria'}
# {'oligonephric', 'oligophrenic'}
# {'ornithoptera', 'prototherian'}
# {'pontificalia', 'palification'}
# {'palmatilobed', 'palmilobated'}
# {'patroclinous', 'pratincolous'}
# {'pelycography', 'pyrgocephaly'}
# {'peradventure', 'preadventure'}
# {'perceptively', 'preceptively'}
# {'perceptually', 'preceptually'}
# {'percontation', 'pernoctation'}
# {'percussioner', 'repercussion'}
# {'prefoliation', 'perfoliation'}
# {'preformative', 'performative'}
# {'perpetualist', 'pluriseptate'}
# {'perviousness', 'previousness', 'viperousness'}
# {'pterographer', 'petrographer'}
# {'pterographic', 'petrographic'}
# {'rephotograph', 'photographer'}
# {'phrenocostal', 'plastochrone'}
# {'podophyllous', 'phyllopodous'}
# {'pythogenesis', 'phytogenesis'}
# {'phytogenetic', 'pythogenetic'}
# {'platysternal', 'transeptally'}
# {'plousiocracy', 'procaciously'}
# {'traditorship', 'podarthritis'}
# {'spectatorial', 'poetastrical'}
# {'polychloride', 'policyholder'}
# {'repossession', 'possessioner'}
# {'prasophagous', 'saprophagous'}
# {'precipitator', 'prepatriotic'}
# {'pronunciable', 'preconnubial'}
# {'preconsultor', 'supercontrol'}
# {'prediastolic', 'psiloceratid'}
# {'pretensively', 'presentively'}
# {'proportioner', 'reproportion'}
# {'reproduction', 'proreduction'}
# {'prototrophic', 'trophotropic'}
# {'pseudelytron', 'unproselyted'}
# {'psychotheism', 'theopsychism'}
# {'rachianectes', 'rhacianectes'}
# {'reattraction', 'retractation'}
# {'rectovesical', 'vesicorectal'}
# {'veratroidine', 'rederivation'}
# {'reillustrate', 'ultrasterile'}
# {'repermission', 'reimpression'}
# {'renumeration', 'remuneration'}
# {'repercussive', 'superservice'}
# {'straightener', 'restraighten'}
# {'restrengthen', 'strengthener'}
# {'uranospinite', 'resupination'}
# {'retransplant', 'transplanter'}
# {'ritelessness', 'tirelessness'}
# {'rubification', 'urbification'}
# {'scarificator', 'sacrificator'}
# {'salamandarin', 'salamandrina', 'salamandrian'}
# {'supermoisten', 'sempiternous'}
# {'serpentinous', 'supertension'}
# {'zoospermatic', 'spermatozoic'}
# {'sporotrichum', 'trichosporum'}
# {'spotlessness', 'stoplessness'}
# {'tastefulness', 'statefulness'}
# {'trenchmaster', 'stretcherman'}
# {'strophiolate', 'theatropolis'}
# {'suitableness', 'subessential'}
# {'unarrestable', 'subterraneal'}
# {'supernacular', 'supranuclear'}
# {'surprisement', 'trumperiness'}
# {'wordsmanship', 'swordmanship'}
# {'terebinthian', 'terebinthina'}
# {'ultramontane', 'tournamental'}
# {'uncelebrated', 'unbraceleted'}
# {'uncoagulated', 'uncatalogued'}
# {'unexceptable', 'unexpectable'}
# {'unimpressive', 'unpermissive'}
# {'unpenetrable', 'unrepentable'}
# {'unreinstated', 'unstraitened'}
# {'unsuspective', 'unsusceptive'}
# {'calyptratae', 'acalyptrate'}
# {'retrocaecal', 'accelerator'}
# {'reaccession', 'accessioner'}
# {'cantharidae', 'acidanthera'}
# {'acipenserid', 'presidencia'}
# {'isocoumarin', 'acrimonious'}
# {'alcicornium', 'acroclinium'}
# {'socraticism', 'acrosticism'}
# {'prothoracic', 'acrotrophic'}
# {'donatiaceae', 'actaeonidae'}
# {'precitation', 'crepitation', 'actinopteri'}
# {'adaptionism', 'adoptianism'}
# {'adenectopic', 'pentadecoic'}
# {'palaemonoid', 'adenolipoma'}
# {'adorability', 'roadability'}
# {'adrenolytic', 'declinatory'}
# {'formicoidea', 'aecidioform'}
# {'aerographer', 'areographer'}
# {'areographic', 'aerographic'}
# {'areological', 'aerological'}
# {'measuration', 'aeronautism'}
# {'aerostatics', 'aortectasis'}
# {'unfactional', 'afunctional'}
# {'alchemistic', 'hemiclastic'}
# {'alexandrian', 'alexandrina'}
# {'algorithmic', 'logarithmic'}
# {'nonidealist', 'alstonidine'}
# {'altitudinal', 'latitudinal'}
# {'amenability', 'nameability'}
# {'melanorrhea', 'amenorrheal'}
# {'monodelphia', 'amidophenol'}
# {'ammonolytic', 'commonality'}
# {'permeameter', 'amperemeter'}
# {'musophagine', 'amphigenous'}
# {'amphophilic', 'amphiphloic'}
# {'amphipodous', 'hippodamous'}
# {'anacreontic', 'canceration'}
# {'placentalia', 'analeptical'}
# {'pharaonical', 'anaphorical'}
# {'anarthropod', 'arthropodan'}
# {'trichomanes', 'anchoretism'}
# {'chiromantis', 'chrismation', 'harmonistic', 'anchoritism'}
# {'phanerogamy', 'anemography'}
# {'englacially', 'angelically'}
# {'anhematosis', 'somasthenia'}
# {'anhydridize', 'hydrazidine'}
# {'creationism', 'reactionism', 'anisometric', 'ramisection', 'miscreation'}
# {'anorthitite', 'trithionate'}
# {'anthogenous', 'neognathous'}
# {'balantidium', 'antialbumid'}
# {'inculcation', 'anticouncil'}
# {'dictational', 'antidotical'}
# {'exterminate', 'antiextreme'}
# {'antimallein', 'inalimental'}
# {'antinepotic', 'pectination'}
# {'triannulate', 'antineutral'}
# {'antiphrasis', 'artisanship'}
# {'pertinacity', 'antipyretic'}
# {'untraceried', 'antireducer', 'reincrudate'}
# {'antitorpedo', 'deportation'}
# {'aphrodistic', 'diastrophic'}
# {'apostrophus', 'pastophorus'}
# {'apportioner', 'reapportion'}
# {'parablepsia', 'appraisable'}
# {'apprehender', 'reapprehend'}
# {'arachidonic', 'characinoid'}
# {'archapostle', 'thecasporal'}
# {'pretracheal', 'archprelate'}
# {'arenicolite', 'ricinoleate'}
# {'secretarian', 'ascertainer', 'reascertain'}
# {'assertional', 'sensatorial'}
# {'asthmogenic', 'mesognathic'}
# {'attentively', 'tentatively'}
# {'avolitional', 'violational'}
# {'bracteiform', 'bacteriform'}
# {'behaviorism', 'misbehavior'}
# {'benzonitrol', 'nitrobenzol'}
# {'genoblastic', 'blastogenic'}
# {'meroblastic', 'blastomeric'}
# {'blisterwort', 'bristlewort'}
# {'bombacaceae', 'cabombaceae'}
# {'bosselation', 'eosinoblast'}
# {'brachiopode', 'cardiophobe'}
# {'broadcaster', 'rebroadcast'}
# {'spreadboard', 'broadspread'}
# {'calandrinae', 'calendarian'}
# {'claviculate', 'calculative'}
# {'dalecarlian', 'calendarial'}
# {'graphically', 'calligraphy'}
# {'calonectria', 'ectocranial'}
# {'deprecation', 'capernoited'}
# {'implacental', 'capillament'}
# {'piratically', 'capillarity'}
# {'carnationed', 'dinoceratan'}
# {'carolingian', 'inorganical'}
# {'carpocerite', 'reciprocate'}
# {'coprolagnia', 'carpogonial'}
# {'catapultier', 'particulate'}
# {'dorsocaudal', 'caudodorsal'}
# {'vacillation', 'cavillation'}
# {'recluseness', 'censureless'}
# {'conterminal', 'centinormal', 'nonmetrical'}
# {'excarnation', 'centraxonia'}
# {'unsucculent', 'centunculus'}
# {'ceroplastic', 'cleistocarp', 'coreplastic'}
# {'rectifiable', 'certifiable'}
# {'ectomorphic', 'cetomorphic', 'chemotropic'}
# {'chaenolobus', 'unchoosable'}
# {'chaetognath', 'gnathotheca'}
# {'chatelainry', 'trachylinae'}
# {'endothecial', 'chelidonate'}
# {'chemiatrist', 'theatricism', 'chrismatite'}
# {'heliostatic', 'chiastolite'}
# {'chionididae', 'onchidiidae'}
# {'chiromantic', 'chromatinic'}
# {'chiroplasty', 'polyarchist'}
# {'melanochroi', 'chloroamine'}
# {'chordotonal', 'notochordal'}
# {'chorization', 'zonotrichia', 'rhizoctonia'}
# {'chromotypic', 'mycotrophic', 'cormophytic'}
# {'diachoretic', 'citharoedic'}
# {'intrication', 'citrination'}
# {'lysogenetic', 'cleistogeny'}
# {'clericature', 'recirculate'}
# {'directional', 'clitoridean'}
# {'coinherence', 'incoherence'}
# {'recollation', 'collationer'}
# {'colonialist', 'oscillation'}
# {'tragicomedy', 'comitragedy'}
# {'monamniotic', 'commination'}
# {'proamniotic', 'comparition'}
# {'recondition', 'conditioner'}
# {'necrogenous', 'congenerous'}
# {'connectival', 'conventical'}
# {'conversable', 'conservable'}
# {'conversancy', 'conservancy'}
# {'desecration', 'considerate'}
# {'constructer', 'reconstruct'}
# {'technocracy', 'conycatcher'}
# {'recopyright', 'copyrighter'}
# {'criminatory', 'coriamyrtin'}
# {'recordation', 'corrodentia'}
# {'cosmetician', 'encomiastic'}
# {'costispinal', 'pansciolist'}
# {'pornerastic', 'cotranspire'}
# {'counteridea', 'decurionate'}
# {'counterplay', 'counterpaly'}
# {'countersale', 'counterseal'}
# {'countertail', 'reluctation'}
# {'countervail', 'involucrate'}
# {'recurvation', 'countervair', 'overcurtain'}
# {'cyanometric', 'craniectomy'}
# {'craniognomy', 'organonymic'}
# {'terraciform', 'crateriform'}
# {'cratometric', 'metrocratic'}
# {'reactionary', 'creationary'}
# {'creationist', 'reactionist'}
# {'crematorial', 'mercatorial'}
# {'intolerance', 'crenelation'}
# {'misreliance', 'criminalese'}
# {'crocodilite', 'crocidolite'}
# {'imprecatory', 'cryptomeria'}
# {'slouchiness', 'cushionless'}
# {'phycocyanin', 'cyanophycin'}
# {'cystomyxoma', 'myxocystoma'}
# {'dactylonomy', 'monodactyly'}
# {'decimosexto', 'sextodecimo'}
# {'redactional', 'declaration'}
# {'dehortation', 'theriodonta'}
# {'edification', 'deification'}
# {'edificatory', 'deificatory'}
# {'dialystelic', 'deistically'}
# {'indissolute', 'delusionist'}
# {'maddeningly', 'demandingly'}
# {'demarcation', 'democratian'}
# {'demoniacism', 'seminomadic'}
# {'murderingly', 'demurringly'}
# {'labiodental', 'dentolabial'}
# {'denunciator', 'underaction'}
# {'trepidation', 'partitioned', 'departition'}
# {'petticoated', 'depetticoat'}
# {'deploration', 'periodontal'}
# {'depravingly', 'pervadingly'}
# {'description', 'discerption'}
# {'discoactine', 'desiccation'}
# {'esperantido', 'desperation'}
# {'determinant', 'detrainment'}
# {'phronimidae', 'diamorphine'}
# {'diphtherian', 'diaphtherin'}
# {'phosphatide', 'diphosphate'}
# {'pteridology', 'dipterology'}
# {'redisappear', 'disappearer'}
# {'rescindment', 'discernment'}
# {'disremember', 'dismemberer'}
# {'tridiapason', 'disparation'}
# {'piebaldness', 'dispensable'}
# {'divisionism', 'misdivision'}
# {'dorsoapical', 'prosodiacal'}
# {'dorsomedial', 'mediodorsal'}
# {'sacrodorsal', 'dorsosacral'}
# {'mesocephaly', 'elaphomyces'}
# {'proteolysis', 'elytroposis'}
# {'enarthrosis', 'nearthrosis'}
# {'endearingly', 'engrainedly'}
# {'imponderous', 'endosporium'}
# {'engrailment', 'realignment'}
# {'ensepulcher', 'ensepulchre'}
# {'untreatable', 'entablature'}
# {'entomophily', 'monophylite'}
# {'spinotectal', 'tectospinal', 'tenoplastic', 'entoplastic'}
# {'enumeration', 'mountaineer'}
# {'incuneation', 'enunciation'}
# {'erucivorous', 'overcurious'}
# {'esperantism', 'strepsinema'}
# {'ethological', 'lethologica', 'theological'}
# {'eucalypteol', 'eucalyptole'}
# {'eucatropine', 'neurectopia'}
# {'evilhearted', 'vilehearted'}
# {'exanimation', 'examination'}
# {'sinfonietta', 'festination', 'infestation'}
# {'lipofibroma', 'fibrolipoma'}
# {'mucofibrous', 'fibromucous'}
# {'myxofibroma', 'fibromyxoma'}
# {'fibroserous', 'serofibrous'}
# {'frowardness', 'forwardness'}
# {'glorifiable', 'frigolabile'}
# {'frontonasal', 'nasofrontal'}
# {'luctiferous', 'fruticulose'}
# {'unformality', 'fulminatory'}
# {'tannogallic', 'gallotannic'}
# {'gallybagger', 'gallybeggar'}
# {'geomagnetic', 'gamogenetic', 'gametogenic'}
# {'gastronomic', 'monogastric'}
# {'integralize', 'gelatinizer'}
# {'genotypical', 'ptyalogenic'}
# {'geoisotherm', 'isogeotherm'}
# {'geometrical', 'glaciometer'}
# {'tocogenetic', 'geotectonic'}
# {'nomographer', 'monographer', 'geranomorph'}
# {'glycerinize', 'glycerizine'}
# {'goldenmouth', 'longmouthed'}
# {'gongoresque', 'gorgonesque'}
# {'marginiform', 'graminiform'}
# {'nomographic', 'phonogramic', 'gramophonic', 'monographic'}
# {'gregarinous', 'grangousier'}
# {'graphologic', 'logographic'}
# {'meteorgraph', 'graphometer'}
# {'pictography', 'typographic', 'graphotypic'}
# {'hoppergrass', 'grasshopper'}
# {'halophytism', 'hylopathism'}
# {'leatherbark', 'halterbreak'}
# {'prehandicap', 'handicapper'}
# {'haptophoric', 'pathophoric'}
# {'protopathic', 'haptotropic'}
# {'heartedness', 'neatherdess'}
# {'heliotactic', 'thiolacetic'}
# {'helleborine', 'helleborein'}
# {'hemiatrophy', 'hypothermia'}
# {'phariseeism', 'hemiparesis'}
# {'hepatocolic', 'otocephalic'}
# {'somatophyte', 'hepatostomy'}
# {'heptaploidy', 'typhlopidae'}
# {'heterically', 'heretically'}
# {'theorematic', 'heteratomic'}
# {'heterotelic', 'heteroclite'}
# {'heterodromy', 'hydrometeor'}
# {'theotherapy', 'heteropathy'}
# {'heteropodal', 'prelatehood'}
# {'holocentrid', 'lechriodont'}
# {'homeogenous', 'homogeneous'}
# {'ruthfulness', 'hurtfulness'}
# {'hydrorachis', 'hydrocharis'}
# {'smoothingly', 'hymnologist'}
# {'thyreohyoid', 'hyothyreoid'}
# {'museography', 'hypergamous'}
# {'hypoglottis', 'phytologist'}
# {'phylloceras', 'hyposcleral'}
# {'hysteriales', 'hysteresial'}
# {'litorinidae', 'idioretinal'}
# {'ilioischiac', 'ischioiliac'}
# {'illaudatory', 'laudatorily'}
# {'lacertiloid', 'illoricated'}
# {'immaterials', 'materialism'}
# {'impenetrate', 'intemperate'}
# {'proseminate', 'impersonate'}
# {'importunate', 'permutation'}
# {'impressible', 'permissible'}
# {'impressibly', 'permissibly'}
# {'preromantic', 'improcreant'}
# {'incensation', 'inscenation'}
# {'nonsanction', 'inconsonant'}
# {'incorporate', 'procreation'}
# {'visceration', 'insectivora'}
# {'vinaigrette', 'vertiginate', 'integrative'}
# {'interastral', 'intertarsal'}
# {'interfinger', 'interfering'}
# {'reverential', 'interleaver'}
# {'intermutual', 'ultraminute'}
# {'internality', 'itinerantly'}
# {'reincentive', 'internecive'}
# {'interpolate', 'triantelope'}
# {'neuropteris', 'interposure'}
# {'reinterpret', 'interpreter'}
# {'reinterrupt', 'interrupter'}
# {'intersocial', 'sclerotinia', 'orleanistic'}
# {'tripersonal', 'intersporal'}
# {'interverbal', 'invertebral'}
# {'interviewer', 'reinterview'}
# {'narcoticism', 'intracosmic'}
# {'stratonical', 'intracostal'}
# {'prenatalist', 'paternalist', 'intraseptal'}
# {'intraspinal', 'pinnitarsal'}
# {'serviential', 'inversatile'}
# {'lithophysal', 'isophthalyl'}
# {'jebusitical', 'justiciable'}
# {'mentolabial', 'labiomental'}
# {'metonymical', 'laminectomy'}
# {'laryngotome', 'maternology'}
# {'latirostres', 'setirostral'}
# {'latrocinium', 'tourmalinic'}
# {'leonhardite', 'lionhearted'}
# {'longimanous', 'longanimous'}
# {'sacrolumbal', 'lumbosacral'}
# {'nymphalidae', 'lymphadenia'}
# {'polyphemian', 'lymphopenia'}
# {'semidormant', 'moderantism', 'memorandist'}
# {'tergeminous', 'mentigerous'}
# {'merosthenic', 'microsthene'}
# {'semological', 'mesological'}
# {'mesoventral', 'ventromesal'}
# {'metaplastic', 'palmatisect'}
# {'metropathic', 'metatrophic'}
# {'meteoritics', 'meteoristic'}
# {'remasticate', 'metrectasia'}
# {'prostomiate', 'metroptosia'}
# {'microcephal', 'prochemical'}
# {'microcinema', 'microcnemia'}
# {'relationism', 'misrelation', 'orientalism'}
# {'misreporter', 'reporterism'}
# {'mithraicist', 'mithraistic'}
# {'modernistic', 'monstricide'}
# {'nomadically', 'monadically'}
# {'monoclonius', 'monoclinous'}
# {'monological', 'nomological'}
# {'monomorphic', 'morphonomic'}
# {'monoplanist', 'postnominal'}
# {'toponymical', 'monotypical'}
# {'unmomentary', 'monumentary'}
# {'tomographic', 'motographic'}
# {'phagocytism', 'mycophagist'}
# {'polysomitic', 'myocolpitis'}
# {'myographist', 'pythagorism'}
# {'tenomyotomy', 'myotenotomy'}
# {'phthalazine', 'naphthalize'}
# {'nasoorbital', 'orbitonasal'}
# {'palatonasal', 'nasopalatal'}
# {'necessarian', 'renaissance'}
# {'percolation', 'neotropical'}
# {'phenologist', 'nephologist'}
# {'phrenocolic', 'nephrocolic'}
# {'phrenopathy', 'nephropathy'}
# {'strophomena', 'nephrostoma'}
# {'neurotripsy', 'tripyrenous'}
# {'unalertness', 'neutralness'}
# {'nonreaction', 'noncreation'}
# {'noncreative', 'nonreactive'}
# {'nonoriental', 'nonrelation'}
# {'nonpaternal', 'nonparental'}
# {'objectative', 'objectivate'}
# {'violability', 'obliviality'}
# {'obscurantic', 'subnarcotic'}
# {'offuscation', 'suffocation'}
# {'semicoronet', 'oncosimeter'}
# {'ontological', 'tonological'}
# {'opiniatrety', 'petitionary'}
# {'potableness', 'optableness'}
# {'optological', 'topological'}
# {'orientalist', 'relationist'}
# {'orthogonial', 'orthologian'}
# {'tionontates', 'ostentation'}
# {'stereotomic', 'osteometric'}
# {'tediousness', 'outsideness'}
# {'tuboovarial', 'ovariotubal'}
# {'overpointed', 'predevotion'}
# {'pactionally', 'polyactinal'}
# {'paracelsist', 'palaestrics'}
# {'paniculitis', 'paulinistic'}
# {'panornithic', 'rhaponticin'}
# {'paracolitis', 'piscatorial'}
# {'reparagraph', 'paragrapher'}
# {'paranephric', 'paraphrenic'}
# {'parasuchian', 'unpharasaic'}
# {'parentalism', 'paternalism'}
# {'paternality', 'parentality'}
# {'parenticide', 'preindicate'}
# {'repartition', 'partitioner'}
# {'paternoster', 'transportee', 'prosternate'}
# {'pennatuloid', 'pendulation'}
# {'predominate', 'pentameroid'}
# {'perambulate', 'preambulate'}
# {'percompound', 'precompound'}
# {'perforative', 'prefavorite'}
# {'precipitate', 'peripatetic'}
# {'peripatidae', 'peripatidea'}
# {'periplaneta', 'prepalatine'}
# {'prepositure', 'peripterous'}
# {'peritropous', 'proprietous'}
# {'septiferous', 'pestiferous'}
# {'petrography', 'typographer', 'pterography'}
# {'philotheist', 'theophilist'}
# {'pythogenous', 'phytogenous'}
# {'phytometric', 'thermotypic'}
# {'spiciferous', 'pisciferous'}
# {'planetabler', 'replantable'}
# {'stomatopoda', 'podostomata'}
# {'polarimetry', 'temporarily', 'premorality'}
# {'polychroism', 'polyorchism'}
# {'psilophyton', 'polyphonist'}
# {'predonation', 'ponderation'}
# {'praelection', 'porcelanite'}
# {'sophistical', 'postischial'}
# {'postuterine', 'pretentious'}
# {'preactively', 'precatively'}
# {'preauditory', 'repudiatory'}
# {'respondence', 'precondense'}
# {'predirector', 'precreditor'}
# {'procidentia', 'predication'}
# {'prelusively', 'repulsively'}
# {'pyranometer', 'premonetary'}
# {'proletarian', 'prerational'}
# {'prescapular', 'supercarpal'}
# {'stereograph', 'preshortage'}
# {'proathletic', 'prothetical'}
# {'reprobation', 'probationer'}
# {'sclerospora', 'prolacrosse'}
# {'proletariat', 'reptatorial'}
# {'prorevision', 'reprovision', 'provisioner'}
# {'prosecretin', 'reinspector'}
# {'protopteran', 'protoparent'}
# {'protophytic', 'tropophytic'}
# {'psychomancy', 'scyphomancy'}
# {'pyrogenetic', 'pyretogenic'}
# {'pyrocomenic', 'pyromeconic'}
# {'reductional', 'radiolucent'}
# {'sparingness', 'raspingness'}
# {'realization', 'rationalize'}
# {'recantation', 'triacontane'}
# {'serviceable', 'receivables'}
# {'reconnoiter', 'reconnoitre'}
# {'reinstation', 'santorinite'}
# {'terpeneless', 'repleteness'}
# {'secretional', 'resectional'}
# {'reserveless', 'reverseless'}
# {'scepterless', 'respectless'}
# {'respiration', 'retinispora'}
# {'superheater', 'resuperheat'}
# {'resurrender', 'surrenderer'}
# {'telegrapher', 'retelegraph'}
# {'traditioner', 'retradition'}
# {'retransform', 'transformer'}
# {'retransport', 'transporter'}
# {'upholsterer', 'reupholster'}
# {'revieweress', 'reversewise'}
# {'trochlearis', 'rhetoricals'}
# {'ruinousness', 'urinousness'}
# {'solaristics', 'scissortail'}
# {'scorbutical', 'subcortical'}
# {'semiovoidal', 'semiovaloid'}
# {'serpiginous', 'spinigerous'}
# {'sightliness', 'slightiness'}
# {'southlander', 'southerland'}
# {'spinoneural', 'unipersonal'}
# {'surgeonship', 'springhouse'}
# {'stalagmitic', 'stigmatical'}
# {'strainerman', 'transmarine'}
# {'subcapsular', 'subscapular'}
# {'susceptible', 'suspectible'}
# {'urosternite', 'tenuiroster'}
# {'unrostrated', 'tetrandrous'}
# {'triceratops', 'tetrasporic'}
# {'whitleather', 'therewithal'}
# {'thersitical', 'trachelitis'}
# {'thyroprivic', 'vitrophyric'}
# {'ultramicron', 'tricolumnar'}
# {'unavertible', 'unveritable'}
# {'unmacerated', 'uncamerated'}
# {'uncartooned', 'uncoronated'}
# {'unrectified', 'uncertified'}
# {'uncollapsed', 'unscalloped'}
# {'uncompliant', 'uncomplaint'}
# {'unconcerted', 'unconcreted'}
# {'unrevocable', 'uncoverable'}
# {'uncreatable', 'untraceable'}
# {'undercoated', 'undecorated'}
# {'underhonest', 'unshortened'}
# {'underlegate', 'unrelegated'}
# {'understream', 'undermaster'}
# {'unmonitored', 'undermotion'}
# {'unsharpened', 'undershapen'}
# {'unrescinded', 'undiscerned'}
# {'unenervated', 'unvenerated'}
# {'unquietable', 'unequitable'}
# {'unexpecting', 'unexcepting'}
# {'unfriending', 'uninfringed'}
# {'ungreenable', 'ungenerable'}
# {'unitiveness', 'unsensitive'}
# {'unsceptered', 'unrespected'}
# {'unsepulchre', 'unsepulcher'}
# {'unstateable', 'untasteable'}
# {'untradeable', 'untreadable'}
# {'ablastemic', 'masticable'}
# {'bacterioid', 'aborticide'}
# {'accipitres', 'preascitic'}
# {'acephalina', 'phalaecian'}
# {'arecaceous', 'aceraceous'}
# {'acervation', 'vacationer'}
# {'acervuline', 'avirulence'}
# {'acetanilid', 'laciniated', 'teniacidal'}
# {'aeronautic', 'acetonuria'}
# {'capernoity', 'acetopyrin'}
# {'anchoretic', 'acherontic'}
# {'ordanchite', 'ditrochean', 'achondrite'}
# {'machinator', 'achromatin', 'chariotman'}
# {'claudicate', 'aciculated'}
# {'acidimeter', 'mediatrice'}
# {'radiectomy', 'acidometry', 'medicatory'}
# {'acleistous', 'ossiculate'}
# {'dicoumarin', 'acridonium'}
# {'acrostical', 'socratical'}
# {'naticiform', 'actiniform'}
# {'actinogram', 'morganatic'}
# {'activation', 'cavitation'}
# {'actomyosin', 'inocystoma'}
# {'octonarius', 'acutorsion'}
# {'adequation', 'deaquation'}
# {'admonisher', 'rhamnoside'}
# {'domination', 'admonition'}
# {'dominative', 'admonitive'}
# {'adnascence', 'ascendance'}
# {'aplodontia', 'adoptional'}
# {'adscendent', 'descendant'}
# {'adulterine', 'laurentide'}
# {'aerography', 'areography'}
# {'aerologist', 'areologist'}
# {'racemation', 'cameration', 'aeromantic', 'maceration'}
# {'aerometric', 'areometric'}
# {'aerophilic', 'epichorial'}
# {'haliotidae', 'aethalioid'}
# {'afterstate', 'aftertaste'}
# {'agregation', 'aggeration'}
# {'agricolist', 'algoristic'}
# {'triplasian', 'airplanist'}
# {'alacritous', 'lactarious', 'lactosuria'}
# {'marginally', 'alarmingly'}
# {'alboranite', 'rationable'}
# {'albuminate', 'antelabium'}
# {'aldermanry', 'marylander'}
# {'melotragic', 'algometric'}
# {'alineation', 'alienation'}
# {'allegorist', 'legislator'}
# {'locational', 'allocation'}
# {'loculation', 'allocution'}
# {'patrilocal', 'allopatric'}
# {'psalterian', 'palestrian', 'alpestrian'}
# {'presential', 'episternal', 'interlapse', 'alpestrine'}
# {'ultraistic', 'truistical', 'altruistic'}
# {'lomentaria', 'ameliorant'}
# {'amherstite', 'hemistater'}
# {'plasmation', 'aminoplast'}
# {'ammunition', 'antimonium'}
# {'amphorette', 'haptometer'}
# {'amphoteric', 'metaphoric'}
# {'amyotrophy', 'myoatrophy'}
# {'maraschino', 'anachorism', 'chorasmian'}
# {'analcitite', 'catalinite'}
# {'catalanist', 'anastaltic'}
# {'gynandrous', 'androgynus'}
# {'unsardonic', 'andronicus'}
# {'menostasia', 'anematosis'}
# {'phanerogam', 'anemograph'}
# {'geometrina', 'ergotamine', 'angiometer'}
# {'monarchian', 'anharmonic'}
# {'anhidrotic', 'trachinoid'}
# {'asperation', 'separation', 'anisoptera'}
# {'rayonnance', 'annoyancer'}
# {'unnational', 'annulation'}
# {'anoestrous', 'treasonous'}
# {'palaemonid', 'anomaliped'}
# {'antagonism', 'montagnais'}
# {'antagonist', 'stagnation'}
# {'neapolitan', 'antelopian', 'panelation'}
# {'antemedial', 'delaminate'}
# {'anthemwise', 'whitmanese'}
# {'anthericum', 'narthecium'}
# {'tachinidae', 'anthicidae'}
# {'anthonomus', 'monanthous'}
# {'lithophane', 'anthophile'}
# {'uniflorate', 'fluorinate', 'antifouler'}
# {'unfainting', 'antifungin'}
# {'theorician', 'antiheroic'}
# {'antilipase', 'sapiential'}
# {'antimasque', 'squamatine'}
# {'remaintain', 'maintainer', 'antimerina'}
# {'antimodern', 'ordainment'}
# {'lamination', 'antimonial'}
# {'innominata', 'antinomian'}
# {'antinormal', 'nonmarital', 'nonmartial'}
# {'napthionic', 'antiphonic'}
# {'crispation', 'antipsoric', 'ascription'}
# {'panostitis', 'antiptosis'}
# {'antiputrid', 'tripudiant'}
# {'antirabies', 'bestiarian'}
# {'paintiness', 'antisepsin'}
# {'inspissate', 'antisepsis'}
# {'psittacine', 'antiseptic'}
# {'antitheism', 'themistian'}
# {'antitropic', 'tritanopic'}
# {'antronasal', 'nasoantral'}
# {'contrapose', 'antroscope'}
# {'syncopator', 'antroscopy'}
# {'antrustion', 'nasturtion'}
# {'apanthropy', 'panatrophy'}
# {'archoptoma', 'apochromat'}
# {'autopsical', 'apolaustic'}
# {'operatical', 'aporetical'}
# {'aposporous', 'aprosopous'}
# {'isoheptane', 'apothesine'}
# {'applicator', 'procapital'}
# {'approacher', 'reapproach'}
# {'loquacious', 'aquicolous'}
# {'arachnitis', 'christiana'}
# {'arbalester', 'arbalestre', 'arrestable'}
# {'arbalister', 'breastrail'}
# {'arctoidean', 'carotidean', 'dinocerata', 'cordaitean'}
# {'arcubalist', 'ultrabasic'}
# {'marginated', 'argentamid'}
# {'aristulate', 'australite'}
# {'armiferous', 'ramiferous'}
# {'ramigerous', 'armigerous'}
# {'mallardite', 'malladrite', 'armillated'}
# {'variegator', 'arrogative'}
# {'senatorian', 'sonneratia', 'arsenation'}
# {'arseniuret', 'uniserrate'}
# {'metrorrhea', 'arthromere'}
# {'ascolichen', 'chalcosine'}
# {'asthenopia', 'asiphonate'}
# {'pleasurous', 'asperulous'}
# {'aspiringly', 'praisingly'}
# {'assertible', 'resistable'}
# {'assoilment', 'salmonsite'}
# {'reastonish', 'astonisher', 'treasonish'}
# {'transigent', 'astringent'}
# {'shapometer', 'atmosphere'}
# {'cautionary', 'auctionary'}
# {'enicuridae', 'audiencier'}
# {'saturnalia', 'australian'}
# {'autometric', 'tautomeric'}
# {'aventurine', 'uninervate'}
# {'ingaevones', 'avignonese'}
# {'babishness', 'shabbiness'}
# {'nabobishly', 'babylonish'}
# {'unsatiable', 'balaustine'}
# {'preallably', 'ballplayer'}
# {'headbander', 'bradenhead', 'barehanded'}
# {'workbasket', 'basketwork'}
# {'tabophobia', 'batophobia'}
# {'branchiata', 'batrachian'}
# {'befathered', 'featherbed'}
# {'pinchbelly', 'bellypinch'}
# {'borolanite', 'bertolonia'}
# {'beturbaned', 'unrabbeted'}
# {'bialveolar', 'labiovelar'}
# {'bimodality', 'myliobatid'}
# {'bipersonal', 'prisonable'}
# {'importable', 'bitemporal'}
# {'notability', 'bitonality'}
# {'blastoderm', 'dermoblast'}
# {'bluishness', 'blushiness'}
# {'redoubling', 'bouldering'}
# {'celebrated', 'braceleted'}
# {'brainwater', 'waterbrain'}
# {'brandisher', 'rebrandish'}
# {'brasiletto', 'strobilate'}
# {'warblingly', 'brawlingly'}
# {'breakstone', 'stonebreak'}
# {'breastweed', 'sweetbread'}
# {'drawbridge', 'bridgeward'}
# {'nasobuccal', 'bucconasal'}
# {'umbiliform', 'bulimiform'}
# {'cacomistle', 'cosmetical'}
# {'cacoxenite', 'excecation'}
# {'taccaceous', 'cactaceous'}
# {'caedmonian', 'macedonian'}
# {'catamenial', 'calamitean'}
# {'calaverite', 'lacerative'}
# {'caledonite', 'celadonite'}
# {'lipoclasis', 'calliopsis'}
# {'calotermes', 'mesorectal', 'metacresol'}
# {'cameograph', 'macrophage'}
# {'campaigner', 'recampaign'}
# {'camptonite', 'pentatomic'}
# {'crownmaker', 'cankerworm'}
# {'trivalence', 'cantilever'}
# {'paraenetic', 'capernaite'}
# {'capitellar', 'prelatical'}
# {'scapulated', 'capsulated'}
# {'carmeloite', 'ectromelia', 'meteorical'}
# {'carminette', 'remittance'}
# {'coronadite', 'decoration', 'carotenoid'}
# {'parcellary', 'carpellary'}
# {'carpellate', 'parcellate', 'prelacteal'}
# {'carpholite', 'proethical'}
# {'carposperm', 'spermocarp'}
# {'scortation', 'cartoonist'}
# {'castoridae', 'cestodaria'}
# {'cathograph', 'tachograph'}
# {'catmalison', 'monastical'}
# {'screenless', 'censerless'}
# {'escortment', 'centermost'}
# {'centesimal', 'lemniscate'}
# {'recitement', 'remittence', 'centimeter'}
# {'centimolar', 'melicraton'}
# {'neomiracle', 'ceremonial'}
# {'ceroplasty', 'coreplasty'}
# {'cesarolite', 'esoterical'}
# {'cetorhinus', 'urosthenic'}
# {'chattation', 'thanatotic'}
# {'teachingly', 'cheatingly'}
# {'schooltime', 'chilostome'}
# {'chirometer', 'rheometric'}
# {'rhynchotal', 'chloranthy'}
# {'tornachile', 'chlorinate', 'ectorhinal'}
# {'choriocele', 'orchiocele'}
# {'choristate', 'rheostatic'}
# {'christener', 'rechristen'}
# {'christophe', 'hectorship'}
# {'chromatoid', 'tichodroma'}
# {'chromatone', 'enomotarch'}
# {'cytochrome', 'chromocyte'}
# {'chromopsia', 'isocamphor'}
# {'chromotype', 'cormophyte', 'ectomorphy'}
# {'chrysotile', 'chrysolite'}
# {'chuprassie', 'haruspices'}
# {'conchinine', 'cinchonine'}
# {'cineration', 'inceration'}
# {'cinnamoned', 'demicannon'}
# {'cirsectomy', 'citromyces'}
# {'cisplatine', 'plasticine'}
# {'inspection', 'cispontine'}
# {'interlocal', 'citronella'}
# {'phylloclad', 'cladophyll'}
# {'clamatores', 'scleromata'}
# {'clangingly', 'glancingly'}
# {'clinoclase', 'oscillance'}
# {'recoilment', 'clinometer'}
# {'necropolis', 'clinospore'}
# {'sclerotial', 'cloisteral'}
# {'sclerotium', 'closterium'}
# {'ptyalocele', 'clypeolate'}
# {'cnidophore', 'princehood'}
# {'coaltitude', 'colatitude'}
# {'cochleitis', 'ochlesitic'}
# {'codirector', 'cocreditor'}
# {'entocoelic', 'coelection'}
# {'galactonic', 'cognatical'}
# {'cognominal', 'gnomonical'}
# {'coinherent', 'incoherent'}
# {'colemanite', 'melaconite'}
# {'colonalgia', 'naological'}
# {'columnated', 'documental'}
# {'combinedly', 'molybdenic'}
# {'incomeless', 'comeliness'}
# {'monometric', 'commorient', 'metronomic'}
# {'procnemial', 'recomplain', 'complainer'}
# {'placentoma', 'complanate'}
# {'recompound', 'compounder'}
# {'decompress', 'compressed'}
# {'connective', 'concentive'}
# {'concertize', 'concretize'}
# {'confounder', 'reconfound'}
# {'reconfront', 'confronter'}
# {'necrogenic', 'congeneric'}
# {'conversant', 'conservant'}
# {'considered', 'deconsider'}
# {'considerer', 'reconsider'}
# {'conspiracy', 'snipocracy'}
# {'contracter', 'correctant', 'recontract'}
# {'covenanter', 'contravene'}
# {'ventricose', 'convertise'}
# {'poculation', 'copulation'}
# {'ectocardia', 'coradicate'}
# {'directoire', 'cordierite'}
# {'radiculose', 'coresidual'}
# {'uncloister', 'cornulites'}
# {'corollated', 'decollator'}
# {'eradicator', 'corradiate', 'cortaderia'}
# {'correption', 'porrection'}
# {'cotylosaur', 'osculatory'}
# {'nectareous', 'countersea'}
# {'uncomplete', 'couplement'}
# {'touchiness', 'couthiness'}
# {'cradlemate', 'malcreated'}
# {'creatinine', 'incinerate'}
# {'creational', 'laceration', 'crotalinae', 'reactional'}
# {'creatively', 'reactively'}
# {'reactivity', 'creativity'}
# {'interlaced', 'credential', 'reclinated'}
# {'creditable', 'directable'}
# {'directress', 'creditress'}
# {'crednerite', 'interceder'}
# {'misdeclare', 'creedalism'}
# {'cristopher', 'rectorship'}
# {'supersonic', 'percussion', 'croupiness'}
# {'scrutation', 'crustation'}
# {'rusticness', 'crustiness'}
# {'cryptodire', 'predictory'}
# {'ctenophore', 'nectophore'}
# {'pasticheur', 'curateship'}
# {'indirectly', 'cylindrite'}
# {'cynophilic', 'philocynic'}
# {'dacryolith', 'hydrotical'}
# {'gardenless', 'dangerless'}
# {'waddlingly', 'dawdlingly'}
# {'endophasic', 'deaconship'}
# {'dealership', 'leadership'}
# {'medication', 'decimation'}
# {'recrudency', 'decurrency'}
# {'fornicated', 'deforciant'}
# {'delegation', 'degelation'}
# {'derogately', 'delegatory'}
# {'deligation', 'gadolinite', 'gelatinoid'}
# {'delineator', 'rondeletia'}
# {'derailment', 'delirament'}
# {'delphinius', 'sulphinide'}
# {'demilustre', 'demiluster'}
# {'demiturned', 'undertimed'}
# {'redemolish', 'demolisher'}
# {'denominate', 'emendation'}
# {'denotation', 'detonation'}
# ...
# {'haul', 'hula'}
# {'hawm', 'wham'}
# {'hazy', 'hayz'}
# {'heel', 'hele'}
# {'here', 'heer'}
# {'heir', 'hire'}
# {'heml', 'helm'}
# {'then', 'neth', 'hent'}
# {'lehr', 'hler', 'herl'}
# {'hoer', 'hero'}
# {'hers', 'resh', 'sher'}
# {'hevi', 'hive'}
# {'when', 'hewn'}
# {'thew', 'whet', 'hewt'}
# {'lith', 'hilt'}
# {'hing', 'nigh'}
# {'hint', 'thin'}
# {'shih', 'hish'}
# {'sinh', 'hisn', 'shin'}
# {'hiss', 'sish'}
# {'sith', 'this', 'tshi', 'hist'}
# {'hoar', 'hora'}
# {'hock', 'koch'}
# {'thio', 'hoti', 'hoit'}
# {'homo', 'moho'}
# {'pooh', 'hoop', 'phoo'}
# {'toho', 'thoo', 'hoot'}
# {'peho', 'hope'}
# {'hose', 'shoe'}
# {'thos', 'host', 'tosh', 'shot'}
# {'huer', 'hure'}
# {'hugo', 'ough'}
# {'hump', 'umph'}
# {'hurt', 'ruth'}
# {'shou', 'huso'}
# {'mabi', 'iamb'}
# {'idle', 'lide', 'lied'}
# {'idyl', 'idly'}
# {'jami', 'ijma'}
# {'ikra', 'kari', 'raki'}
# {'kail', 'kali', 'ilka'}
# {'yill', 'illy', 'lily'}
# {'toil', 'ilot'}
# {'ilya', 'yali'}
# {'mimi', 'immi'}
# {'zein', 'inez'}
# {'skin', 'sink', 'inks'}
# {'inly', 'liny'}
# {'nori', 'iron', 'inro', 'noir'}
# {'tino', 'into', 'oint', 'nito'}
# {'iodo', 'ooid'}
# {'tiao', 'iota'}
# {'ipil', 'pili'}
# {'kori', 'irok'}
# {'isis', 'sisi'}
# {'lise', 'isle', 'sile'}
# {'iten', 'tien', 'tine', 'neti'}
# {'teri', 'reit', 'tier', 'tire', 'iter', 'rite'}
# {'itmo', 'moit', 'omit', 'timo'}
# {'zati', 'tiza', 'itza'}
# {'vain', 'ivan', 'vina'}
# {'zira', 'izar'}
# {'lija', 'jail'}
# {'jina', 'jain'}
# {'maja', 'jama'}
# {'jean', 'jane'}
# {'jota', 'jato'}
# {'juan', 'jaun'}
# {'puja', 'jaup'}
# {'join', 'joni'}
# {'mojo', 'joom'}
# {'teju', 'jute'}
# {'kaik', 'kaki'}
# {'kale', 'lake', 'leak'}
# {'loka', 'kola', 'kalo'}
# {'meak', 'kame', 'make'}
# {'kang', 'knag'}
# {'sank', 'kans'}
# {'lark', 'karl', 'kral'}
# {'roka', 'kora', 'okra', 'karo'}
# {'kasm', 'mask'}
# {'keta', 'kate', 'take', 'teak'}
# {'khat', 'kath'}
# {'kyat', 'katy', 'taky'}
# {'kavi', 'kiva'}
# {'kayo', 'oaky'}
# {'keel', 'leek', 'kele'}
# {'keen', 'knee'}
# {'keep', 'peek'}
# {'skee', 'kees', 'seek'}
# {'kent', 'knet'}
# {'pike', 'kepi', 'kipe'}
# {'kern', 'renk'}
# {'keto', 'toke', 'oket'}
# {'teuk', 'ketu', 'tuke'}
# {'puke', 'keup'}
# {'kiel', 'like'}
# {'kiku', 'kuki'}
# {'link', 'kiln'}
# {'koil', 'kilo', 'koli'}
# {'kilp', 'klip'}
# {'kirk', 'rikk'}
# {'kirn', 'rink'}
# {'shik', 'kish', 'sikh'}
# {'kist', 'skit'}
# {'klan', 'lank'}
# {'klop', 'polk'}
# {'pank', 'knap'}
# {'rank', 'kran', 'knar', 'nark'}
# {'knit', 'tink'}
# {'tonk', 'knot'}
# {'tunk', 'knut'}
# {'loke', 'koel'}
# {'look', 'kolo'}
# {'moke', 'kome'}
# {'komi', 'moki'}
# {'kona', 'nako'}
# {'roke', 'kore'}
# {'roky', 'kory', 'york'}
# {'skoo', 'sook', 'koso'}
# {'toko', 'koto', 'took'}
# {'risk', 'kris'}
# {'kroo', 'rook'}
# {'rauk', 'kuar', 'raku'}
# {'kulm', 'mulk'}
# {'kurt', 'turk'}
# {'skua', 'kusa'}
# {'kyar', 'yark'}
# {'yelk', 'kyle'}
# {'yolk', 'kylo'}
# {'tyke', 'kyte'}
# {'lola', 'olla', 'lalo'}
# {'palm', 'lamp'}
# {'palp', 'lapp', 'plap'}
# {'lias', 'lasi', 'lisa', 'sail', 'sial'}
# {'lask', 'skal'}
# {'last', 'salt', 'slat'}
# {'taal', 'lata', 'tala'}
# {'ulna', 'unal', 'laun', 'luna'}
# {'veal', 'vela', 'vale', 'lave'}
# {'lawk', 'walk'}
# {'laze', 'zeal'}
# {'lepa', 'leap', 'pale', 'peal', 'plea'}
# {'peel', 'leep', 'pele'}
# {'leer', 'reel'}
# {'tele', 'lete', 'teel', 'leet'}
# {'selt', 'lest'}
# {'leto', 'tole', 'lote'}
# {'telt', 'lett'}
# {'leuk', 'luke'}
# {'vole', 'velo', 'love', 'levo'}
# {'lewd', 'weld'}
# {'line', 'lien', 'neil', 'nile'}
# {'lier', 'rile', 'lire'}
# {'lilt', 'till'}
# {'limp', 'plim', 'pilm'}
# {'lion', 'noil', 'loin', 'lino'}
# {'pali', 'pial', 'lipa', 'pail'}
# {'skil', 'lisk', 'silk'}
# {'lisp', 'slip'}
# {'slit', 'silt', 'list'}
# {'tile', 'teli', 'teil', 'lite'}
# {'well', 'llew'}
# {'mola', 'olam', 'malo', 'loma', 'loam'}
# {'lori', 'roil', 'loir'}
# {'siol', 'lois', 'silo', 'soil', 'soli'}
# {'loom', 'mool'}
# {'nolo', 'loon'}
# {'polo', 'pool', 'loop'}
# {'tool', 'loot'}
# {'olpe', 'lope', 'pole'}
# {'oral', 'lora'}
# {'orle', 'lore', 'role'}
# {'loro', 'orlo', 'olor', 'rool'}
# {'lose', 'sole', 'sloe'}
# {'lots', 'slot', 'lost'}
# {'ludo', 'loud'}
# {'tolu', 'lout'}
# {'yowl', 'owly', 'lowy'}
# {'odyl', 'loyd'}
# {'slue', 'lues'}
# {'lula', 'ulla'}
# {'plum', 'lump'}
# {'pelu', 'pule', 'peul', 'lupe'}
# {'lure', 'rule'}
# {'shlu', 'lush', 'shul'}
# {'lusk', 'sulk'}
# {'lust', 'slut'}
# {'tule', 'lute'}
# {'ulex', 'luxe'}
# {'lyas', 'slay'}
# {'only', 'lyon'}
# {'lyre', 'rely'}
# {'sley', 'lyse'}
# {'noam', 'moan', 'oman', 'mano', 'noma', 'mona'}
# {'myna', 'many'}
# {'mart', 'tram'}
# {'sham', 'mash', 'samh'}
# {'mats', 'stam', 'mast'}
# {'musa', 'saum', 'masu'}
# {'meta', 'tema', 'team', 'meat', 'tame', 'mate'}
# {'numa', 'maun'}
# {'mawp', 'wamp'}
# {'meet', 'mete', 'teem'}
# {'mien', 'mine', 'mein'}
# {'oime', 'meio'}
# {'mome', 'memo'}
# {'reem', 'mere'}
# {'omer', 'more', 'rome', 'mero'}
# {'seem', 'smee', 'seme', 'mese'}
# {'some', 'mose', 'meso'}
# {'sima', 'saim', 'siam', 'mias'}
# {'mike', 'miek'}
# {'moil', 'milo'}
# {'rimy', 'miry', 'yirm'}
# {'semi', 'mise', 'sime'}
# {'smit', 'stim', 'mist'}
# {'omen', 'mone', 'nome'}
# {'mono', 'moon'}
# {'pomo', 'moop'}
# {'moor', 'room', 'moro'}
# {'moot', 'toom'}
# {'pome', 'poem', 'mope'}
# {'morn', 'norm'}
# {'mote', 'tome'}
# {'ulmo', 'moul'}
# {'rimu', 'muir'}
# {'stum', 'smut', 'must'}
# {'muta', 'taum'}
# {'mute', 'tume'}
# {'snab', 'nabs'}
# {'nain', 'nina'}
# {'nape', 'neap', 'pane', 'nepa', 'pean'}
# {'napu', 'puan', 'puna'}
# {'yarn', 'nary'}
# {'stan', 'nast', 'sant'}
# {'natr', 'tran', 'rant', 'tarn'}
# {'nawt', 'tawn', 'want'}
# {'nazi', 'zain'}
# {'neep', 'peen'}
# {'teen', 'neet', 'nete'}
# {'none', 'neon'}
# {'rine', 'neri', 'rein'}
# {'nesh', 'shen'}
# {'sten', 'nest', 'sent'}
# {'oven', 'nevo'}
# {'snew', 'sewn', 'news'}
# {'newt', 'went'}
# {'snib', 'nibs'}
# {'pain', 'pani', 'pina', 'pian', 'nipa'}
# {'niue', 'unie'}
# {'poon', 'noop'}
# {'nope', 'peon', 'pone', 'open'}
# {'roan', 'orna', 'nora'}
# {'nous', 'onus', 'nosu'}
# {'tone', 'note'}
# {'noup', 'puno', 'upon'}
# {'wont', 'town', 'nowt'}
# {'zion', 'nozi'}
# {'oast', 'stoa', 'taos'}
# {'ondy', 'yond'}
# {'oner', 'rone'}
# {'oont', 'onto', 'toon'}
# {'oons', 'soon'}
# {'paho', 'opah', 'poha'}
# {'opsy', 'posy'}
# {'opus', 'soup'}
# {'oryx', 'roxy'}
# {'toto', 'otto', 'toot'}
# {'oust', 'suto', 'otus'}
# {'sour', 'ours'}
# {'rove', 'over'}
# {'ower', 'wore'}
# {'yore', 'oyer', 'roey'}
# {'pala', 'paal'}
# {'pika', 'paik'}
# {'pipa', 'paip'}
# {'ripa', 'pari', 'pria', 'pair'}
# {'plat', 'palt'}
# {'pyla', 'pyal', 'paly', 'play'}
# {'prad', 'pard'}
# {'trap', 'rapt', 'part', 'prat', 'tarp'}
# {'taps', 'stap', 'past', 'spat'}
# {'peat', 'pate', 'teap', 'tape'}
# {'paut', 'patu', 'tapu'}
# {'upla', 'paul'}
# {'paup', 'pupa'}
# {'pope', 'pepo'}
# {'peri', 'pier', 'ripe'}
# {'terp', 'petr', 'pert'}
# {'prue', 'peru', 'pure'}
# {'seps', 'pess'}
# {'sept', 'step', 'pest', 'spet'}
# {'peto', 'pote', 'poet', 'tope'}
# {'pewy', 'wype'}
# {'phit', 'pith'}
# {'shop', 'soph', 'posh', 'phos'}
# {'phot', 'toph'}
# {'pien', 'pine'}
# {'piet', 'tipe'}
# {'piny', 'pyin'}
# {'pise', 'sipe'}
# {'pish', 'ship'}
# {'skip', 'pisk'}
# {'spit', 'pist'}
# {'polt', 'plot'}
# {'ploy', 'poly'}
# {'pulp', 'plup'}
# {'poor', 'proo'}
# {'topo', 'poot', 'toop'}
# {'pore', 'rope'}
# {'pyro', 'pory', 'ropy'}
# {'stop', 'spot', 'post', 'tops'}
# {'roup', 'pour'}
# {'pout', 'toup'}
# {'ramp', 'pram'}
# {'rupa', 'prau'}
# {'prep', 'repp'}
# {'rype', 'pyre', 'prey'}
# {'ropp', 'prop'}
# {'prut', 'turp'}
# {'sari', 'sair', 'rais'}
# {'reak', 'rake'}
# {'rare', 'rear'}
# {'sara', 'rasa'}
# {'spar', 'rasp'}
# {'taar', 'rata', 'tara'}
# {'rate', 'tare', 'tera', 'tear'}
# {'uran', 'urna', 'raun'}
# {'ravi', 'vari', 'riva', 'vair', 'vira'}
# {'reet', 'teer', 'tree'}
# {'seri', 'reis', 'sire', 'rise', 'sier'}
# {'tern', 'rent'}
# {'rune', 'ruen', 'renu'}
# {'resp', 'reps'}
# {'stre', 'rest', 'sert'}
# {'rush', 'rhus'}
# {'roit', 'riot', 'trio'}
# {'rist', 'stir'}
# {'rive', 'vier', 'veri', 'vire'}
# {'roto', 'toro', 'root'}
# {'sory', 'rosy'}
# {'tora', 'taro', 'rota'}
# {'rote', 'tore'}
# {'toru', 'rout', 'tour'}
# {'tyro', 'ryot', 'troy', 'tory', 'royt'}
# {'turn', 'runt', 'trun'}
# {'saur', 'rusa', 'sura', 'ursa', 'usar'}
# {'user', 'suer', 'ruse', 'sure'}
# {'ruta', 'taur'}
# {'yern', 'ryen'}
# {'sadr', 'sard'}
# {'sago', 'soga'}
# {'shoa', 'saho'}
# {'sake', 'seak'}
# {'sika', 'siak', 'saki'}
# {'slap', 'salp'}
# {'sang', 'snag'}
# {'star', 'tars', 'tsar', 'stra', 'sart'}
# {'saul', 'sula'}
# {'utas', 'tasu', 'saut'}
# {'sawn', 'snaw', 'swan'}
# {'taws', 'staw', 'twas', 'wast', 'sawt', 'swat'}
# {'scye', 'syce'}
# {'shea', 'seah'}
# {'seit', 'site'}
# {'send', 'sned'}
# {'stet', 'test', 'sett'}
# {'shat', 'tash'}
# {'shaw', 'wash'}
# {'shoo', 'soho'}
# {'shut', 'tush', 'thus'}
# {'snig', 'sign', 'sing'}
# {'skat', 'task'}
# {'soke', 'skeo'}
# {'skey', 'skye'}
# {'skun', 'sunk'}
# {'wels', 'slew'}
# {'sold', 'slod'}
# {'sloo', 'solo', 'sool'}
# {'slow', 'sowl'}
# {'suld', 'slud'}
# {'span', 'snap'}
# {'spin', 'snip'}
# {'snod', 'sond'}
# {'song', 'snog'}
# {'sown', 'snow'}
# {'snug', 'sung'}
# {'spun', 'snup'}
# {'stof', 'soft'}
# {'toss', 'sots'}
# {'sumo', 'soum'}
# {'wots', 'swot', 'sowt', 'stow'}
# {'swep', 'spew'}
# {'stew', 'west'}
# {'stey', 'yest'}
# {'togs', 'stog'}
# {'tost', 'stot'}
# {'suet', 'stue'}
# {'stun', 'sunt', 'tsun'}
# {'stut', 'tuts'}
# {'styx', 'xyst'}
# {'swap', 'wasp'}
# {'yaws', 'sway', 'ways'}
# {'tatu', 'taut'}
# {'tave', 'veta'}
# {'teet', 'tete'}
# {'weta', 'twae', 'tewa'}
# {'what', 'wath', 'thaw'}
# {'they', 'yeth'}
# {'yont', 'tony'}
# {'tron', 'torn'}
# {'tort', 'trot'}
# {'toty', 'tyto'}
# {'yowt', 'towy'}
# {'tyre', 'trey'}
# {'trow', 'wort'}
# {'unto', 'tuno'}
# {'walt', 'twal'}
# {'watt', 'twat'}
# {'weet', 'twee'}
# {'twin', 'wint'}
# {'ulva', 'uval'}
# {'unze', 'zenu'}
# {'vail', 'vali', 'vial', 'vila'}
# {'vein', 'vine'}
# {'vote', 'veto', 'voet'}
# {'view', 'wive'}
# {'waeg', 'wega', 'wage'}
# {'waer', 'ware', 'wear'}
# {'wail', 'wali'}
# {'weka', 'wake', 'weak'}
# {'weal', 'wale'}
# {'weam', 'wame'}
# {'warf', 'wraf'}
# {'wran', 'warn'}
# {'warp', 'wrap'}
# {'weed', 'wede'}
# {'wene', 'ween'}
# {'weir', 'weri', 'wire'}
# {'with', 'whit'}
# {'wisp', 'wips'}
# {'yate', 'yeat', 'yeta'}
# {'yees', 'yese'}
# {'aal', 'ala'}
# {'ama', 'aam'}
# {'baa', 'aba'}
# {'bab', 'abb'}
# {'bea', 'abe', 'bae'}
# {'boa', 'abo'}
# {'aby', 'bay'}
# {'ach', 'cha'}
# {'act', 'cat'}
# {'dad', 'add'}
# {'dae', 'ade'}
# {'ado', 'oda', 'dao'}
# {'day', 'ady', 'yad'}
# {'zad', 'adz'}
# {'are', 'ear', 'aer', 'era', 'rea'}
# {'aes', 'sea', 'ase'}
# {'fat', 'aft'}
# {'ago', 'goa'}
# {'gay', 'agy'}
# {'hao', 'aho'}
# {'hat', 'tha', 'aht'}
# {'auh', 'ahu', 'hau'}
# {'ida', 'aid'}
# {'lai', 'ail', 'ila'}
# {'ima', 'aim', 'ami'}
# {'ira', 'air', 'ria'}
# {'ait', 'ati', 'ita', 'tai'}
# {'ake', 'kea'}
# {'koa', 'oak', 'ako', 'oka'}
# {'auk', 'kua', 'aku'}
# {'alb', 'bal', 'lab'}
# {'lea', 'ale'}
# {'alk', 'lak'}
# {'lan', 'aln'}
# {'lao', 'loa', 'alo'}
# {'lap', 'pal', 'alp'}
# {'tal', 'alt', 'lat'}
# {'aly', 'lay'}
# {'mae', 'ame'}
# {'amt', 'mat', 'tam'}
# {'may', 'amy', 'mya', 'yam'}
# {'ana', 'naa'}
# {'and', 'dan'}
# {'ian', 'ani'}
# {'ann', 'nan'}
# {'ant', 'nat', 'tan'}
# {'any', 'nay', 'yan'}
# {'ape', 'pea'}
# {'apt', 'pat', 'tap'}
# {'car', 'arc'}
# {'kra', 'ark'}
# {'mar', 'ram', 'arm'}
# {'nar', 'ran', 'arn'}
# {'ora', 'oar', 'aro'}
# {'art', 'tar', 'tra', 'rat'}
# {'aru', 'rua', 'ura'}
# {'rax', 'arx'}
# {'ray', 'yar', 'ary'}
# {'saa', 'asa'}
# {'sha', 'ash', 'sah'}
# {'sak', 'ask'}
# {'spa', 'sap', 'asp'}
# {'ast', 'sat'}
# {'taa', 'ata'}
# {'ate', 'tae', 'tea', 'eat', 'eta'}
# {'mau', 'aum'}
# {'ave', 'eva'}
# {'ova', 'avo'}
# {'wad', 'daw', 'awd'}
# {'wea', 'awe', 'wae'}
# {'awl', 'law'}
# {'awn', 'wan', 'naw'}
# {'yea', 'aye'}
# {'zoa', 'azo'}
# {'cab', 'bac'}
# {'dab', 'bad'}
# {'bag', 'gab'}
# {'bam', 'mab'}
# {'ban', 'nab'}
# {'bra', 'bar', 'rab'}
# {'sab', 'bas'}
# {'tab', 'bat'}
# {'baw', 'wab'}
# {'bed', 'deb'}
# {'bel', 'elb'}
# {'neb', 'ben'}
# {'reb', 'ber'}
# {'bye', 'bey'}
# {'dib', 'bid'}
# {'gib', 'big'}
# {'bim', 'mib'}
# {'bin', 'nib'}
# {'bis', 'sib'}
# {'tib', 'bit'}
# {'blo', 'lob'}
# {'dob', 'bod'}
# {'bog', 'gob'}
# {'bom', 'mob'}
# {'nob', 'bon'}
# {'bop', 'pob'}
# {'rob', 'orb', 'bor'}
# {'sob', 'bos'}
# {'bow', 'wob'}
# {'dub', 'bud'}
# {'nub', 'bun'}
# {'rub', 'bur'}
# {'sub', 'bus'}
# {'but', 'tub'}
# {'cal', 'lac'}
# {'cam', 'mac'}
# {'cap', 'pac'}
# {'caw', 'wac'}
# {'ich', 'chi', 'hic'}
# {'cho', 'och'}
# {'tic', 'cit'}
# {'cod', 'doc'}
# {'orc', 'roc', 'cor', 'cro'}
# {'cos', 'soc', 'osc'}
# {'gad', 'dag'}
# {'dha', 'had', 'dah'}
# {'dal', 'lad'}
# {'dam', 'mad'}
# {'pad', 'dap'}
# {'dar', 'rad'}
# {'das', 'sad'}
# {'ged', 'deg'}
# {'eld', 'del', 'led'}
# {'ned', 'end', 'den'}
# {'wed', 'dew'}
# {'dey', 'dye', 'yed'}
# {'dhu', 'hud'}
# {'die', 'ide'}
# {'dig', 'gid'}
# {'mid', 'dim'}
# {'nid', 'ind', 'din'}
# {'sid', 'dis'}
# {'dit', 'tid'}
# {'odd', 'dod'}
# {'doe', 'ode', 'edo'}
# {'dog', 'god'}
# {'dol', 'lod', 'old'}
# {'mod', 'dom'}
# {'don', 'nod'}
# {'dop', 'pod'}
# {'dor', 'rod'}
# {'sod', 'ods', 'dos'}
# {'dot', 'tod'}
# {'dow', 'wod', 'owd'}
# {'dug', 'gud'}
# {'dum', 'mud'}
# {'udo', 'duo'}
# {'dup', 'pud'}
# {'ean', 'nea', 'nae'}
# {'lee', 'eel'}
# {'ree', 'eer', 'ere'}
# {'eft', 'fet'}
# {'ego', 'geo'}
# {'kee', 'eke'}
# {'lie', 'lei', 'eli'}
# {'lek', 'elk'}
# {'mel', 'elm'}
# {'els', 'les'}
# {'let', 'elt'}
# {'mem', 'emm'}
# {'ume', 'emu'}
# {'ens', 'sen'}
# {'one', 'eon', 'neo'}
# {'red', 'erd'}
# {'ger', 'reg', 'erg'}
# {'ers', 'ser'}
# {'eve', 'vee'}
# {'wee', 'ewe'}
# {'yee', 'eye'}
# {'eyn', 'nye', 'yen'}
# {'far', 'fra'}
# {'fei', 'ife', 'fie'}
# {'nef', 'fen'}
# {'gif', 'fig'}
# {'flo', 'lof'}
# {'foo', 'ofo'}
# {'for', 'fro', 'orf'}
# {'oft', 'fot'}
# {'fou', 'ouf'}
# {'urf', 'fur'}
# {'gaj', 'jag'}
# {'lag', 'gal'}
# {'mag', 'gam'}
# {'nag', 'gan'}
# {'gra', 'gar', 'rag'}
# {'sag', 'gas'}
# {'tag', 'gat'}
# {'gaw', 'wag'}
# {'gaz', 'zag'}
# {'gel', 'leg'}
# {'gem', 'meg'}
# {'seg', 'ges'}
# {'teg', 'get'}
# {'gim', 'mig'}
# {'gin', 'ing', 'nig'}
# {'goi', 'gio'}
# {'pig', 'gip'}
# {'tig', 'git'}
# {'gnu', 'gun'}
# {'log', 'gol'}
# {'nog', 'gon'}
# {'gor', 'rog'}
# {'gos', 'sog'}
# {'tog', 'got'}
# {'gul', 'lug'}
# {'mug', 'gum'}
# {'gup', 'pug'}
# {'gur', 'rug'}
# {'tug', 'gut'}
# {'hak', 'kha'}
# {'mah', 'ham'}
# {'hap', 'pah'}
# {'wah', 'wha', 'haw', 'hwa'}
# {'hay', 'yah'}
# {'hie', 'hei'}
# {'rhe', 'her', 'reh'}
# {'het', 'the'}
# {'hip', 'phi'}
# {'hsi', 'his', 'shi'}
# {'pho', 'poh', 'hop'}
# {'hot', 'tho'}
# {'who', 'how'}
# {'ugh', 'hug'}
# {'huk', 'khu'}
# {'hup', 'phu'}
# {'obi', 'ibo'}
# {'kil', 'ilk'}
# {'pim', 'imp'}
# {'kin', 'ink'}
# {'ion', 'ino'}
# {'rie', 'ire'}
# {'rik', 'irk'}
# {'ism', 'sim'}
# {'sit', 'ist', 'its'}
# {'ito', 'toi'}
# {'vai', 'iva', 'via'}
# {'yoi', 'iyo'}
# {'raj', 'jar'}
# {'jat', 'taj'}
# {'nak', 'kan'}
# {'yak', 'kay'}
# {'kip', 'pik'}
# {'koi', 'oki'}
# {'kor', 'rok'}
# {'kos', 'sok'}
# {'mal', 'lam'}
# {'sla', 'las', 'sal'}
# {'ole', 'leo'}
# {'rel', 'ler'}
# {'lue', 'ule', 'leu'}
# {'lye', 'ley'}
# {'mil', 'lim'}
# {'nil', 'lin'}
# {'lis', 'sil'}
# {'til', 'lit'}
# {'pol', 'lop'}
# {'lot', 'tol'}
# {'lou', 'luo'}
# {'low', 'owl', 'lwo'}
# {'lys', 'sly'}
# {'man', 'nam'}
# {'oam', 'mao'}
# {'map', 'pam'}
# {'sma', 'mas', 'sam'}
# {'mwa', 'maw'}
# {'meo', 'moe'}
# {'mew', 'wem'}
# {'ohm', 'mho'}
# {'nim', 'min'}
# {'rim', 'mir'}
# {'mop', 'pom'}
# {'mot', 'tom'}
# {'moy', 'yom'}
# {'rum', 'mru'}
# {'sum', 'mus'}
# {'pan', 'nap'}
# {'nep', 'pen'}
# {'ten', 'net'}
# {'new', 'wen'}
# {'pin', 'nip'}
# {'tin', 'nit'}
# {'ona', 'noa'}
# {'ron', 'nor'}
# {'ton', 'not'}
# {'own', 'won', 'now'}
# {'noy', 'yon'}
# {'tun', 'nut'}
# {'toa', 'oat', 'tao'}
# {'oer', 'roe', 'ore'}
# {'soe', 'ose', 'oes'}
# {'son', 'ons'}
# {'poe', 'ope'}
# {'opt', 'top', 'pot'}
# {'ort', 'tor', 'rot'}
# {'ory', 'roy', 'yor'}
# {'oto', 'too'}
# {'our', 'uro'}
# {'tou', 'out'}
# {'woe', 'owe'}
# {'yox', 'oxy'}
# {'par', 'rap'}
# {'pau', 'pua'}
# {'wap', 'paw'}
# {'pya', 'pay', 'yap'}
# {'rep', 'per'}
# {'pir', 'rip'}
# {'pit', 'tip'}
# {'wop', 'pow'}
# {'pry', 'pyr'}
# {'psi', 'sip'}
# {'pus', 'sup'}
# {'put', 'tup'}
# {'sar', 'ras'}
# {'war', 'raw'}
# {'rio', 'roi'}
# {'rit', 'tri'}
# {'wro', 'row'}
# {'urd', 'rud'}
# {'ure', 'rue'}
# {'run', 'urn'}
# {'urs', 'sur', 'rus'}
# {'tur', 'rut'}
# {'rye', 'yer'}
# {'sia', 'sai'}
# {'saw', 'swa', 'was'}
# {'yas', 'say'}
# {'wes', 'sew'}
# {'sey', 'yes', 'sye'}
# {'soh', 'sho'}
# {'ush', 'shu'}
# {'sir', 'sri'}
# {'sis', 'ssi'}
# {'sus', 'ssu'}
# {'stu', 'ust'}
# {'sud', 'uds'}
# {'sue', 'use'}
# {'tau', 'tua', 'uta'}
# {'vat', 'tav'}
# {'twa', 'wat', 'taw'}
# {'tay', 'yat'}
# {'tew', 'wet'}
# {'two', 'tow', 'wot'}
# {'yot', 'toy'}
# {'ute', 'tue'}
# {'twi', 'wit'}
# {'yet', 'tye'}
# {'vau', 'uva'}
# {'vie', 'vei'}
# {'way', 'yaw'}
# {'yew', 'wye', 'wey'}
# {'yow', 'woy'}
# {'yeo', 'yoe'}
# {'ab', 'ba'}
# {'ad', 'da'}
# {'ae', 'ea'}
# {'ah', 'ha'}
# {'ak', 'ka'}
# {'al', 'la'}
# {'am', 'ma'}
# {'na', 'an'}
# {'ra', 'ar'}
# {'as', 'sa'}
# {'at', 'ta'}
# {'aw', 'wa'}
# {'ya', 'ay'}
# {'ed', 'de'}
# {'id', 'di'}
# {'do', 'od'}
# {'eh', 'he'}
# {'me', 'em'}
# {'en', 'ne'}
# {'re', 'er'}
# {'se', 'es'}
# {'ye', 'ey'}
# {'fi', 'if'}
# {'of', 'fo'}
# {'go', 'og'}
# {'oh', 'ho'}
# {'ni', 'in'}
# {'is', 'si'}
# {'it', 'ti'}
# {'ko', 'ok'}
# {'om', 'mo'}
# {'um', 'mu'}
# {'my', 'ym'}
# {'no', 'on'}
# {'un', 'nu'}
# {'ro', 'or'}
# {'so', 'os'}
# {'ow', 'wo'}
# {'pu', 'up'}
# {'ut', 'tu'}
