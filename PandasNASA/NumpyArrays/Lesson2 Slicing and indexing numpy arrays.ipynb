# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
monalisa = np.load('monalisa.npy')

# %%
monalisa.shape
# Out:
# (1198, 804, 3)

# %%
plt.imshow(monalisa)

# %%
monalisa[600,400,0]
# Out:
# 247

# %%
monalisa[-50,-50,1]
# Out:
# 11

# %%
#assign specific points in the array to another value (don't forget the array is 3 dimensional)
monalisa[400,200,0] = monalisa[600,400,1] = monalisa[600,400,2] = 0

# %%
plt.imshow(monalisa)

# %%
 monalisa[400,200,0]
# Out:
# 0

# %%
normalList = [[1,2,3],[4,5,6],[7,8,9]]

# %%
# normalList[2][2]
normalList[1,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-64f6ff29e24c> in <module>
#       1 # normalList[2][2]
# ----> 2 normalList[1, :2]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
#plotting particular points in the image
plt.imshow(monalisa[400:800,200:600,0:3])

# %%
plt.imshow(monalisa[400:800,:,:])

# %%
plt.imshow(monalisa[400:800,...])

# %%
plt.imshow(monalisa[::20,::20,:])

# %%
plt.imshow(monalisa[::-20,::20,:])

# %%
rows = monalisa[20,::20,0]

# %%
rows.shape
# Out:
# (41,)

# %%
rows
# Out:
# array([104,  81, 107, 100,  90,  98,  94, 103, 103,  97,  99, 105, 116,
#        100,  90,  97,  85,  97,  93,  97, 104,  94,  85, 112,  92,  98,
#         88,  81, 106,  79,  80,  91,  82, 100, 104,  88,  88,  79,  81,
#         81,  88], dtype=uint8)

# %%
plt.plot(monalisa[20,::20,0])

# %%
rect = monalisa[20:21,::20,0]

# %%
rect.shape
# Out:
# (1, 41)

# %%
rect
# Out:
# array([[104,  81, 107, 100,  90,  98,  94, 103, 103,  97,  99, 105, 116,
#         100,  90,  97,  85,  97,  93,  97, 104,  94,  85, 112,  92,  98,
#          88,  81, 106,  79,  80,  91,  82, 100, 104,  88,  88,  79,  81,
#          81,  88]], dtype=uint8)

# %%
monalisa[20:300,20:300,:] = 255

# %%
plt.imshow(monalisa)

# %%
monalisa[20:300,20:300,:] = np.random.randint(100,255)

# %%
plt.imshow(monalisa)
